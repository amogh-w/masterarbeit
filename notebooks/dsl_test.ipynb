# %%
import sys
import os

# Add the src directory to sys.path
sys.path.append(os.path.abspath("../src"))

# %%
from abstractions.primitives.shapes import Box

# %%
# from abstractions.dsl import instantiate, Rect
from abstractions.primitives import show_boxes
from abstractions.toy_data import random_squares
# Out:
# ---------------------------------------------------------------------------
# ImportError                               Traceback (most recent call last)
# Cell In[11], line 2
#       1 # from abstractions.dsl import instantiate, Rect
# ----> 2 from abstractions.primitives import show_boxes
#       3 from abstractions.toy_data import random_squares
#
# ImportError: cannot import name 'show_boxes' from 'abstractions.primitives' (/Users/amogh/Projects/AbstractionDiscovery/src/abstractions/primitives/__init__.py)

# %%
shapes = random_squares(1)
boxes = shapes[0].get_box_list()
print(len(boxes))
show_boxes(boxes)
# Out:
# 4

# %%
tokens = [Rect, float, float]
params = [0.5, 0.7]
shape = instantiate(tokens, params)

print(shape.s_x)
print(shape.s_y)
show_boxes(shape.get_box_list())
print(tokens)
print(params)
# Out:
# 0.5
# 0.7
# [<class 'abstractions.dsl.Rect'>, <class 'float'>, <class 'float'>]
# [0.5, 0.7]
