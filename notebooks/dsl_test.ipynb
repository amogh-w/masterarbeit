# %%
import sys
import os

# Add the src directory to sys.path
sys.path.append(os.path.abspath("../src"))

# %%
from abstractions.primitives.shapes import Box

# %%
from abstractions.dsl.instantiation import instantiate
from abstractions.dsl.nodes import Rect
from abstractions.primitives.visualization import show_boxes
from abstractions.data.toy import random_squares

# %%
shapes = random_squares(1)
boxes = shapes[0].get_box_list()
print(len(boxes))
show_boxes(boxes)
# Out:
# 4

# %%
tokens = [Rect, float, float]
params = [0.5, 0.7]
shape = instantiate(tokens, params)

print(shape.s_x)
print(shape.s_y)
show_boxes(shape.get_box_list())
print(tokens)
print(params)
# Out:
# 0.5
# 0.7
# [<class 'abstractions.dsl.nodes.Rect'>, <class 'float'>, <class 'float'>]
# [0.5, 0.7]
