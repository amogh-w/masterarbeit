# %%
import sys
import os
sys.path.append(os.path.abspath("../src"))

# %%
DEBUG = True

from termcolor import cprint

def debug_info(*args):
    """Prints a yellow 'INFO' message if DEBUG is True."""
    if DEBUG:
        cprint(f"[INFO] {' '.join(map(str, args))}", "yellow")

def debug_error(*args):
    """Prints a red 'ERROR' message if DEBUG is True."""
    if DEBUG:
        cprint(f"[ERROR] {' '.join(map(str, args))}", "red")

def debug_success(*args):
    """Prints a green 'SUCCESS' message if DEBUG is True."""
    if DEBUG:
        cprint(f"[SUCCESS] {' '.join(map(str, args))}", "green")

# %%
from pathlib import Path

def get_dataset_directory():
    current_path = Path.cwd()
    base_project_dir = current_path.parent
    dataset_directory = base_project_dir / "src" / "abstractionssymh" / "dataset"

    debug_info("Current notebook location:", current_path)
    debug_info("Base project directory:", base_project_dir)
    debug_info("Target dataset directory:", dataset_directory)

    return dataset_directory

dataset_directory = get_dataset_directory()
# Out:
# [INFO] Current notebook location: c:\Users\Amogh\abstraction-discovery\notebookssymh
# [INFO] Base project directory: c:\Users\Amogh\abstraction-discovery
# [INFO] Target dataset directory: c:\Users\Amogh\abstraction-discovery\src\abstractionssymh\dataset

# %%
import random
from abstractionssymh.data_loader import parse_json_to_dsl

def load_chair_dsl(chair_directory, use_random=False):
    json_files = sorted(chair_directory.glob("*.json"))
    if not json_files:
        debug_error("No JSON files found in:", chair_directory)
        return None

    file_path = random.choice(json_files) if use_random else json_files[0]
    debug_success("Loading chair file:", file_path)

    json_content = file_path.read_text(encoding="utf-8")
    dsl_object = parse_json_to_dsl(json_content)

    debug_success("Successfully parsed DSL object")
    debug_info(dsl_object)
    return dsl_object

chair_directory = dataset_directory / "Chair"
dsl_object = load_chair_dsl(chair_directory, use_random=False)
# Out:
# [SUCCESS] Loading chair file: c:\Users\Amogh\abstraction-discovery\src\abstractionssymh\dataset\Chair\Chair_1.json
# [SUCCESS] Successfully parsed DSL object
# [INFO] Union(
#     Union(
#         Translate(center=[0.003, 0.149, 0.072])
#             Rotate(quat=[0.0000, 0.0000, 0.0000, 1.0000])
#                 Scale(lengths=[0.891, 0.224, 0.806])
#                     Box(label=1),
#         Translate(center=[0.004, -0.422, 0.170])
#             Rotate(quat=[-0.3389, -0.0000, 0.0065, 0.9408])
#                 Scale(lengths=[0.898, 0.524, 1.154])
#                     Box(label=2)
#     ),
#     Translate(center=[0.030, 0.488, -0.315])
#         Rotate(quat=[-0.0821, -0.0071, -0.0494, 0.9954])
#             Scale(lengths=[0.892, 0.781, 0.305])
#                 Box(label=0)
# )

# %%
from abstractionssymh.plot_utils import plot_dsl_with_k3d

def plot_chair(dsl_obj):
    if dsl_obj is None:
        debug_error("No DSL object to plot.")
        return
    try:
        debug_info("Rendering DSL object with k3d...")
        plot_dsl_with_k3d(dsl_obj)
        debug_success("Plotting complete.")
    except Exception as e:
        debug_error("Failed to plot DSL object:", e)

plot_chair(dsl_object)
# Out:
# [INFO] Rendering DSL object with k3d...
# Expanding DSL tree for visualization...
# Found 3 total boxes after expansion.
# Output()
# [SUCCESS] Plotting complete.

# %%
from collections import defaultdict

def find_all_subtrees(node):
    """Recursively yields all subtrees (nodes) in a DSL object."""
    name, (params, children) = type(node).__name__, node.serialize()[1]
    for child in children:
        if hasattr(child, "serialize"):
            yield from find_all_subtrees(child)
    yield node

# %%
def collect_singleton_and_pair_data(dsl_shapes):
    """Collects singleton parameters and parent-child pair parameters."""
    if not dsl_shapes:
        debug_error("No DSL shapes provided for analysis.")
        return {}, {}

    s_data, p_data = defaultdict(list), defaultdict(list)

    for shape in dsl_shapes:
        for node in find_all_subtrees(shape):
            name, (p_params, children) = type(node).__name__, node.serialize()[1]

            if p_params:
                s_data[name].append(p_params)

            for child in (c for c in children if hasattr(c, "serialize")):
                c_name, (c_params, _) = type(child).__name__, child.serialize()[1]
                combo_params = p_params + c_params
                if combo_params:
                    pair_sig = f"{name}({c_name})"
                    p_data[pair_sig].append(combo_params)

    debug_success("Collected keys:",
                  f"{s_data.keys()} singletons, {p_data.keys()} pairs")
    debug_success("Collected parameters:",
                  f"{len(s_data)} singletons, {len(p_data)} pairs")
    return dict(sorted(s_data.items())), dict(sorted(p_data.items()))

# %%
import torch
import torch.nn as nn
from torch.utils.data import DataLoader, TensorDataset
from torch.optim import AdamW
from abstractionssymh.dsl_nodes import Box, Scale, Rotate, Translate, Union, SymRef, SymRot, SymTrans

device = torch.device("cuda" if torch.cuda.is_available() else "cpu")

# %%
device
# Out:
# device(type='cuda')

# %%
def t(tensor):
    return tensor.to(device)

# %%
class Autoencoder(nn.Module):
    """Simple fully-connected autoencoder with configurable hidden dim."""
    def __init__(self, input_dim: int, hidden_dim: int):
        super().__init__()
        debug_info(f"Initializing Autoencoder: input_dim={input_dim}, hidden_dim={hidden_dim}")

        self.encoder = nn.Sequential(
            nn.Linear(input_dim, 32), nn.ReLU(),
            nn.Linear(32, 16), nn.ReLU(),
            nn.Linear(16, hidden_dim)
        )
        self.decoder = nn.Sequential(
            nn.Linear(hidden_dim, 16), nn.ReLU(),
            nn.Linear(16, 32), nn.ReLU(),
            nn.Linear(32, input_dim)
        )

        debug_success("Autoencoder initialized successfully.")

    def forward(self, x):
        # debug_info(f"Forward pass: input shape={tuple(x.shape)}")
        latent = self.encoder(x)
        # debug_info(f"Encoded latent shape={tuple(latent.shape)}")
        decoded = self.decoder(latent)
        # debug_info(f"Decoded output shape={tuple(decoded.shape)}")
        return latent, decoded

# %%
def instantiate_pattern(pattern_name, params, children):
    """
    Rebuilds a DSL sub-tree from its pattern name, parameters, and preserved children.
    Handles both SINGLETON and PAIR patterns.
    """
    debug_info(f"[INSTANTIATE] Pattern: '{pattern_name}' | params={params[:10]}{'...' if len(params)>10 else ''} | #children={len(children)}")

    # Registry defining parent parameter lengths for known PAIRS
    param_split = {
        'Scale(Box)': 3, 'Rotate(Scale)': 4, 'Translate(Rotate)': 3,
        'Union(Translate)': 0, 'Union(SymRef)': 0, 'Union(SymRot)': 0, 'Union(SymTrans)': 0,
        'SymRef(Union)': 6, 'SymRef(Translate)': 6, 'SymRot(Union)': 6,
        'SymRot(Translate)': 6, 'SymTrans(Translate)': 3
    }

    # --- SINGLETON RECONSTRUCTION ---
    if pattern_name in ['Scale', 'Rotate', 'Translate', 'SymRef', 'SymRot', 'SymTrans']:
        NodeClass = globals()[pattern_name]
        child_node = children[0] if children else Box(-1)

        if NodeClass == SymRef:
            debug_info(f"  [SINGLETON] SymRef with params length {len(params)}")
            return SymRef(child_node, plane_normal=params[:3], point_on_plane=params[3:])
        if NodeClass == SymRot:
            debug_info(f"  [SINGLETON] SymRot with params length {len(params)}")
            return SymRot(child_node, axis=params[:3], center=params[3:], n_fold=-1)
        if NodeClass == SymTrans:
            debug_info(f"  [SINGLETON] SymTrans with params length {len(params)}")
            return SymTrans(child_node, end_point=params, n_fold=-1)

        return NodeClass(child_node, params)

    # --- PAIR RECONSTRUCTION ---
    elif pattern_name in param_split:
        p_len = param_split[pattern_name]
        p_params, c_params = params[:p_len], params[p_len:]
        parent_name, child_name = pattern_name.split('(')[0], pattern_name.split('(')[1][:-1]
        ParentClass, ChildClass = globals()[parent_name], globals()[child_name]

        # --- Build child node ---
        grandchild_node = children[0] if children else Box(-1)
        if ChildClass == Box:
            child_node = Box(-1)
        elif ChildClass == Union:
            if len(children) >= 2:
                child_node = Union(children[0], children[1])
            else:
                debug_error(f"  [PAIR] Unexpected children for Union in {pattern_name}")
                child_node = Box(-1)
        elif ChildClass == SymRef:
            child_node = SymRef(grandchild_node, plane_normal=c_params[:3], point_on_plane=c_params[3:])
        elif ChildClass == SymRot:
            child_node = SymRot(grandchild_node, axis=c_params[:3], center=c_params[3:], n_fold=-1)
        elif ChildClass == SymTrans:
            child_node = SymTrans(grandchild_node, end_point=c_params, n_fold=-1)
        else:
            child_node = ChildClass(grandchild_node, c_params)

        # --- Build parent node ---
        if ParentClass == Union:
            if len(children) >= 2:
                return Union(child_node, children[1])
            else:
                debug_error(f"  [PAIR] Union parent with missing second child in {pattern_name}")
                return Box(-1)
        elif ParentClass == SymRef:
            return SymRef(child_node, plane_normal=p_params[:3], point_on_plane=p_params[3:])
        elif ParentClass == SymRot:
            return SymRot(child_node, axis=p_params[:3], center=p_params[3:], n_fold=-1)
        elif ParentClass == SymTrans:
            return SymTrans(child_node, end_point=p_params, n_fold=-1)
        else:
            return ParentClass(child_node, p_params)

    debug_error(f"[UNKNOWN PATTERN] '{pattern_name}', defaulting to Box(-1)")
    return Box(-1)

# %%
import textwrap


class Abstraction:
    def __init__(self, pattern_name, compressed_params, model, children=None):
        self.pattern_name, self.compressed_params, self.model = pattern_name, compressed_params, model
        self.children = children if children is not None else []
    
    def __str__(self):
        # Create the header for the Abstraction node
        header = f"Abs({self.pattern_name}, dim={len(self.compressed_params)})"
        
        # If the abstraction has preserved children, indent and print them
        if not self.children:
            return header
        else:
            # Indent each child's own string representation
            child_strs = [textwrap.indent(str(c), '    ') for c in self.children]
            # Join the indented child strings
            return f"{header}(\n" + ",\n".join(child_strs) + "\n)"

    __repr__ = __str__  # makes debugging in lists/dicts nicer

    def expand(self):
        """Reconstructs the full DSL node from compressed parameters."""
        debug_info(f"Expanding abstraction: {self}")

        if not self.compressed_params:
            debug_error("No compressed params found. Returning Box(-1).")
            return Box(-1)  # fallback if params are missing

        self.model.eval()
        with torch.no_grad():
            params_tensor = t(torch.tensor(
                self.compressed_params, dtype=torch.float32
            )).unsqueeze(0)
            debug_info(f"Compressed params tensor shape: {tuple(params_tensor.shape)}")
            reconstructed_params = self.model.decoder(params_tensor).squeeze().tolist()
            debug_success(f"Reconstructed params: {reconstructed_params}")

        rebuilt_node = instantiate_pattern(self.pattern_name, reconstructed_params, self.children)
        debug_success(f"Successfully rebuilt node: {rebuilt_node}")
        return rebuilt_node.expand()

# %%
def prepare_autoencoder_train_data(parameters, mask, batch_size=64):
    """Creates a DataLoader from parameters and a boolean mask."""
    debug_info(f"Preparing DataLoader: batch_size={batch_size}, mask sum={mask.sum().item()}")
    tensor = t(torch.tensor(parameters, dtype=torch.float32))
    if mask.shape[0] != tensor.shape[0]:
        debug_error(f"Mask size {mask.shape[0]} does not match data size {tensor.shape[0]}")
        raise ValueError(f"Mask size {mask.shape[0]} != data size {tensor.shape[0]}")
    dataloader = DataLoader(TensorDataset(tensor[mask]), batch_size=batch_size, shuffle=True)
    debug_success("DataLoader prepared successfully.")
    return dataloader

# %%
def is_well_explained(model, parameters_tensor, error_threshold):
    """Checks if parameters are well reconstructed by the autoencoder."""
    model.eval()
    with torch.no_grad():
        _, reconstructions = model(parameters_tensor)
        error, _ = torch.max(torch.abs(reconstructions - parameters_tensor), dim=-1)
    debug_info(f"Max reconstruction error per sample: {error}")
    well_explained = error < error_threshold
    debug_info(f"Number of well-explained examples: {well_explained.sum().item()}/{len(well_explained)}")
    return well_explained

# %%
def train_autoencoder(model, dataloader, epochs=50, lr=1e-3):
    """Trains an autoencoder on the given DataLoader."""
    debug_info(f"Training autoencoder for {epochs} epochs, learning rate={lr}")
    optimizer = AdamW(model.parameters(), lr=lr)
    loss_fn = nn.MSELoss()
    model.train()

    for epoch in range(epochs):
        epoch_loss = 0.0
        for batch in dataloader:
            x = batch[0].to(device)
            optimizer.zero_grad()
            _, x_rec = model(x)
            loss = loss_fn(x_rec, x)
            loss.backward()
            optimizer.step()
            epoch_loss += loss.item() * x.size(0)
        debug_info(f"Epoch {epoch+1}/{epochs} - Average loss: {epoch_loss / len(dataloader.dataset):.6f}")

    debug_success("Autoencoder training complete.")
    return model

# %%
def find_abstractions(
    structures,
    structure_type="PATTERNS",
    min_examples=100,
    retrain_iterations=3,
    error_threshold=0.05,
    epochs=50,
):
    """Trains autoencoders for each structure type and returns models."""
    trained_models = {}
    sorted_structures = sorted(structures.items(), key=lambda item: len(item[1]), reverse=True)

    debug_info(f"Finding abstractions for {len(sorted_structures)} structures of type {structure_type}")

    for name, parameters in sorted_structures:
        if len(parameters) < min_examples:
            debug_info(f"Skipping {name} (only {len(parameters)} examples)")
            continue

        num_params = len(parameters[0])
        if num_params <= 1:
            debug_info(f"Skipping {name} (too few params: {num_params})")
            continue

        debug_success(f"Training model for {name} with {len(parameters)} samples, {num_params} params")
        params_tensor = t(torch.tensor(parameters, dtype=torch.float32))
        mask = torch.ones(len(parameters), dtype=torch.bool)

        for iteration in range(retrain_iterations):
            if not mask.any():
                debug_info(f"All {name} examples filtered out at iteration {iteration}")
                break

            debug_info(f"Iteration {iteration+1}/{retrain_iterations} for {name}")
            dataloader = prepare_autoencoder_train_data(parameters, mask=mask)
            model = Autoencoder(num_params, max(1, num_params - 1)).to(device)
            model = train_autoencoder(model, dataloader, epochs=epochs)

            mask = is_well_explained(model, params_tensor, error_threshold)

        trained_models[name] = model
        debug_success(f"Model training finished for {name}. Total well-explained examples: {mask.sum().item()}/{len(parameters)}")

    debug_success(f"Finished training {len(trained_models)} {structure_type}")
    return trained_models

# %%
def integrate_abstractions(node, singleton_models, pair_models, error_threshold, depth=0):
    indent = "  " * depth

    if isinstance(node, Abstraction):
        debug_info(f"{indent}[Abstraction] Node already abstracted: {node.pattern_name}")
        return node

    # 1. Recurse to children first
    _, (_, children) = node.serialize()
    rebuilt_children = [
        integrate_abstractions(c, singleton_models, pair_models, error_threshold, depth+1)
        if hasattr(c, 'serialize') else c
        for c in children
    ]

    # 2. Rebuild current node
    try:
        if isinstance(node, Union):
            current_node = Union(rebuilt_children[0], rebuilt_children[1])
        elif isinstance(node, SymRef):
            current_node = SymRef(rebuilt_children[0], plane_normal=node.plane, point_on_plane=node.point_on_plane)
        elif isinstance(node, SymRot):
            current_node = SymRot(rebuilt_children[0], axis=node.axis, center=node.center, n_fold=node.n)
        elif isinstance(node, SymTrans):
            current_node = SymTrans(rebuilt_children[0], end_point=node.end_point, n_fold=node.n)
        elif hasattr(node, 'child'):
            kwargs = {k:v for k,v in node.__dict__.items() if k != 'child'}
            current_node = type(node)(rebuilt_children[0], **kwargs)
        else:
            current_node = type(node)(*rebuilt_children)
        debug_info(f"{indent}[Rebuilt] {type(current_node).__name__} with {len(rebuilt_children)} children")
    except Exception as e:
        debug_error(f"{indent}[Rebuild FAILED] {type(node).__name__} at depth {depth}: {e}")
        return node

    # 3. Try pair abstraction
    child_nodes = [c for c in rebuilt_children if hasattr(c, 'serialize')]
    if len(child_nodes) == 1:
        child_node = child_nodes[0]
        if not isinstance(child_node, Abstraction):
            pair_sig = f"{type(current_node).__name__}({type(child_node).__name__})"
            if pair_sig in pair_models:
                model, (p_params, _), (c_params, c_children) = pair_models[pair_sig], current_node.serialize()[1], child_node.serialize()[1]
                if p_params + c_params:
                    combined = t(torch.tensor(p_params + c_params, dtype=torch.float32)).unsqueeze(0)
                    _, reconstruction = model(combined)
                    error = torch.max(torch.abs(reconstruction - combined)).item()
                    debug_info(f"{indent}[PAIR CHECK] {pair_sig}, error={error:.4f}")
                    if error < error_threshold:
                        encoding, _ = model(combined)
                        grandchildren = [c for c in c_children if hasattr(c, 'serialize')]
                        debug_success(f"{indent}[PAIR ABSTRACTION CREATED] {pair_sig}")
                        return Abstraction(pair_sig, encoding.squeeze().tolist(), model, children=grandchildren)

    # 4. Try singleton abstraction
    name = type(current_node).__name__
    if name in singleton_models:
        model, (p_params, _) = singleton_models[name], current_node.serialize()[1]
        if p_params:
            params_tensor = t(torch.tensor(p_params, dtype=torch.float32)).unsqueeze(0)
            _, reconstruction = model(params_tensor)
            error = torch.max(torch.abs(reconstruction - params_tensor)).item()
            debug_info(f"{indent}[SINGLETON CHECK] {name}, error={error:.4f}")
            if error < error_threshold:
                encoding, _ = model(params_tensor)
                debug_success(f"{indent}[SINGLETON ABSTRACTION CREATED] {name}")
                return Abstraction(name, encoding.squeeze().tolist(), model, children=child_nodes)

    # 5. No abstraction, return rebuilt node
    debug_info(f"{indent}[RETURN NODE] {type(current_node).__name__}")
    return current_node

# %%
# Load DSL shapes

chair_directory = dataset_directory / "Chair"
json_files = sorted(list(chair_directory.glob("*.json")))

try:
    debug_info("Starting to load DSL shapes from JSON files...")
    all_dsl_shapes = [parse_json_to_dsl(Path(f).read_text()) for f in json_files[:1000]]
    debug_success(f"Loaded {len(all_dsl_shapes)} shapes from dataset.")
except Exception as e:
    debug_error("Failed to load DSL shapes:", e)
    all_dsl_shapes = []

# Collect parameters
if all_dsl_shapes:
    debug_info("Collecting singleton and pair parameters from loaded shapes...")
    singleton_params, pair_params = collect_singleton_and_pair_data(all_dsl_shapes)

    num_singleton = sum(len(v) for v in singleton_params.values())
    num_pair = sum(len(v) for v in pair_params.values())
    debug_success(f"Collected {num_singleton} singleton and {num_pair} pair parameter sets.")

    # Report top structures by count
    # top_singletons = sorted(singleton_params.items(), key=lambda x: len(x[1]), reverse=True)[:5]
    # top_pairs = sorted(pair_params.items(), key=lambda x: len(x[1]), reverse=True)[:5]
    # debug_info("Top singleton structures by example count:", top_singletons)
    # debug_info("Top pair structures by example count:", top_pairs)

    # Train singleton models
    debug_info("Starting singleton model training...")
    singleton_models = find_abstractions(singleton_params, structure_type="SINGLETONS", min_examples=50, epochs=25)

    # Train pair models
    debug_info("Starting pair model training...")
    pair_models = find_abstractions(pair_params, structure_type="PAIRS", min_examples=50, epochs=25)

    debug_success(f"Training complete. {len(singleton_models)} singleton models and {len(pair_models)} pair models trained.")

else:
    debug_error("No DSL shapes available. Abstraction pipeline skipped.")
# Out:
# [INFO] Starting to load DSL shapes from JSON files...
# [SUCCESS] Loaded 1000 shapes from dataset.
# [INFO] Collecting singleton and pair parameters from loaded shapes...
# [SUCCESS] Collected keys: dict_keys(['Scale', 'Rotate', 'Translate', 'SymRef', 'SymRot', 'SymTrans']) singletons, dict_keys(['Scale(Box)', 'Rotate(Scale)', 'Translate(Rotate)', 'Union(Translate)', 'SymRef(Union)', 'Union(SymRef)', 'SymRef(Translate)', 'SymRot(Union)', 'Union(SymRot)', 'SymRot(Translate)', 'SymTrans(Translate)', 'Union(SymTrans)']) pairs
# [SUCCESS] Collected parameters: 6 singletons, 12 pairs
# [SUCCESS] Collected 21173 singleton and 28701 pair parameter sets.
# [INFO] Starting singleton model training...
# [INFO] Finding abstractions for 6 structures of type SINGLETONS
# [SUCCESS] Training model for Rotate with 6386 samples, 4 params
# [INFO] Iteration 1/3 for Rotate
# [INFO] Preparing DataLoader: batch_size=64, mask sum=6386
# [SUCCESS] DataLoader prepared successfully.
# [INFO] Initializing Autoencoder: input_dim=4, hidden_dim=3
# [SUCCESS] Autoencoder initialized successfully.
# [INFO] Training autoencoder for 25 epochs, learning rate=0.001
# [INFO] Epoch 1/25 - Average loss: 0.040297
# [INFO] Epoch 2/25 - Average loss: 0.002875
# [INFO] Epoch 3/25 - Average loss: 0.001598
# [INFO] Epoch 4/25 - Average loss: 0.000655
# [INFO] Epoch 5/25 - Average loss: 0.000488
# [INFO] Epoch 6/25 - Average loss: 0.000439
# [INFO] Epoch 7/25 - Average loss: 0.000421
# [INFO] Epoch 8/25 - Average loss: 0.000410
# [INFO] Epoch 9/25 - Average loss: 0.000401
# [INFO] Epoch 10/25 - Average loss: 0.000380
# [INFO] Epoch 11/25 - Average loss: 0.000222
# [INFO] Epoch 12/25 - Average loss: 0.000061
# [INFO] Epoch 13/25 - Average loss: 0.000036
# [INFO] Epoch 14/25 - Average loss: 0.000027
# [INFO] Epoch 15/25 - Average loss: 0.000022
# [INFO] Epoch 16/25 - Average loss: 0.000018
# [INFO] Epoch 17/25 - Average loss: 0.000015
# [INFO] Epoch 18/25 - Average loss: 0.000014
# [INFO] Epoch 19/25 - Average loss: 0.000012
# [INFO] Epoch 20/25 - Average loss: 0.000011
# [INFO] Epoch 21/25 - Average loss: 0.000010
# [INFO] Epoch 22/25 - Average loss: 0.000009
# [INFO] Epoch 23/25 - Average loss: 0.000008
# [INFO] Epoch 24/25 - Average loss: 0.000007
# [INFO] Epoch 25/25 - Average loss: 0.000006
# [SUCCESS] Autoencoder training complete.
# [INFO] Max reconstruction error per sample: tensor([0.0014, 0.0016, 0.0023,  ..., 0.0014, 0.0014, 0.0016], device='cuda:0')
# [INFO] Number of well-explained examples: 6384/6386
# [INFO] Iteration 2/3 for Rotate
# [INFO] Preparing DataLoader: batch_size=64, mask sum=6384
# [SUCCESS] DataLoader prepared successfully.
# [INFO] Initializing Autoencoder: input_dim=4, hidden_dim=3
# [SUCCESS] Autoencoder initialized successfully.
# [INFO] Training autoencoder for 25 epochs, learning rate=0.001
# [INFO] Epoch 1/25 - Average loss: 0.082602
# [INFO] Epoch 2/25 - Average loss: 0.003236
# [INFO] Epoch 3/25 - Average loss: 0.003200
# [INFO] Epoch 4/25 - Average loss: 0.003172
# [INFO] Epoch 5/25 - Average loss: 0.003119
# [INFO] Epoch 6/25 - Average loss: 0.002860
# [INFO] Epoch 7/25 - Average loss: 0.001833
# [INFO] Epoch 8/25 - Average loss: 0.001618
# [INFO] Epoch 9/25 - Average loss: 0.001561
# [INFO] Epoch 10/25 - Average loss: 0.001439
# [INFO] Epoch 11/25 - Average loss: 0.000997
# [INFO] Epoch 12/25 - Average loss: 0.000542
# [INFO] Epoch 13/25 - Average loss: 0.000321
# [INFO] Epoch 14/25 - Average loss: 0.000180
# [INFO] Epoch 15/25 - Average loss: 0.000091
# [INFO] Epoch 16/25 - Average loss: 0.000058
# [INFO] Epoch 17/25 - Average loss: 0.000049
# [INFO] Epoch 18/25 - Average loss: 0.000043
# [INFO] Epoch 19/25 - Average loss: 0.000038
# [INFO] Epoch 20/25 - Average loss: 0.000037
# [INFO] Epoch 21/25 - Average loss: 0.000036
# [INFO] Epoch 22/25 - Average loss: 0.000034
# [INFO] Epoch 23/25 - Average loss: 0.000031
# [INFO] Epoch 24/25 - Average loss: 0.000030
# [INFO] Epoch 25/25 - Average loss: 0.000029
# [SUCCESS] Autoencoder training complete.
# [INFO] Max reconstruction error per sample: tensor([0.0021, 0.0105, 0.0111,  ..., 0.0021, 0.0021, 0.0026], device='cuda:0')
# [INFO] Number of well-explained examples: 6352/6386
# [INFO] Iteration 3/3 for Rotate
# [INFO] Preparing DataLoader: batch_size=64, mask sum=6352
# [SUCCESS] DataLoader prepared successfully.
# [INFO] Initializing Autoencoder: input_dim=4, hidden_dim=3
# [SUCCESS] Autoencoder initialized successfully.
# [INFO] Training autoencoder for 25 epochs, learning rate=0.001
# [INFO] Epoch 1/25 - Average loss: 0.112369
# [INFO] Epoch 2/25 - Average loss: 0.003069
# [INFO] Epoch 3/25 - Average loss: 0.002489
# [INFO] Epoch 4/25 - Average loss: 0.001529
# [INFO] Epoch 5/25 - Average loss: 0.001410
# [INFO] Epoch 6/25 - Average loss: 0.001168
# [INFO] Epoch 7/25 - Average loss: 0.000708
# [INFO] Epoch 8/25 - Average loss: 0.000419
# [INFO] Epoch 9/25 - Average loss: 0.000375
# [INFO] Epoch 10/25 - Average loss: 0.000366
# [INFO] Epoch 11/25 - Average loss: 0.000365
# [INFO] Epoch 12/25 - Average loss: 0.000359
# [INFO] Epoch 13/25 - Average loss: 0.000356
# [INFO] Epoch 14/25 - Average loss: 0.000337
# [INFO] Epoch 15/25 - Average loss: 0.000315
# [INFO] Epoch 16/25 - Average loss: 0.000265
# [INFO] Epoch 17/25 - Average loss: 0.000149
# [INFO] Epoch 18/25 - Average loss: 0.000057
# [INFO] Epoch 19/25 - Average loss: 0.000041
# [INFO] Epoch 20/25 - Average loss: 0.000034
# [INFO] Epoch 21/25 - Average loss: 0.000028
# [INFO] Epoch 22/25 - Average loss: 0.000024
# [INFO] Epoch 23/25 - Average loss: 0.000021
# [INFO] Epoch 24/25 - Average loss: 0.000019
# [INFO] Epoch 25/25 - Average loss: 0.000016
# [SUCCESS] Autoencoder training complete.
# [INFO] Max reconstruction error per sample: tensor([0.0025, 0.0086, 0.0087,  ..., 0.0025, 0.0025, 0.0047], device='cuda:0')
# [INFO] Number of well-explained examples: 6350/6386
# [SUCCESS] Model training finished for Rotate. Total well-explained examples: 6350/6386
# [SUCCESS] Training model for Scale with 6386 samples, 3 params
# [INFO] Iteration 1/3 for Scale
# [INFO] Preparing DataLoader: batch_size=64, mask sum=6386
# [SUCCESS] DataLoader prepared successfully.
# [INFO] Initializing Autoencoder: input_dim=3, hidden_dim=2
# [SUCCESS] Autoencoder initialized successfully.
# [INFO] Training autoencoder for 25 epochs, learning rate=0.001
# [INFO] Epoch 1/25 - Average loss: 0.181508
# [INFO] Epoch 2/25 - Average loss: 0.058250
# [INFO] Epoch 3/25 - Average loss: 0.041768
# [INFO] Epoch 4/25 - Average loss: 0.021809
# [INFO] Epoch 5/25 - Average loss: 0.014442
# [INFO] Epoch 6/25 - Average loss: 0.010961
# [INFO] Epoch 7/25 - Average loss: 0.009396
# [INFO] Epoch 8/25 - Average loss: 0.008514
# [INFO] Epoch 9/25 - Average loss: 0.007956
# [INFO] Epoch 10/25 - Average loss: 0.007433
# [INFO] Epoch 11/25 - Average loss: 0.007126
# [INFO] Epoch 12/25 - Average loss: 0.006740
# [INFO] Epoch 13/25 - Average loss: 0.006399
# [INFO] Epoch 14/25 - Average loss: 0.006100
# [INFO] Epoch 15/25 - Average loss: 0.005985
# [INFO] Epoch 16/25 - Average loss: 0.005776
# [INFO] Epoch 17/25 - Average loss: 0.005723
# [INFO] Epoch 18/25 - Average loss: 0.005596
# [INFO] Epoch 19/25 - Average loss: 0.005488
# [INFO] Epoch 20/25 - Average loss: 0.005377
# [INFO] Epoch 21/25 - Average loss: 0.005341
# [INFO] Epoch 22/25 - Average loss: 0.005317
# [INFO] Epoch 23/25 - Average loss: 0.005183
# [INFO] Epoch 24/25 - Average loss: 0.005122
# [INFO] Epoch 25/25 - Average loss: 0.005117
# [SUCCESS] Autoencoder training complete.
# [INFO] Max reconstruction error per sample: tensor([0.0327, 0.1419, 0.0666,  ..., 0.0083, 0.0245, 0.0148], device='cuda:0')
# [INFO] Number of well-explained examples: 4107/6386
# [INFO] Iteration 2/3 for Scale
# [INFO] Preparing DataLoader: batch_size=64, mask sum=4107
# [SUCCESS] DataLoader prepared successfully.
# [INFO] Initializing Autoencoder: input_dim=3, hidden_dim=2
# [SUCCESS] Autoencoder initialized successfully.
# [INFO] Training autoencoder for 25 epochs, learning rate=0.001
# [INFO] Epoch 1/25 - Average loss: 0.150663
# [INFO] Epoch 2/25 - Average loss: 0.075248
# [INFO] Epoch 3/25 - Average loss: 0.038692
# [INFO] Epoch 4/25 - Average loss: 0.009335
# [INFO] Epoch 5/25 - Average loss: 0.003234
# [INFO] Epoch 6/25 - Average loss: 0.002293
# [INFO] Epoch 7/25 - Average loss: 0.001993
# [INFO] Epoch 8/25 - Average loss: 0.001776
# [INFO] Epoch 9/25 - Average loss: 0.001642
# [INFO] Epoch 10/25 - Average loss: 0.001503
# [INFO] Epoch 11/25 - Average loss: 0.001389
# [INFO] Epoch 12/25 - Average loss: 0.001277
# [INFO] Epoch 13/25 - Average loss: 0.001169
# [INFO] Epoch 14/25 - Average loss: 0.001129
# [INFO] Epoch 15/25 - Average loss: 0.001058
# [INFO] Epoch 16/25 - Average loss: 0.001006
# [INFO] Epoch 17/25 - Average loss: 0.000932
# [INFO] Epoch 18/25 - Average loss: 0.000900
# [INFO] Epoch 19/25 - Average loss: 0.000865
# [INFO] Epoch 20/25 - Average loss: 0.000830
# [INFO] Epoch 21/25 - Average loss: 0.000796
# [INFO] Epoch 22/25 - Average loss: 0.000786
# [INFO] Epoch 23/25 - Average loss: 0.000753
# [INFO] Epoch 24/25 - Average loss: 0.000724
# [INFO] Epoch 25/25 - Average loss: 0.000700
# [SUCCESS] Autoencoder training complete.
# [INFO] Max reconstruction error per sample: tensor([0.0232, 0.1482, 0.0844,  ..., 0.0106, 0.0187, 0.0152], device='cuda:0')
# [INFO] Number of well-explained examples: 4094/6386
# [INFO] Iteration 3/3 for Scale
# [INFO] Preparing DataLoader: batch_size=64, mask sum=4094
# [SUCCESS] DataLoader prepared successfully.
# [INFO] Initializing Autoencoder: input_dim=3, hidden_dim=2
# [SUCCESS] Autoencoder initialized successfully.
# [INFO] Training autoencoder for 25 epochs, learning rate=0.001
# [INFO] Epoch 1/25 - Average loss: 0.130536
# [INFO] Epoch 2/25 - Average loss: 0.066806
# [INFO] Epoch 3/25 - Average loss: 0.029042
# [INFO] Epoch 4/25 - Average loss: 0.008947
# [INFO] Epoch 5/25 - Average loss: 0.002687
# [INFO] Epoch 6/25 - Average loss: 0.001368
# [INFO] Epoch 7/25 - Average loss: 0.001040
# [INFO] Epoch 8/25 - Average loss: 0.000913
# [INFO] Epoch 9/25 - Average loss: 0.000815
# [INFO] Epoch 10/25 - Average loss: 0.000756
# [INFO] Epoch 11/25 - Average loss: 0.000719
# [INFO] Epoch 12/25 - Average loss: 0.000681
# [INFO] Epoch 13/25 - Average loss: 0.000646
# [INFO] Epoch 14/25 - Average loss: 0.000619
# [INFO] Epoch 15/25 - Average loss: 0.000610
# [INFO] Epoch 16/25 - Average loss: 0.000594
# [INFO] Epoch 17/25 - Average loss: 0.000598
# [INFO] Epoch 18/25 - Average loss: 0.000561
# [INFO] Epoch 19/25 - Average loss: 0.000546
# [INFO] Epoch 20/25 - Average loss: 0.000537
# [INFO] Epoch 21/25 - Average loss: 0.000534
# [INFO] Epoch 22/25 - Average loss: 0.000515
# [INFO] Epoch 23/25 - Average loss: 0.000505
# [INFO] Epoch 24/25 - Average loss: 0.000494
# [INFO] Epoch 25/25 - Average loss: 0.000504
# [SUCCESS] Autoencoder training complete.
# [INFO] Max reconstruction error per sample: tensor([0.0222, 0.2863, 0.1097,  ..., 0.0291, 0.0310, 0.0316], device='cuda:0')
# [INFO] Number of well-explained examples: 3973/6386
# [SUCCESS] Model training finished for Scale. Total well-explained examples: 3973/6386
# [SUCCESS] Training model for Translate with 6386 samples, 3 params
# [INFO] Iteration 1/3 for Translate
# [INFO] Preparing DataLoader: batch_size=64, mask sum=6386
# [SUCCESS] DataLoader prepared successfully.
# [INFO] Initializing Autoencoder: input_dim=3, hidden_dim=2
# [SUCCESS] Autoencoder initialized successfully.
# [INFO] Training autoencoder for 25 epochs, learning rate=0.001
# [INFO] Epoch 1/25 - Average loss: 0.084878
# [INFO] Epoch 2/25 - Average loss: 0.039559
# [INFO] Epoch 3/25 - Average loss: 0.024494
# [INFO] Epoch 4/25 - Average loss: 0.015129
# [INFO] Epoch 5/25 - Average loss: 0.010205
# [INFO] Epoch 6/25 - Average loss: 0.008430
# [INFO] Epoch 7/25 - Average loss: 0.007879
# [INFO] Epoch 8/25 - Average loss: 0.007598
# [INFO] Epoch 9/25 - Average loss: 0.007241
# [INFO] Epoch 10/25 - Average loss: 0.007077
# [INFO] Epoch 11/25 - Average loss: 0.006854
# [INFO] Epoch 12/25 - Average loss: 0.006645
# [INFO] Epoch 13/25 - Average loss: 0.006513
# [INFO] Epoch 14/25 - Average loss: 0.006303
# [INFO] Epoch 15/25 - Average loss: 0.006165
# [INFO] Epoch 16/25 - Average loss: 0.005974
# [INFO] Epoch 17/25 - Average loss: 0.005843
# [INFO] Epoch 18/25 - Average loss: 0.005629
# [INFO] Epoch 19/25 - Average loss: 0.005419
# [INFO] Epoch 20/25 - Average loss: 0.005266
# [INFO] Epoch 21/25 - Average loss: 0.005140
# [INFO] Epoch 22/25 - Average loss: 0.004936
# [INFO] Epoch 23/25 - Average loss: 0.004682
# [INFO] Epoch 24/25 - Average loss: 0.004533
# [INFO] Epoch 25/25 - Average loss: 0.004417
# [SUCCESS] Autoencoder training complete.
# [INFO] Max reconstruction error per sample: tensor([0.0773, 0.0673, 0.0427,  ..., 0.0168, 0.0201, 0.0076], device='cuda:0')
# [INFO] Number of well-explained examples: 3491/6386
# [INFO] Iteration 2/3 for Translate
# [INFO] Preparing DataLoader: batch_size=64, mask sum=3491
# [SUCCESS] DataLoader prepared successfully.
# [INFO] Initializing Autoencoder: input_dim=3, hidden_dim=2
# [SUCCESS] Autoencoder initialized successfully.
# [INFO] Training autoencoder for 25 epochs, learning rate=0.001
# [INFO] Epoch 1/25 - Average loss: 0.092171
# [INFO] Epoch 2/25 - Average loss: 0.046494
# [INFO] Epoch 3/25 - Average loss: 0.026024
# [INFO] Epoch 4/25 - Average loss: 0.023644
# [INFO] Epoch 5/25 - Average loss: 0.022062
# [INFO] Epoch 6/25 - Average loss: 0.017495
# [INFO] Epoch 7/25 - Average loss: 0.011034
# [INFO] Epoch 8/25 - Average loss: 0.009533
# [INFO] Epoch 9/25 - Average loss: 0.008651
# [INFO] Epoch 10/25 - Average loss: 0.007363
# [INFO] Epoch 11/25 - Average loss: 0.005803
# [INFO] Epoch 12/25 - Average loss: 0.003747
# [INFO] Epoch 13/25 - Average loss: 0.002285
# [INFO] Epoch 14/25 - Average loss: 0.001674
# [INFO] Epoch 15/25 - Average loss: 0.001321
# [INFO] Epoch 16/25 - Average loss: 0.001152
# [INFO] Epoch 17/25 - Average loss: 0.001044
# [INFO] Epoch 18/25 - Average loss: 0.000968
# [INFO] Epoch 19/25 - Average loss: 0.000896
# [INFO] Epoch 20/25 - Average loss: 0.000804
# [INFO] Epoch 21/25 - Average loss: 0.000762
# [INFO] Epoch 22/25 - Average loss: 0.000689
# [INFO] Epoch 23/25 - Average loss: 0.000659
# [INFO] Epoch 24/25 - Average loss: 0.000625
# [INFO] Epoch 25/25 - Average loss: 0.000611
# [SUCCESS] Autoencoder training complete.
# [INFO] Max reconstruction error per sample: tensor([0.0637, 0.0826, 0.0441,  ..., 0.0314, 0.0315, 0.0072], device='cuda:0')
# [INFO] Number of well-explained examples: 3236/6386
# [INFO] Iteration 3/3 for Translate
# [INFO] Preparing DataLoader: batch_size=64, mask sum=3236
# [SUCCESS] DataLoader prepared successfully.
# [INFO] Initializing Autoencoder: input_dim=3, hidden_dim=2
# [SUCCESS] Autoencoder initialized successfully.
# [INFO] Training autoencoder for 25 epochs, learning rate=0.001
# [INFO] Epoch 1/25 - Average loss: 0.086222
# [INFO] Epoch 2/25 - Average loss: 0.072579
# [INFO] Epoch 3/25 - Average loss: 0.027646
# [INFO] Epoch 4/25 - Average loss: 0.018383
# [INFO] Epoch 5/25 - Average loss: 0.011296
# [INFO] Epoch 6/25 - Average loss: 0.006921
# [INFO] Epoch 7/25 - Average loss: 0.003957
# [INFO] Epoch 8/25 - Average loss: 0.002262
# [INFO] Epoch 9/25 - Average loss: 0.001678
# [INFO] Epoch 10/25 - Average loss: 0.001374
# [INFO] Epoch 11/25 - Average loss: 0.001190
# [INFO] Epoch 12/25 - Average loss: 0.001056
# [INFO] Epoch 13/25 - Average loss: 0.000990
# [INFO] Epoch 14/25 - Average loss: 0.000916
# [INFO] Epoch 15/25 - Average loss: 0.000862
# [INFO] Epoch 16/25 - Average loss: 0.000828
# [INFO] Epoch 17/25 - Average loss: 0.000809
# [INFO] Epoch 18/25 - Average loss: 0.000774
# [INFO] Epoch 19/25 - Average loss: 0.000751
# [INFO] Epoch 20/25 - Average loss: 0.000728
# [INFO] Epoch 21/25 - Average loss: 0.000706
# [INFO] Epoch 22/25 - Average loss: 0.000690
# [INFO] Epoch 23/25 - Average loss: 0.000666
# [INFO] Epoch 24/25 - Average loss: 0.000662
# [INFO] Epoch 25/25 - Average loss: 0.000641
# [SUCCESS] Autoencoder training complete.
# [INFO] Max reconstruction error per sample: tensor([0.1429, 0.1276, 0.0694,  ..., 0.0169, 0.0226, 0.0241], device='cuda:0')
# [INFO] Number of well-explained examples: 3012/6386
# [SUCCESS] Model training finished for Translate. Total well-explained examples: 3012/6386
# [SUCCESS] Training model for SymRef with 1950 samples, 6 params
# [INFO] Iteration 1/3 for SymRef
# [INFO] Preparing DataLoader: batch_size=64, mask sum=1950
# [SUCCESS] DataLoader prepared successfully.
# [INFO] Initializing Autoencoder: input_dim=6, hidden_dim=5
# [SUCCESS] Autoencoder initialized successfully.
# [INFO] Training autoencoder for 25 epochs, learning rate=0.001
# [INFO] Epoch 1/25 - Average loss: 0.177057
# [INFO] Epoch 2/25 - Average loss: 0.081872
# [INFO] Epoch 3/25 - Average loss: 0.055182
# [INFO] Epoch 4/25 - Average loss: 0.047068
# [INFO] Epoch 5/25 - Average loss: 0.031619
# [INFO] Epoch 6/25 - Average loss: 0.013567
# [INFO] Epoch 7/25 - Average loss: 0.006042
# [INFO] Epoch 8/25 - Average loss: 0.002541
# [INFO] Epoch 9/25 - Average loss: 0.001434
# [INFO] Epoch 10/25 - Average loss: 0.001192
# [INFO] Epoch 11/25 - Average loss: 0.001099
# [INFO] Epoch 12/25 - Average loss: 0.001058
# [INFO] Epoch 13/25 - Average loss: 0.001018
# [INFO] Epoch 14/25 - Average loss: 0.000981
# [INFO] Epoch 15/25 - Average loss: 0.000974
# [INFO] Epoch 16/25 - Average loss: 0.000942
# [INFO] Epoch 17/25 - Average loss: 0.000932
# [INFO] Epoch 18/25 - Average loss: 0.000911
# [INFO] Epoch 19/25 - Average loss: 0.000897
# [INFO] Epoch 20/25 - Average loss: 0.000897
# [INFO] Epoch 21/25 - Average loss: 0.000873
# [INFO] Epoch 22/25 - Average loss: 0.000865
# [INFO] Epoch 23/25 - Average loss: 0.000853
# [INFO] Epoch 24/25 - Average loss: 0.000846
# [INFO] Epoch 25/25 - Average loss: 0.000843
# [SUCCESS] Autoencoder training complete.
# [INFO] Max reconstruction error per sample: tensor([0.0112, 0.0102, 0.0068,  ..., 0.0072, 0.0206, 0.0446], device='cuda:0')
# [INFO] Number of well-explained examples: 1772/1950
# [INFO] Iteration 2/3 for SymRef
# [INFO] Preparing DataLoader: batch_size=64, mask sum=1772
# [SUCCESS] DataLoader prepared successfully.
# [INFO] Initializing Autoencoder: input_dim=6, hidden_dim=5
# [SUCCESS] Autoencoder initialized successfully.
# [INFO] Training autoencoder for 25 epochs, learning rate=0.001
# [INFO] Epoch 1/25 - Average loss: 0.129977
# [INFO] Epoch 2/25 - Average loss: 0.065914
# [INFO] Epoch 3/25 - Average loss: 0.043317
# [INFO] Epoch 4/25 - Average loss: 0.039988
# [INFO] Epoch 5/25 - Average loss: 0.032753
# [INFO] Epoch 6/25 - Average loss: 0.023842
# [INFO] Epoch 7/25 - Average loss: 0.020452
# [INFO] Epoch 8/25 - Average loss: 0.017097
# [INFO] Epoch 9/25 - Average loss: 0.009285
# [INFO] Epoch 10/25 - Average loss: 0.002725
# [INFO] Epoch 11/25 - Average loss: 0.001526
# [INFO] Epoch 12/25 - Average loss: 0.001233
# [INFO] Epoch 13/25 - Average loss: 0.001112
# [INFO] Epoch 14/25 - Average loss: 0.001039
# [INFO] Epoch 15/25 - Average loss: 0.000976
# [INFO] Epoch 16/25 - Average loss: 0.000922
# [INFO] Epoch 17/25 - Average loss: 0.000862
# [INFO] Epoch 18/25 - Average loss: 0.000808
# [INFO] Epoch 19/25 - Average loss: 0.000761
# [INFO] Epoch 20/25 - Average loss: 0.000716
# [INFO] Epoch 21/25 - Average loss: 0.000679
# [INFO] Epoch 22/25 - Average loss: 0.000615
# [INFO] Epoch 23/25 - Average loss: 0.000565
# [INFO] Epoch 24/25 - Average loss: 0.000518
# [INFO] Epoch 25/25 - Average loss: 0.000464
# [SUCCESS] Autoencoder training complete.
# [INFO] Max reconstruction error per sample: tensor([0.0155, 0.0097, 0.0049,  ..., 0.0058, 0.0126, 0.0479], device='cuda:0')
# [INFO] Number of well-explained examples: 1751/1950
# [INFO] Iteration 3/3 for SymRef
# [INFO] Preparing DataLoader: batch_size=64, mask sum=1751
# [SUCCESS] DataLoader prepared successfully.
# [INFO] Initializing Autoencoder: input_dim=6, hidden_dim=5
# [SUCCESS] Autoencoder initialized successfully.
# [INFO] Training autoencoder for 25 epochs, learning rate=0.001
# [INFO] Epoch 1/25 - Average loss: 0.156723
# [INFO] Epoch 2/25 - Average loss: 0.075174
# [INFO] Epoch 3/25 - Average loss: 0.041099
# [INFO] Epoch 4/25 - Average loss: 0.038047
# [INFO] Epoch 5/25 - Average loss: 0.033700
# [INFO] Epoch 6/25 - Average loss: 0.025326
# [INFO] Epoch 7/25 - Average loss: 0.016805
# [INFO] Epoch 8/25 - Average loss: 0.013743
# [INFO] Epoch 9/25 - Average loss: 0.012313
# [INFO] Epoch 10/25 - Average loss: 0.009717
# [INFO] Epoch 11/25 - Average loss: 0.004129
# [INFO] Epoch 12/25 - Average loss: 0.000494
# [INFO] Epoch 13/25 - Average loss: 0.000188
# [INFO] Epoch 14/25 - Average loss: 0.000146
# [INFO] Epoch 15/25 - Average loss: 0.000126
# [INFO] Epoch 16/25 - Average loss: 0.000113
# [INFO] Epoch 17/25 - Average loss: 0.000105
# [INFO] Epoch 18/25 - Average loss: 0.000098
# [INFO] Epoch 19/25 - Average loss: 0.000095
# [INFO] Epoch 20/25 - Average loss: 0.000089
# [INFO] Epoch 21/25 - Average loss: 0.000086
# [INFO] Epoch 22/25 - Average loss: 0.000086
# [INFO] Epoch 23/25 - Average loss: 0.000079
# [INFO] Epoch 24/25 - Average loss: 0.000076
# [INFO] Epoch 25/25 - Average loss: 0.000074
# [SUCCESS] Autoencoder training complete.
# [INFO] Max reconstruction error per sample: tensor([0.0164, 0.0091, 0.0042,  ..., 0.0055, 0.0156, 0.0482], device='cuda:0')
# [INFO] Number of well-explained examples: 1743/1950
# [SUCCESS] Model training finished for SymRef. Total well-explained examples: 1743/1950
# [INFO] Skipping SymTrans (only 42 examples)
# [INFO] Skipping SymRot (only 23 examples)
# [SUCCESS] Finished training 4 SINGLETONS
# [INFO] Starting pair model training...
# [INFO] Finding abstractions for 12 structures of type PAIRS
# [SUCCESS] Training model for Rotate(Scale) with 6386 samples, 7 params
# [INFO] Iteration 1/3 for Rotate(Scale)
# [INFO] Preparing DataLoader: batch_size=64, mask sum=6386
# [SUCCESS] DataLoader prepared successfully.
# [INFO] Initializing Autoencoder: input_dim=7, hidden_dim=6
# [SUCCESS] Autoencoder initialized successfully.
# [INFO] Training autoencoder for 25 epochs, learning rate=0.001
# [INFO] Epoch 1/25 - Average loss: 0.094499
# [INFO] Epoch 2/25 - Average loss: 0.025448
# [INFO] Epoch 3/25 - Average loss: 0.009280
# [INFO] Epoch 4/25 - Average loss: 0.003020
# [INFO] Epoch 5/25 - Average loss: 0.001879
# [INFO] Epoch 6/25 - Average loss: 0.001827
# [INFO] Epoch 7/25 - Average loss: 0.001799
# [INFO] Epoch 8/25 - Average loss: 0.001760
# [INFO] Epoch 9/25 - Average loss: 0.001668
# [INFO] Epoch 10/25 - Average loss: 0.001481
# [INFO] Epoch 11/25 - Average loss: 0.001212
# [INFO] Epoch 12/25 - Average loss: 0.001088
# [INFO] Epoch 13/25 - Average loss: 0.001054
# [INFO] Epoch 14/25 - Average loss: 0.001003
# [INFO] Epoch 15/25 - Average loss: 0.000980
# [INFO] Epoch 16/25 - Average loss: 0.000963
# [INFO] Epoch 17/25 - Average loss: 0.000941
# [INFO] Epoch 18/25 - Average loss: 0.000928
# [INFO] Epoch 19/25 - Average loss: 0.000903
# [INFO] Epoch 20/25 - Average loss: 0.000846
# [INFO] Epoch 21/25 - Average loss: 0.000741
# [INFO] Epoch 22/25 - Average loss: 0.000525
# [INFO] Epoch 23/25 - Average loss: 0.000337
# [INFO] Epoch 24/25 - Average loss: 0.000294
# [INFO] Epoch 25/25 - Average loss: 0.000280
# [SUCCESS] Autoencoder training complete.
# [INFO] Max reconstruction error per sample: tensor([0.0094, 0.0541, 0.0586,  ..., 0.0059, 0.0059, 0.0132], device='cuda:0')
# [INFO] Number of well-explained examples: 5868/6386
# [INFO] Iteration 2/3 for Rotate(Scale)
# [INFO] Preparing DataLoader: batch_size=64, mask sum=5868
# [SUCCESS] DataLoader prepared successfully.
# [INFO] Initializing Autoencoder: input_dim=7, hidden_dim=6
# [SUCCESS] Autoencoder initialized successfully.
# [INFO] Training autoencoder for 25 epochs, learning rate=0.001
# [INFO] Epoch 1/25 - Average loss: 0.173795
# [INFO] Epoch 2/25 - Average loss: 0.044373
# [INFO] Epoch 3/25 - Average loss: 0.023894
# [INFO] Epoch 4/25 - Average loss: 0.012458
# [INFO] Epoch 5/25 - Average loss: 0.010049
# [INFO] Epoch 6/25 - Average loss: 0.006288
# [INFO] Epoch 7/25 - Average loss: 0.001329
# [INFO] Epoch 8/25 - Average loss: 0.001125
# [INFO] Epoch 9/25 - Average loss: 0.001101
# [INFO] Epoch 10/25 - Average loss: 0.001087
# [INFO] Epoch 11/25 - Average loss: 0.001079
# [INFO] Epoch 12/25 - Average loss: 0.001079
# [INFO] Epoch 13/25 - Average loss: 0.001068
# [INFO] Epoch 14/25 - Average loss: 0.001062
# [INFO] Epoch 15/25 - Average loss: 0.001057
# [INFO] Epoch 16/25 - Average loss: 0.001059
# [INFO] Epoch 17/25 - Average loss: 0.001047
# [INFO] Epoch 18/25 - Average loss: 0.001038
# [INFO] Epoch 19/25 - Average loss: 0.001026
# [INFO] Epoch 20/25 - Average loss: 0.001005
# [INFO] Epoch 21/25 - Average loss: 0.000982
# [INFO] Epoch 22/25 - Average loss: 0.000933
# [INFO] Epoch 23/25 - Average loss: 0.000842
# [INFO] Epoch 24/25 - Average loss: 0.000673
# [INFO] Epoch 25/25 - Average loss: 0.000463
# [SUCCESS] Autoencoder training complete.
# [INFO] Max reconstruction error per sample: tensor([0.0078, 0.0873, 0.0443,  ..., 0.0125, 0.0126, 0.0094], device='cuda:0')
# [INFO] Number of well-explained examples: 5229/6386
# [INFO] Iteration 3/3 for Rotate(Scale)
# [INFO] Preparing DataLoader: batch_size=64, mask sum=5229
# [SUCCESS] DataLoader prepared successfully.
# [INFO] Initializing Autoencoder: input_dim=7, hidden_dim=6
# [SUCCESS] Autoencoder initialized successfully.
# [INFO] Training autoencoder for 25 epochs, learning rate=0.001
# [INFO] Epoch 1/25 - Average loss: 0.132740
# [INFO] Epoch 2/25 - Average loss: 0.045508
# [INFO] Epoch 3/25 - Average loss: 0.022426
# [INFO] Epoch 4/25 - Average loss: 0.012840
# [INFO] Epoch 5/25 - Average loss: 0.009125
# [INFO] Epoch 6/25 - Average loss: 0.007514
# [INFO] Epoch 7/25 - Average loss: 0.005897
# [INFO] Epoch 8/25 - Average loss: 0.002382
# [INFO] Epoch 9/25 - Average loss: 0.000452
# [INFO] Epoch 10/25 - Average loss: 0.000398
# [INFO] Epoch 11/25 - Average loss: 0.000374
# [INFO] Epoch 12/25 - Average loss: 0.000362
# [INFO] Epoch 13/25 - Average loss: 0.000362
# [INFO] Epoch 14/25 - Average loss: 0.000361
# [INFO] Epoch 15/25 - Average loss: 0.000362
# [INFO] Epoch 16/25 - Average loss: 0.000353
# [INFO] Epoch 17/25 - Average loss: 0.000354
# [INFO] Epoch 18/25 - Average loss: 0.000349
# [INFO] Epoch 19/25 - Average loss: 0.000347
# [INFO] Epoch 20/25 - Average loss: 0.000342
# [INFO] Epoch 21/25 - Average loss: 0.000344
# [INFO] Epoch 22/25 - Average loss: 0.000342
# [INFO] Epoch 23/25 - Average loss: 0.000345
# [INFO] Epoch 24/25 - Average loss: 0.000349
# [INFO] Epoch 25/25 - Average loss: 0.000351
# [SUCCESS] Autoencoder training complete.
# [INFO] Max reconstruction error per sample: tensor([0.0108, 0.3252, 0.0535,  ..., 0.0047, 0.0058, 0.0283], device='cuda:0')
# [INFO] Number of well-explained examples: 4467/6386
# [SUCCESS] Model training finished for Rotate(Scale). Total well-explained examples: 4467/6386
# [SUCCESS] Training model for Scale(Box) with 6386 samples, 3 params
# [INFO] Iteration 1/3 for Scale(Box)
# [INFO] Preparing DataLoader: batch_size=64, mask sum=6386
# [SUCCESS] DataLoader prepared successfully.
# [INFO] Initializing Autoencoder: input_dim=3, hidden_dim=2
# [SUCCESS] Autoencoder initialized successfully.
# [INFO] Training autoencoder for 25 epochs, learning rate=0.001
# [INFO] Epoch 1/25 - Average loss: 0.139204
# [INFO] Epoch 2/25 - Average loss: 0.024375
# [INFO] Epoch 3/25 - Average loss: 0.012510
# [INFO] Epoch 4/25 - Average loss: 0.009466
# [INFO] Epoch 5/25 - Average loss: 0.008514
# [INFO] Epoch 6/25 - Average loss: 0.007835
# [INFO] Epoch 7/25 - Average loss: 0.007285
# [INFO] Epoch 8/25 - Average loss: 0.006744
# [INFO] Epoch 9/25 - Average loss: 0.006184
# [INFO] Epoch 10/25 - Average loss: 0.005712
# [INFO] Epoch 11/25 - Average loss: 0.005459
# [INFO] Epoch 12/25 - Average loss: 0.005268
# [INFO] Epoch 13/25 - Average loss: 0.005120
# [INFO] Epoch 14/25 - Average loss: 0.005074
# [INFO] Epoch 15/25 - Average loss: 0.004902
# [INFO] Epoch 16/25 - Average loss: 0.004783
# [INFO] Epoch 17/25 - Average loss: 0.004735
# [INFO] Epoch 18/25 - Average loss: 0.004651
# [INFO] Epoch 19/25 - Average loss: 0.004553
# [INFO] Epoch 20/25 - Average loss: 0.004574
# [INFO] Epoch 21/25 - Average loss: 0.004475
# [INFO] Epoch 22/25 - Average loss: 0.004437
# [INFO] Epoch 23/25 - Average loss: 0.004402
# [INFO] Epoch 24/25 - Average loss: 0.004300
# [INFO] Epoch 25/25 - Average loss: 0.004224
# [SUCCESS] Autoencoder training complete.
# [INFO] Max reconstruction error per sample: tensor([0.0145, 0.0594, 0.0758,  ..., 0.0139, 0.0248, 0.0391], device='cuda:0')
# [INFO] Number of well-explained examples: 4063/6386
# [INFO] Iteration 2/3 for Scale(Box)
# [INFO] Preparing DataLoader: batch_size=64, mask sum=4063
# [SUCCESS] DataLoader prepared successfully.
# [INFO] Initializing Autoencoder: input_dim=3, hidden_dim=2
# [SUCCESS] Autoencoder initialized successfully.
# [INFO] Training autoencoder for 25 epochs, learning rate=0.001
# [INFO] Epoch 1/25 - Average loss: 0.118376
# [INFO] Epoch 2/25 - Average loss: 0.051847
# [INFO] Epoch 3/25 - Average loss: 0.032397
# [INFO] Epoch 4/25 - Average loss: 0.014640
# [INFO] Epoch 5/25 - Average loss: 0.010372
# [INFO] Epoch 6/25 - Average loss: 0.006737
# [INFO] Epoch 7/25 - Average loss: 0.004110
# [INFO] Epoch 8/25 - Average loss: 0.002907
# [INFO] Epoch 9/25 - Average loss: 0.002413
# [INFO] Epoch 10/25 - Average loss: 0.002129
# [INFO] Epoch 11/25 - Average loss: 0.001988
# [INFO] Epoch 12/25 - Average loss: 0.001831
# [INFO] Epoch 13/25 - Average loss: 0.001685
# [INFO] Epoch 14/25 - Average loss: 0.001563
# [INFO] Epoch 15/25 - Average loss: 0.001463
# [INFO] Epoch 16/25 - Average loss: 0.001375
# [INFO] Epoch 17/25 - Average loss: 0.001291
# [INFO] Epoch 18/25 - Average loss: 0.001223
# [INFO] Epoch 19/25 - Average loss: 0.001170
# [INFO] Epoch 20/25 - Average loss: 0.001116
# [INFO] Epoch 21/25 - Average loss: 0.001070
# [INFO] Epoch 22/25 - Average loss: 0.001030
# [INFO] Epoch 23/25 - Average loss: 0.001010
# [INFO] Epoch 24/25 - Average loss: 0.000953
# [INFO] Epoch 25/25 - Average loss: 0.000909
# [SUCCESS] Autoencoder training complete.
# [INFO] Max reconstruction error per sample: tensor([0.0207, 0.0756, 0.0885,  ..., 0.0316, 0.0328, 0.0194], device='cuda:0')
# [INFO] Number of well-explained examples: 3791/6386
# [INFO] Iteration 3/3 for Scale(Box)
# [INFO] Preparing DataLoader: batch_size=64, mask sum=3791
# [SUCCESS] DataLoader prepared successfully.
# [INFO] Initializing Autoencoder: input_dim=3, hidden_dim=2
# [SUCCESS] Autoencoder initialized successfully.
# [INFO] Training autoencoder for 25 epochs, learning rate=0.001
# [INFO] Epoch 1/25 - Average loss: 0.149374
# [INFO] Epoch 2/25 - Average loss: 0.083618
# [INFO] Epoch 3/25 - Average loss: 0.059148
# [INFO] Epoch 4/25 - Average loss: 0.046365
# [INFO] Epoch 5/25 - Average loss: 0.043343
# [INFO] Epoch 6/25 - Average loss: 0.037628
# [INFO] Epoch 7/25 - Average loss: 0.017689
# [INFO] Epoch 8/25 - Average loss: 0.009134
# [INFO] Epoch 9/25 - Average loss: 0.004765
# [INFO] Epoch 10/25 - Average loss: 0.002505
# [INFO] Epoch 11/25 - Average loss: 0.001692
# [INFO] Epoch 12/25 - Average loss: 0.001395
# [INFO] Epoch 13/25 - Average loss: 0.001023
# [INFO] Epoch 14/25 - Average loss: 0.000854
# [INFO] Epoch 15/25 - Average loss: 0.000784
# [INFO] Epoch 16/25 - Average loss: 0.000709
# [INFO] Epoch 17/25 - Average loss: 0.000674
# [INFO] Epoch 18/25 - Average loss: 0.000646
# [INFO] Epoch 19/25 - Average loss: 0.000611
# [INFO] Epoch 20/25 - Average loss: 0.000579
# [INFO] Epoch 21/25 - Average loss: 0.000566
# [INFO] Epoch 22/25 - Average loss: 0.000554
# [INFO] Epoch 23/25 - Average loss: 0.000534
# [INFO] Epoch 24/25 - Average loss: 0.000517
# [INFO] Epoch 25/25 - Average loss: 0.000485
# [SUCCESS] Autoencoder training complete.
# [INFO] Max reconstruction error per sample: tensor([0.0401, 0.1090, 0.1239,  ..., 0.0367, 0.0440, 0.0123], device='cuda:0')
# [INFO] Number of well-explained examples: 3657/6386
# [SUCCESS] Model training finished for Scale(Box). Total well-explained examples: 3657/6386
# [SUCCESS] Training model for Translate(Rotate) with 6386 samples, 7 params
# [INFO] Iteration 1/3 for Translate(Rotate)
# [INFO] Preparing DataLoader: batch_size=64, mask sum=6386
# [SUCCESS] DataLoader prepared successfully.
# [INFO] Initializing Autoencoder: input_dim=7, hidden_dim=6
# [SUCCESS] Autoencoder initialized successfully.
# [INFO] Training autoencoder for 25 epochs, learning rate=0.001
# [INFO] Epoch 1/25 - Average loss: 0.102358
# [INFO] Epoch 2/25 - Average loss: 0.025135
# [INFO] Epoch 3/25 - Average loss: 0.008958
# [INFO] Epoch 4/25 - Average loss: 0.002509
# [INFO] Epoch 5/25 - Average loss: 0.001967
# [INFO] Epoch 6/25 - Average loss: 0.001901
# [INFO] Epoch 7/25 - Average loss: 0.001877
# [INFO] Epoch 8/25 - Average loss: 0.001859
# [INFO] Epoch 9/25 - Average loss: 0.001839
# [INFO] Epoch 10/25 - Average loss: 0.001813
# [INFO] Epoch 11/25 - Average loss: 0.001791
# [INFO] Epoch 12/25 - Average loss: 0.001718
# [INFO] Epoch 13/25 - Average loss: 0.001609
# [INFO] Epoch 14/25 - Average loss: 0.001189
# [INFO] Epoch 15/25 - Average loss: 0.000869
# [INFO] Epoch 16/25 - Average loss: 0.000699
# [INFO] Epoch 17/25 - Average loss: 0.000480
# [INFO] Epoch 18/25 - Average loss: 0.000356
# [INFO] Epoch 19/25 - Average loss: 0.000327
# [INFO] Epoch 20/25 - Average loss: 0.000312
# [INFO] Epoch 21/25 - Average loss: 0.000311
# [INFO] Epoch 22/25 - Average loss: 0.000304
# [INFO] Epoch 23/25 - Average loss: 0.000302
# [INFO] Epoch 24/25 - Average loss: 0.000301
# [INFO] Epoch 25/25 - Average loss: 0.000298
# [SUCCESS] Autoencoder training complete.
# [INFO] Max reconstruction error per sample: tensor([0.0078, 0.0486, 0.0544,  ..., 0.0107, 0.0100, 0.0079], device='cuda:0')
# [INFO] Number of well-explained examples: 5829/6386
# [INFO] Iteration 2/3 for Translate(Rotate)
# [INFO] Preparing DataLoader: batch_size=64, mask sum=5829
# [SUCCESS] DataLoader prepared successfully.
# [INFO] Initializing Autoencoder: input_dim=7, hidden_dim=6
# [SUCCESS] Autoencoder initialized successfully.
# [INFO] Training autoencoder for 25 epochs, learning rate=0.001
# [INFO] Epoch 1/25 - Average loss: 0.089252
# [INFO] Epoch 2/25 - Average loss: 0.030852
# [INFO] Epoch 3/25 - Average loss: 0.009533
# [INFO] Epoch 4/25 - Average loss: 0.007131
# [INFO] Epoch 5/25 - Average loss: 0.002177
# [INFO] Epoch 6/25 - Average loss: 0.001079
# [INFO] Epoch 7/25 - Average loss: 0.001012
# [INFO] Epoch 8/25 - Average loss: 0.000964
# [INFO] Epoch 9/25 - Average loss: 0.000923
# [INFO] Epoch 10/25 - Average loss: 0.000875
# [INFO] Epoch 11/25 - Average loss: 0.000754
# [INFO] Epoch 12/25 - Average loss: 0.000555
# [INFO] Epoch 13/25 - Average loss: 0.000430
# [INFO] Epoch 14/25 - Average loss: 0.000382
# [INFO] Epoch 15/25 - Average loss: 0.000361
# [INFO] Epoch 16/25 - Average loss: 0.000339
# [INFO] Epoch 17/25 - Average loss: 0.000334
# [INFO] Epoch 18/25 - Average loss: 0.000327
# [INFO] Epoch 19/25 - Average loss: 0.000321
# [INFO] Epoch 20/25 - Average loss: 0.000321
# [INFO] Epoch 21/25 - Average loss: 0.000316
# [INFO] Epoch 22/25 - Average loss: 0.000307
# [INFO] Epoch 23/25 - Average loss: 0.000309
# [INFO] Epoch 24/25 - Average loss: 0.000303
# [INFO] Epoch 25/25 - Average loss: 0.000294
# [SUCCESS] Autoencoder training complete.
# [INFO] Max reconstruction error per sample: tensor([0.0124, 0.0312, 0.0469,  ..., 0.0202, 0.0106, 0.0156], device='cuda:0')
# [INFO] Number of well-explained examples: 5411/6386
# [INFO] Iteration 3/3 for Translate(Rotate)
# [INFO] Preparing DataLoader: batch_size=64, mask sum=5411
# [SUCCESS] DataLoader prepared successfully.
# [INFO] Initializing Autoencoder: input_dim=7, hidden_dim=6
# [SUCCESS] Autoencoder initialized successfully.
# [INFO] Training autoencoder for 25 epochs, learning rate=0.001
# [INFO] Epoch 1/25 - Average loss: 0.072029
# [INFO] Epoch 2/25 - Average loss: 0.015167
# [INFO] Epoch 3/25 - Average loss: 0.005805
# [INFO] Epoch 4/25 - Average loss: 0.001312
# [INFO] Epoch 5/25 - Average loss: 0.000789
# [INFO] Epoch 6/25 - Average loss: 0.000689
# [INFO] Epoch 7/25 - Average loss: 0.000633
# [INFO] Epoch 8/25 - Average loss: 0.000577
# [INFO] Epoch 9/25 - Average loss: 0.000460
# [INFO] Epoch 10/25 - Average loss: 0.000226
# [INFO] Epoch 11/25 - Average loss: 0.000119
# [INFO] Epoch 12/25 - Average loss: 0.000093
# [INFO] Epoch 13/25 - Average loss: 0.000078
# [INFO] Epoch 14/25 - Average loss: 0.000065
# [INFO] Epoch 15/25 - Average loss: 0.000059
# [INFO] Epoch 16/25 - Average loss: 0.000055
# [INFO] Epoch 17/25 - Average loss: 0.000053
# [INFO] Epoch 18/25 - Average loss: 0.000049
# [INFO] Epoch 19/25 - Average loss: 0.000050
# [INFO] Epoch 20/25 - Average loss: 0.000044
# [INFO] Epoch 21/25 - Average loss: 0.000044
# [INFO] Epoch 22/25 - Average loss: 0.000041
# [INFO] Epoch 23/25 - Average loss: 0.000041
# [INFO] Epoch 24/25 - Average loss: 0.000039
# [INFO] Epoch 25/25 - Average loss: 0.000039
# [SUCCESS] Autoencoder training complete.
# [INFO] Max reconstruction error per sample: tensor([0.0026, 0.0360, 0.0500,  ..., 0.0039, 0.0044, 0.0204], device='cuda:0')
# [INFO] Number of well-explained examples: 5344/6386
# [SUCCESS] Model training finished for Translate(Rotate). Total well-explained examples: 5344/6386
# [SUCCESS] Training model for Union(Translate) with 5513 samples, 3 params
# [INFO] Iteration 1/3 for Union(Translate)
# [INFO] Preparing DataLoader: batch_size=64, mask sum=5513
# [SUCCESS] DataLoader prepared successfully.
# [INFO] Initializing Autoencoder: input_dim=3, hidden_dim=2
# [SUCCESS] Autoencoder initialized successfully.
# [INFO] Training autoencoder for 25 epochs, learning rate=0.001
# [INFO] Epoch 1/25 - Average loss: 0.086543
# [INFO] Epoch 2/25 - Average loss: 0.037316
# [INFO] Epoch 3/25 - Average loss: 0.021538
# [INFO] Epoch 4/25 - Average loss: 0.015968
# [INFO] Epoch 5/25 - Average loss: 0.012314
# [INFO] Epoch 6/25 - Average loss: 0.010773
# [INFO] Epoch 7/25 - Average loss: 0.009861
# [INFO] Epoch 8/25 - Average loss: 0.009176
# [INFO] Epoch 9/25 - Average loss: 0.008707
# [INFO] Epoch 10/25 - Average loss: 0.008301
# [INFO] Epoch 11/25 - Average loss: 0.007972
# [INFO] Epoch 12/25 - Average loss: 0.007634
# [INFO] Epoch 13/25 - Average loss: 0.007324
# [INFO] Epoch 14/25 - Average loss: 0.007119
# [INFO] Epoch 15/25 - Average loss: 0.006874
# [INFO] Epoch 16/25 - Average loss: 0.006770
# [INFO] Epoch 17/25 - Average loss: 0.006502
# [INFO] Epoch 18/25 - Average loss: 0.006384
# [INFO] Epoch 19/25 - Average loss: 0.006209
# [INFO] Epoch 20/25 - Average loss: 0.006099
# [INFO] Epoch 21/25 - Average loss: 0.006017
# [INFO] Epoch 22/25 - Average loss: 0.005998
# [INFO] Epoch 23/25 - Average loss: 0.005828
# [INFO] Epoch 24/25 - Average loss: 0.005737
# [INFO] Epoch 25/25 - Average loss: 0.005714
# [SUCCESS] Autoencoder training complete.
# [INFO] Max reconstruction error per sample: tensor([0.1241, 0.0167, 0.0278,  ..., 0.0445, 0.0190, 0.0497], device='cuda:0')
# [INFO] Number of well-explained examples: 2544/5513
# [INFO] Iteration 2/3 for Union(Translate)
# [INFO] Preparing DataLoader: batch_size=64, mask sum=2544
# [SUCCESS] DataLoader prepared successfully.
# [INFO] Initializing Autoencoder: input_dim=3, hidden_dim=2
# [SUCCESS] Autoencoder initialized successfully.
# [INFO] Training autoencoder for 25 epochs, learning rate=0.001
# [INFO] Epoch 1/25 - Average loss: 0.085626
# [INFO] Epoch 2/25 - Average loss: 0.054159
# [INFO] Epoch 3/25 - Average loss: 0.022813
# [INFO] Epoch 4/25 - Average loss: 0.019104
# [INFO] Epoch 5/25 - Average loss: 0.015172
# [INFO] Epoch 6/25 - Average loss: 0.008945
# [INFO] Epoch 7/25 - Average loss: 0.007952
# [INFO] Epoch 8/25 - Average loss: 0.007743
# [INFO] Epoch 9/25 - Average loss: 0.007608
# [INFO] Epoch 10/25 - Average loss: 0.007459
# [INFO] Epoch 11/25 - Average loss: 0.007358
# [INFO] Epoch 12/25 - Average loss: 0.007330
# [INFO] Epoch 13/25 - Average loss: 0.007191
# [INFO] Epoch 14/25 - Average loss: 0.007045
# [INFO] Epoch 15/25 - Average loss: 0.006913
# [INFO] Epoch 16/25 - Average loss: 0.006802
# [INFO] Epoch 17/25 - Average loss: 0.006676
# [INFO] Epoch 18/25 - Average loss: 0.006456
# [INFO] Epoch 19/25 - Average loss: 0.006149
# [INFO] Epoch 20/25 - Average loss: 0.005851
# [INFO] Epoch 21/25 - Average loss: 0.005355
# [INFO] Epoch 22/25 - Average loss: 0.004724
# [INFO] Epoch 23/25 - Average loss: 0.004066
# [INFO] Epoch 24/25 - Average loss: 0.003398
# [INFO] Epoch 25/25 - Average loss: 0.002913
# [SUCCESS] Autoencoder training complete.
# [INFO] Max reconstruction error per sample: tensor([0.2885, 0.1083, 0.0242,  ..., 0.0646, 0.0108, 0.0528], device='cuda:0')
# [INFO] Number of well-explained examples: 2419/5513
# [INFO] Iteration 3/3 for Union(Translate)
# [INFO] Preparing DataLoader: batch_size=64, mask sum=2419
# [SUCCESS] DataLoader prepared successfully.
# [INFO] Initializing Autoencoder: input_dim=3, hidden_dim=2
# [SUCCESS] Autoencoder initialized successfully.
# [INFO] Training autoencoder for 25 epochs, learning rate=0.001
# [INFO] Epoch 1/25 - Average loss: 0.083968
# [INFO] Epoch 2/25 - Average loss: 0.052415
# [INFO] Epoch 3/25 - Average loss: 0.019870
# [INFO] Epoch 4/25 - Average loss: 0.012542
# [INFO] Epoch 5/25 - Average loss: 0.010822
# [INFO] Epoch 6/25 - Average loss: 0.009451
# [INFO] Epoch 7/25 - Average loss: 0.006886
# [INFO] Epoch 8/25 - Average loss: 0.002514
# [INFO] Epoch 9/25 - Average loss: 0.001518
# [INFO] Epoch 10/25 - Average loss: 0.001356
# [INFO] Epoch 11/25 - Average loss: 0.001252
# [INFO] Epoch 12/25 - Average loss: 0.001148
# [INFO] Epoch 13/25 - Average loss: 0.001034
# [INFO] Epoch 14/25 - Average loss: 0.000946
# [INFO] Epoch 15/25 - Average loss: 0.000851
# [INFO] Epoch 16/25 - Average loss: 0.000771
# [INFO] Epoch 17/25 - Average loss: 0.000693
# [INFO] Epoch 18/25 - Average loss: 0.000622
# [INFO] Epoch 19/25 - Average loss: 0.000562
# [INFO] Epoch 20/25 - Average loss: 0.000510
# [INFO] Epoch 21/25 - Average loss: 0.000463
# [INFO] Epoch 22/25 - Average loss: 0.000429
# [INFO] Epoch 23/25 - Average loss: 0.000400
# [INFO] Epoch 24/25 - Average loss: 0.000380
# [INFO] Epoch 25/25 - Average loss: 0.000347
# [SUCCESS] Autoencoder training complete.
# [INFO] Max reconstruction error per sample: tensor([0.1006, 0.1126, 0.0049,  ..., 0.0824, 0.0157, 0.0402], device='cuda:0')
# [INFO] Number of well-explained examples: 2601/5513
# [SUCCESS] Model training finished for Union(Translate). Total well-explained examples: 2601/5513
# [SUCCESS] Training model for Union(SymRef) with 1950 samples, 6 params
# [INFO] Iteration 1/3 for Union(SymRef)
# [INFO] Preparing DataLoader: batch_size=64, mask sum=1950
# [SUCCESS] DataLoader prepared successfully.
# [INFO] Initializing Autoencoder: input_dim=6, hidden_dim=5
# [SUCCESS] Autoencoder initialized successfully.
# [INFO] Training autoencoder for 25 epochs, learning rate=0.001
# [INFO] Epoch 1/25 - Average loss: 0.144737
# [INFO] Epoch 2/25 - Average loss: 0.078827
# [INFO] Epoch 3/25 - Average loss: 0.057153
# [INFO] Epoch 4/25 - Average loss: 0.050878
# [INFO] Epoch 5/25 - Average loss: 0.040996
# [INFO] Epoch 6/25 - Average loss: 0.025916
# [INFO] Epoch 7/25 - Average loss: 0.015393
# [INFO] Epoch 8/25 - Average loss: 0.009381
# [INFO] Epoch 9/25 - Average loss: 0.007177
# [INFO] Epoch 10/25 - Average loss: 0.005436
# [INFO] Epoch 11/25 - Average loss: 0.002898
# [INFO] Epoch 12/25 - Average loss: 0.001317
# [INFO] Epoch 13/25 - Average loss: 0.001052
# [INFO] Epoch 14/25 - Average loss: 0.001016
# [INFO] Epoch 15/25 - Average loss: 0.000983
# [INFO] Epoch 16/25 - Average loss: 0.000958
# [INFO] Epoch 17/25 - Average loss: 0.000938
# [INFO] Epoch 18/25 - Average loss: 0.000925
# [INFO] Epoch 19/25 - Average loss: 0.000918
# [INFO] Epoch 20/25 - Average loss: 0.000903
# [INFO] Epoch 21/25 - Average loss: 0.000896
# [INFO] Epoch 22/25 - Average loss: 0.000882
# [INFO] Epoch 23/25 - Average loss: 0.000873
# [INFO] Epoch 24/25 - Average loss: 0.000863
# [INFO] Epoch 25/25 - Average loss: 0.000859
# [SUCCESS] Autoencoder training complete.
# [INFO] Max reconstruction error per sample: tensor([0.0215, 0.0124, 0.0069,  ..., 0.0074, 0.0110, 0.0385], device='cuda:0')
# [INFO] Number of well-explained examples: 1764/1950
# [INFO] Iteration 2/3 for Union(SymRef)
# [INFO] Preparing DataLoader: batch_size=64, mask sum=1764
# [SUCCESS] DataLoader prepared successfully.
# [INFO] Initializing Autoencoder: input_dim=6, hidden_dim=5
# [SUCCESS] Autoencoder initialized successfully.
# [INFO] Training autoencoder for 25 epochs, learning rate=0.001
# [INFO] Epoch 1/25 - Average loss: 0.140777
# [INFO] Epoch 2/25 - Average loss: 0.066088
# [INFO] Epoch 3/25 - Average loss: 0.041791
# [INFO] Epoch 4/25 - Average loss: 0.038115
# [INFO] Epoch 5/25 - Average loss: 0.028420
# [INFO] Epoch 6/25 - Average loss: 0.018904
# [INFO] Epoch 7/25 - Average loss: 0.016135
# [INFO] Epoch 8/25 - Average loss: 0.013646
# [INFO] Epoch 9/25 - Average loss: 0.008565
# [INFO] Epoch 10/25 - Average loss: 0.003299
# [INFO] Epoch 11/25 - Average loss: 0.001753
# [INFO] Epoch 12/25 - Average loss: 0.000735
# [INFO] Epoch 13/25 - Average loss: 0.000328
# [INFO] Epoch 14/25 - Average loss: 0.000272
# [INFO] Epoch 15/25 - Average loss: 0.000258
# [INFO] Epoch 16/25 - Average loss: 0.000243
# [INFO] Epoch 17/25 - Average loss: 0.000238
# [INFO] Epoch 18/25 - Average loss: 0.000230
# [INFO] Epoch 19/25 - Average loss: 0.000225
# [INFO] Epoch 20/25 - Average loss: 0.000222
# [INFO] Epoch 21/25 - Average loss: 0.000219
# [INFO] Epoch 22/25 - Average loss: 0.000217
# [INFO] Epoch 23/25 - Average loss: 0.000215
# [INFO] Epoch 24/25 - Average loss: 0.000214
# [INFO] Epoch 25/25 - Average loss: 0.000212
# [SUCCESS] Autoencoder training complete.
# [INFO] Max reconstruction error per sample: tensor([0.0172, 0.0048, 0.0037,  ..., 0.0041, 0.0094, 0.0368], device='cuda:0')
# [INFO] Number of well-explained examples: 1769/1950
# [INFO] Iteration 3/3 for Union(SymRef)
# [INFO] Preparing DataLoader: batch_size=64, mask sum=1769
# [SUCCESS] DataLoader prepared successfully.
# [INFO] Initializing Autoencoder: input_dim=6, hidden_dim=5
# [SUCCESS] Autoencoder initialized successfully.
# [INFO] Training autoencoder for 25 epochs, learning rate=0.001
# [INFO] Epoch 1/25 - Average loss: 0.210520
# [INFO] Epoch 2/25 - Average loss: 0.132300
# [INFO] Epoch 3/25 - Average loss: 0.063007
# [INFO] Epoch 4/25 - Average loss: 0.036021
# [INFO] Epoch 5/25 - Average loss: 0.023540
# [INFO] Epoch 6/25 - Average loss: 0.019609
# [INFO] Epoch 7/25 - Average loss: 0.018442
# [INFO] Epoch 8/25 - Average loss: 0.017041
# [INFO] Epoch 9/25 - Average loss: 0.014689
# [INFO] Epoch 10/25 - Average loss: 0.010801
# [INFO] Epoch 11/25 - Average loss: 0.006045
# [INFO] Epoch 12/25 - Average loss: 0.003549
# [INFO] Epoch 13/25 - Average loss: 0.001980
# [INFO] Epoch 14/25 - Average loss: 0.000824
# [INFO] Epoch 15/25 - Average loss: 0.000318
# [INFO] Epoch 16/25 - Average loss: 0.000212
# [INFO] Epoch 17/25 - Average loss: 0.000185
# [INFO] Epoch 18/25 - Average loss: 0.000182
# [INFO] Epoch 19/25 - Average loss: 0.000159
# [INFO] Epoch 20/25 - Average loss: 0.000147
# [INFO] Epoch 21/25 - Average loss: 0.000144
# [INFO] Epoch 22/25 - Average loss: 0.000134
# [INFO] Epoch 23/25 - Average loss: 0.000135
# [INFO] Epoch 24/25 - Average loss: 0.000123
# [INFO] Epoch 25/25 - Average loss: 0.000121
# [SUCCESS] Autoencoder training complete.
# [INFO] Max reconstruction error per sample: tensor([0.0145, 0.0078, 0.0059,  ..., 0.0062, 0.0098, 0.0406], device='cuda:0')
# [INFO] Number of well-explained examples: 1742/1950
# [SUCCESS] Model training finished for Union(SymRef). Total well-explained examples: 1742/1950
# [SUCCESS] Training model for SymRef(Union) with 1128 samples, 6 params
# [INFO] Iteration 1/3 for SymRef(Union)
# [INFO] Preparing DataLoader: batch_size=64, mask sum=1128
# [SUCCESS] DataLoader prepared successfully.
# [INFO] Initializing Autoencoder: input_dim=6, hidden_dim=5
# [SUCCESS] Autoencoder initialized successfully.
# [INFO] Training autoencoder for 25 epochs, learning rate=0.001
# [INFO] Epoch 1/25 - Average loss: 0.217334
# [INFO] Epoch 2/25 - Average loss: 0.150401
# [INFO] Epoch 3/25 - Average loss: 0.090923
# [INFO] Epoch 4/25 - Average loss: 0.051317
# [INFO] Epoch 5/25 - Average loss: 0.046517
# [INFO] Epoch 6/25 - Average loss: 0.045003
# [INFO] Epoch 7/25 - Average loss: 0.043102
# [INFO] Epoch 8/25 - Average loss: 0.040363
# [INFO] Epoch 9/25 - Average loss: 0.035742
# [INFO] Epoch 10/25 - Average loss: 0.029841
# [INFO] Epoch 11/25 - Average loss: 0.024320
# [INFO] Epoch 12/25 - Average loss: 0.021254
# [INFO] Epoch 13/25 - Average loss: 0.017451
# [INFO] Epoch 14/25 - Average loss: 0.009822
# [INFO] Epoch 15/25 - Average loss: 0.004804
# [INFO] Epoch 16/25 - Average loss: 0.003668
# [INFO] Epoch 17/25 - Average loss: 0.002747
# [INFO] Epoch 18/25 - Average loss: 0.002085
# [INFO] Epoch 19/25 - Average loss: 0.001626
# [INFO] Epoch 20/25 - Average loss: 0.001319
# [INFO] Epoch 21/25 - Average loss: 0.001058
# [INFO] Epoch 22/25 - Average loss: 0.000813
# [INFO] Epoch 23/25 - Average loss: 0.000650
# [INFO] Epoch 24/25 - Average loss: 0.000534
# [INFO] Epoch 25/25 - Average loss: 0.000483
# [SUCCESS] Autoencoder training complete.
# [INFO] Max reconstruction error per sample: tensor([0.0203, 0.0064, 0.0108,  ..., 0.0064, 0.0099, 0.0401], device='cuda:0')
# [INFO] Number of well-explained examples: 1052/1128
# [INFO] Iteration 2/3 for SymRef(Union)
# [INFO] Preparing DataLoader: batch_size=64, mask sum=1052
# [SUCCESS] DataLoader prepared successfully.
# [INFO] Initializing Autoencoder: input_dim=6, hidden_dim=5
# ...
#         0.1532, 0.0549, 0.1213, 0.2520, 0.0278, 0.1330, 0.1880, 0.0176, 0.1477,
#         0.0555, 0.2807, 0.0856, 0.0746, 0.1537, 0.3077, 0.1252, 0.0607, 0.0920,
#         0.0660, 0.5030, 0.2873, 0.2687, 0.1180, 0.0746, 0.0746, 0.2936, 0.0741,
#         0.2807, 0.0207, 0.1599, 0.1952, 0.0746, 0.4881, 0.4516, 0.0887, 0.1126,
#         0.2979, 0.1220, 0.0669, 0.0746, 0.1329, 0.2965, 0.1054, 0.0821, 0.3496,
#         0.2894, 0.1016, 0.3446, 0.2052, 0.0964, 0.1596, 0.1062, 0.1673, 0.0746,
#         0.0635, 0.2968, 0.0874, 0.3636, 0.0761, 0.1305, 0.1955, 0.0560, 0.1590,
#         0.0453, 0.2215, 0.2472, 0.1333, 0.1079, 0.0226, 0.1578, 0.3083, 0.1252,
#         0.0589, 0.1938, 0.0375, 0.1290, 0.1480, 0.1121, 0.0950, 0.1903, 0.0715,
#         0.0962, 0.0990, 0.0990, 0.0471, 0.4298, 0.1580, 0.1800, 0.2563, 0.2101,
#         0.3370, 0.1827, 0.2997, 0.1007, 0.0746, 0.1249, 0.2597, 0.1799, 0.1385,
#         0.0433, 0.1081, 0.1073, 0.0474, 0.1334, 0.2003, 0.0207, 0.1609, 0.0430,
#         0.1245, 0.1044, 0.0612, 0.2807, 0.0433, 0.0378, 0.0962, 0.1056, 0.2033,
#         0.1827, 0.0948, 0.1656, 0.1827, 0.1781, 0.0398, 0.0953, 0.1652, 0.4112,
#         0.0497, 0.1024, 0.1827, 0.1526, 0.1183, 0.2600, 0.2687, 0.1558, 0.1135,
#         0.0834, 0.0906, 0.1759, 0.2177, 0.2564, 0.0497, 0.1663, 0.0715, 0.2674,
#         0.0682, 0.0712, 0.1567, 0.2185, 0.0990, 0.2788, 0.1647, 0.2687, 0.1726,
#         0.0469, 0.2074, 0.1294, 0.4112, 0.0325, 0.0715, 0.1076, 0.1550, 0.0697,
#         0.1127, 0.1827, 0.4112, 0.2162, 0.2873, 0.2687, 0.0715, 0.0997, 0.0715,
#         0.1359, 0.2577, 0.0482, 0.1381, 0.0881, 0.0783, 0.0434, 0.2861, 0.0957,
#         0.1123, 0.0942, 0.1554, 0.1113, 0.0964, 0.0687, 0.3018, 0.0951, 0.0715,
#         0.0731, 0.0917, 0.0549, 0.4112, 0.1351, 0.2010, 0.1813, 0.1476, 0.0872,
#         0.1592, 0.0964, 0.0916, 0.1655, 0.0964, 0.2101, 0.2337, 0.1746, 0.1364,
#         0.0436, 0.1473, 0.1604, 0.1724, 0.0889, 0.2687, 0.0981, 0.2014, 0.0715,
#         0.0536, 0.0715, 0.1116, 0.1169, 0.1024, 0.1754, 0.0488, 0.0939, 0.2442,
#         0.1827, 0.0558, 0.1220, 0.2017, 0.0849, 0.2023, 0.0420, 0.1123, 0.0990,
#         0.2663, 0.1749, 0.1666, 0.0506, 0.1336, 0.2955, 0.4613, 0.1835, 0.1622,
#         0.0964, 0.1604, 0.1578, 0.1090, 0.2206, 0.5055, 0.2687, 0.3043, 0.2313,
#         0.1827, 0.4430, 0.1590, 0.1684, 0.1290, 0.1297, 0.0659, 0.2838, 0.0902,
#         0.1641, 0.0964, 0.1806, 0.0933, 0.1158, 0.0800, 0.0913, 0.1290, 0.0280,
#         0.1670, 0.0350, 0.0976, 0.1245, 0.0610, 0.0717, 0.0850, 0.0757, 0.0715,
#         0.0917, 0.2597, 0.0637, 0.2774, 0.1682, 0.0464, 0.2663, 0.1256, 0.0384,
#         0.1604, 0.1124, 0.0247, 0.1290, 0.0709, 0.1551, 0.0709, 0.0657, 0.1044,
#         0.0326, 0.1669, 0.1760, 0.0915, 0.1575, 0.0964, 0.0779, 0.2374, 0.0954,
#         0.2659, 0.2643, 0.0497, 0.0486, 0.1779, 0.0485, 0.3180, 0.0746, 0.1577,
#         0.1336, 0.2049, 0.0526, 0.1336, 0.1017, 0.1461, 0.1934, 0.1780, 0.1220,
#         0.2673, 0.2405, 0.0962, 0.1305, 0.1827, 0.0912, 0.2962, 0.0957, 0.2467,
#         0.1367, 0.1013, 0.1033, 0.1469, 0.0320, 0.1761, 0.1409, 0.1060, 0.2152,
#         0.1045, 0.3073, 0.1241, 0.0685, 0.1290, 0.3121, 0.0919, 0.0466, 0.2807,
#         0.1204, 0.1497, 0.1665, 0.1290, 0.1629, 0.1654, 0.0485, 0.0527, 0.2807,
#         0.0207, 0.0802, 0.0667, 0.2167, 0.1250, 0.0715, 0.0360, 0.2623, 0.1290,
#         0.1290, 0.1290, 0.0234, 0.2550, 0.1184, 0.0709, 0.3159, 0.0769, 0.1206,
#         0.1277, 0.0757, 0.2145, 0.0855, 0.1759, 0.1316, 0.0279, 0.0634, 0.0746,
#         0.1910, 0.1218, 0.0646, 0.1759, 0.2542, 0.2177, 0.0914, 0.0715, 0.1336,
#         0.1336, 0.1255, 0.1290, 0.0312, 0.1054, 0.0904, 0.2177, 0.1759, 0.2563,
#         0.1336, 0.0757, 0.2910, 0.0834, 0.0686, 0.2005, 0.0593, 0.1771, 0.0746,
#         0.0973, 0.1078, 0.1408, 0.0512, 0.1850, 0.0275, 0.0926, 0.1759, 0.2177,
#         0.0946, 0.1149, 0.1830, 0.0580, 0.2807, 0.1124, 0.3116, 0.0901, 0.1642,
#         0.0964, 0.0829, 0.0434, 0.1564, 0.0905, 0.1282, 0.1393, 0.2911, 0.1376,
#         0.3294, 0.1831, 0.2304, 0.2699, 0.1561, 0.0524, 0.1259, 0.0219, 0.1396,
#         0.1971, 0.1604, 0.2353, 0.0861, 0.0622, 0.0481, 0.3105, 0.1243, 0.0695,
#         0.1150, 0.0281, 0.0547, 0.2807, 0.0244, 0.0812, 0.0286, 0.1643, 0.0477,
#         0.2969, 0.1309, 0.1621, 0.1690, 0.0695, 0.1077, 0.0969, 0.3361, 0.1167,
#         0.0703, 0.1701, 0.0395, 0.1156, 0.1333, 0.1166, 0.0306, 0.0492, 0.2807,
#         0.0595, 0.0636, 0.2646, 0.0894, 0.1583, 0.0964, 0.2674, 0.1071, 0.2697,
#         0.2604, 0.1937, 0.1337, 0.0638, 0.1444, 0.1848, 0.3390, 0.4084, 0.1738,
#         0.1319, 0.2225, 0.0583, 0.1479, 0.1837, 0.0551, 0.0379, 0.1302, 0.0807,
#         0.1198, 0.2312, 0.0716, 0.0651, 0.1386, 0.3099, 0.1268, 0.0681, 0.0691,
#         0.3108, 0.2861, 0.1158, 0.0477, 0.0340, 0.1973, 0.0663, 0.1915, 0.0758,
#         0.1680, 0.1618, 0.2947, 0.1067, 0.0459, 0.0442, 0.3304, 0.1829, 0.2797,
#         0.1123, 0.1301, 0.2029, 0.1788, 0.1450, 0.0437, 0.0682, 0.0386, 0.2665,
#         0.1774, 0.0801, 0.1121, 0.0195, 0.0538, 0.2807, 0.0852, 0.1176, 0.0356,
#         0.1733, 0.2234, 0.0437, 0.3177, 0.1018, 0.2837, 0.1160, 0.1810, 0.2352,
#         0.0696, 0.1613, 0.2296, 0.1038, 0.0860, 0.0727, 0.1700, 0.2942, 0.1054,
#         0.2038, 0.1827, 0.1290, 0.0927, 0.0859, 0.0394, 0.1827, 0.0319, 0.1783,
#         0.1112, 0.0709, 0.3381, 0.2649, 0.0773, 0.1425, 0.2961, 0.1033, 0.1372,
#         0.1873, 0.1456, 0.1112, 0.1551, 0.1314, 0.0638, 0.1117, 0.4516, 0.1685,
#         0.0529, 0.2922, 0.0352, 0.2481, 0.0892, 0.1681, 0.3469, 0.1582, 0.1660,
#         0.5269, 0.2500, 0.1157, 0.0924, 0.1759, 0.2566, 0.2177, 0.0888, 0.1358,
#         0.2337, 0.1031, 0.0179, 0.0872, 0.0941, 0.1626, 0.0204, 0.0945, 0.2157,
#         0.0823, 0.0257, 0.2323, 0.1413, 0.0715, 0.0758, 0.2915, 0.1449, 0.0315,
#         0.2970, 0.1675, 0.1874, 0.3244, 0.1490, 0.0177, 0.0715, 0.0820, 0.0965,
#         0.0385, 0.3241, 0.1150, 0.1374, 0.0602, 0.2218, 0.1104, 0.1368, 0.3467,
#         0.4949, 0.4480, 0.2318, 0.1791, 0.0426, 0.0764, 0.2149, 0.0831, 0.0995,
#         0.1627, 0.1687, 0.0865, 0.1609, 0.0964, 0.0443, 0.1406, 0.2257, 0.0844,
#         0.1166, 0.2217, 0.1941, 0.0889, 0.1637, 0.0964, 0.0784, 0.0391, 0.0281,
#         0.0746, 0.0964, 0.0265, 0.2414, 0.2012, 0.1956, 0.1597, 0.2785, 0.0852,
#         0.2013, 0.1173, 0.0891, 0.3467, 0.1626, 0.1101, 0.0265, 0.4588, 0.4543,
#         0.0312, 0.0579, 0.0661, 0.1827, 0.1631, 0.0300, 0.0702, 0.0862, 0.1365,
#         0.1098, 0.1026, 0.0865, 0.0288, 0.0569, 0.0322, 0.3250, 0.1807, 0.1428,
#         0.3006, 0.0678, 0.0272, 0.0813, 0.2548, 0.3924, 0.0769, 0.3236, 0.0962,
#         0.1342, 0.0135, 0.2648], device='cuda:0')
# [INFO] Number of well-explained examples: 96/822
# [INFO] Iteration 2/3 for SymRef(Translate)
# [INFO] Preparing DataLoader: batch_size=64, mask sum=96
# [SUCCESS] DataLoader prepared successfully.
# [INFO] Initializing Autoencoder: input_dim=9, hidden_dim=8
# [SUCCESS] Autoencoder initialized successfully.
# [INFO] Training autoencoder for 25 epochs, learning rate=0.001
# [INFO] Epoch 1/25 - Average loss: 0.149671
# [INFO] Epoch 2/25 - Average loss: 0.145154
# [INFO] Epoch 3/25 - Average loss: 0.140679
# [INFO] Epoch 4/25 - Average loss: 0.136294
# [INFO] Epoch 5/25 - Average loss: 0.131852
# [INFO] Epoch 6/25 - Average loss: 0.127361
# [INFO] Epoch 7/25 - Average loss: 0.122740
# [INFO] Epoch 8/25 - Average loss: 0.118014
# [INFO] Epoch 9/25 - Average loss: 0.113169
# [INFO] Epoch 10/25 - Average loss: 0.108185
# [INFO] Epoch 11/25 - Average loss: 0.103137
# [INFO] Epoch 12/25 - Average loss: 0.097883
# [INFO] Epoch 13/25 - Average loss: 0.092552
# [INFO] Epoch 14/25 - Average loss: 0.087002
# [INFO] Epoch 15/25 - Average loss: 0.081127
# [INFO] Epoch 16/25 - Average loss: 0.075082
# [INFO] Epoch 17/25 - Average loss: 0.068762
# [INFO] Epoch 18/25 - Average loss: 0.062394
# [INFO] Epoch 19/25 - Average loss: 0.055855
# [INFO] Epoch 20/25 - Average loss: 0.049533
# [INFO] Epoch 21/25 - Average loss: 0.043456
# [INFO] Epoch 22/25 - Average loss: 0.037550
# [INFO] Epoch 23/25 - Average loss: 0.032078
# [INFO] Epoch 24/25 - Average loss: 0.027237
# [INFO] Epoch 25/25 - Average loss: 0.023292
# [SUCCESS] Autoencoder training complete.
# [INFO] Max reconstruction error per sample: tensor([0.2314, 0.2182, 0.9775, 0.2260, 0.3079, 0.2431, 0.2887, 0.8191, 0.2203,
#         0.9877, 0.6163, 0.2236, 0.9980, 0.2431, 0.2129, 0.9950, 0.3111, 0.6629,
#         0.6602, 0.2233, 0.3120, 0.2128, 0.9950, 0.3107, 0.7104, 0.2130, 0.9950,
#         0.3243, 0.3079, 0.2194, 0.2127, 0.9950, 0.2322, 1.0286, 0.2857, 0.2843,
#         0.3094, 0.2431, 0.8265, 0.2380, 0.2476, 0.2131, 0.9950, 0.2284, 0.6769,
#         0.2236, 0.2335, 0.9774, 0.2341, 0.2379, 0.2328, 1.0283, 1.0369, 1.0334,
#         0.9882, 0.2376, 0.2811, 0.2213, 0.2325, 0.2811, 0.6553, 0.5679, 0.6805,
#         0.2080, 0.3079, 0.2991, 0.5636, 0.3135, 0.2339, 0.6179, 0.2131, 0.3130,
#         0.3308, 0.8696, 0.2122, 0.9950, 0.2431, 0.6180, 0.2179, 0.3079, 1.0337,
#         0.2347, 1.0450, 1.0514, 0.2355, 0.3381, 0.8330, 0.9877, 0.6734, 0.2149,
#         0.9979, 0.2292, 0.3126, 0.7350, 0.2323, 0.9877, 0.6105, 0.2185, 0.9980,
#         0.2130, 0.9950, 0.3494, 0.2431, 0.3344, 0.6705, 0.6632, 0.2206, 0.2207,
#         0.2231, 0.8994, 0.7819, 0.5840, 0.3124, 0.2431, 0.2431, 0.6284, 0.2555,
#         0.9950, 0.2336, 0.9794, 0.8341, 0.2431, 0.9894, 1.0286, 0.3000, 0.3166,
#         0.6342, 0.6490, 0.2226, 0.2431, 0.2958, 0.6179, 0.2213, 0.2376, 0.7051,
#         0.6180, 0.2223, 0.7800, 0.3467, 0.3402, 0.8014, 0.3011, 0.2877, 0.2431,
#         0.2215, 0.6179, 0.2168, 0.7321, 0.3282, 0.9880, 0.6224, 0.2123, 0.9980,
#         0.2229, 0.3688, 0.6506, 0.9880, 0.7255, 0.2176, 0.9980, 0.6668, 0.6661,
#         0.2204, 0.6487, 0.2215, 0.2339, 0.3277, 1.0000, 0.3855, 0.6679, 0.4918,
#         0.3134, 0.3138, 0.3138, 0.2477, 0.7433, 0.7468, 0.5499, 0.9807, 0.9764,
#         0.8460, 0.3130, 0.6179, 0.2221, 0.2431, 0.9879, 0.5696, 0.7690, 0.9977,
#         0.2229, 0.2218, 0.6457, 0.2225, 0.9877, 0.6225, 0.2165, 0.9979, 0.2236,
#         0.6361, 0.4288, 0.2122, 0.9950, 0.2979, 0.3049, 0.3134, 0.7922, 0.6533,
#         0.3130, 0.3139, 0.2817, 0.3130, 0.3511, 0.3057, 0.2239, 0.2975, 1.0337,
#         0.2347, 0.3133, 0.3130, 0.6953, 0.3128, 0.7426, 0.5840, 0.3357, 0.2699,
#         0.3675, 0.7078, 1.0514, 1.0541, 0.7179, 0.2347, 0.2919, 0.4918, 0.5913,
#         0.2354, 0.2959, 0.3473, 0.8268, 0.3138, 0.7686, 0.5968, 0.5840, 0.9783,
#         0.2260, 0.7276, 0.2347, 1.0337, 0.2201, 0.4918, 0.3126, 0.7256, 0.2229,
#         0.6541, 0.3130, 1.0337, 0.5929, 0.7819, 0.5840, 0.4918, 0.3135, 0.4918,
#         0.9881, 0.5750, 0.2322, 0.9980, 0.8446, 0.2392, 0.2981, 0.5636, 0.7186,
#         0.2851, 0.7933, 0.9890, 0.5437, 0.3748, 0.3265, 0.6179, 0.2181, 0.4918,
#         0.3181, 0.3828, 0.2271, 1.0337, 0.9880, 0.6224, 0.7644, 0.9978, 0.7788,
#         0.9887, 0.3748, 0.7816, 0.9887, 0.3748, 0.3170, 0.6133, 0.7153, 0.9882,
#         0.2319, 0.9980, 0.2906, 0.6845, 0.2216, 0.5840, 0.3131, 0.6487, 0.4918,
#         0.2289, 0.4918, 0.3117, 0.7242, 0.3133, 0.9763, 0.2199, 0.3892, 0.8082,
#         0.3130, 0.2147, 1.0008, 0.6865, 0.2875, 0.9882, 0.2492, 0.6457, 0.7098,
#         0.7510, 0.3603, 0.9783, 0.2262, 0.3079, 0.6676, 0.8924, 0.2334, 0.3499,
#         0.3748, 0.2906, 0.7090, 0.2283, 0.7591, 0.8998, 0.5840, 0.5429, 0.3485,
#         0.3130, 0.7083, 0.2885, 0.3450, 0.2339, 0.2908, 0.6863, 0.7130, 0.7915,
#         0.9887, 0.3748, 0.9935, 0.3056, 0.2138, 0.2631, 0.2335, 0.2339, 0.3037,
#         0.3510, 0.3176, 0.3213, 0.8643, 0.3261, 0.3377, 0.2875, 0.2355, 0.4918,
#         0.2296, 0.7343, 0.2691, 0.7294, 0.9773, 0.2339, 0.7901, 0.9990, 0.3044,
#         0.2906, 0.2287, 0.2179, 0.2339, 0.2812, 0.5735, 0.2812, 0.2992, 0.3474,
#         0.3174, 0.3497, 0.3726, 0.7990, 0.9887, 0.3748, 0.3037, 0.7386, 0.2991,
#         1.0285, 1.0239, 0.2347, 0.2232, 0.9757, 0.2239, 0.7686, 0.2431, 0.7191,
#         0.3079, 0.6553, 0.3184, 0.3079, 0.3163, 0.2957, 0.2887, 0.2239, 0.2946,
#         0.6617, 0.6757, 0.3134, 0.3245, 0.3130, 0.2169, 0.6670, 0.5378, 0.7439,
#         0.9974, 0.3128, 0.7032, 0.7060, 0.4426, 0.9818, 0.7132, 0.3196, 0.2976,
#         0.3868, 0.6745, 0.6609, 0.2243, 0.2339, 0.9340, 0.2942, 0.2137, 0.9950,
#         0.7640, 0.2846, 0.2854, 0.2339, 0.3511, 0.9783, 0.2252, 0.2131, 0.9950,
#         0.2322, 0.6647, 0.2114, 0.9927, 0.3155, 0.4918, 0.2130, 0.8190, 0.2339,
#         0.2339, 0.2339, 0.2325, 0.3360, 0.8700, 0.2812, 0.7930, 0.2216, 0.8589,
#         0.6880, 0.2355, 1.0450, 0.7012, 1.0514, 0.7162, 0.2062, 0.3086, 0.2431,
#         0.3819, 1.0002, 0.3854, 1.0514, 0.7090, 1.0541, 0.7086, 0.4918, 0.3079,
#         0.3079, 0.3801, 0.2339, 0.2400, 0.3423, 0.2166, 1.0541, 1.0514, 0.7182,
#         0.3079, 0.2355, 0.2938, 0.3707, 0.2232, 0.9483, 0.4665, 0.3720, 0.2431,
#         0.2161, 0.3029, 0.2670, 0.2946, 0.3380, 0.2922, 0.3846, 1.0514, 1.0541,
#         0.7180, 0.3374, 0.6782, 0.2123, 0.9950, 1.0001, 0.7771, 0.7881, 0.9891,
#         0.3748, 0.3670, 0.3091, 0.3431, 0.3846, 0.8191, 0.6538, 0.6505, 0.2153,
#         0.7148, 0.7484, 0.9925, 0.6375, 0.6417, 0.5792, 0.9875, 0.2069, 0.9975,
#         0.3369, 0.2906, 0.9898, 0.2217, 0.3328, 0.3076, 0.6706, 0.6661, 0.2229,
#         0.8420, 0.2323, 0.2131, 0.9950, 0.2093, 1.0017, 0.3087, 0.6327, 0.2028,
#         0.9495, 0.3124, 0.9845, 0.3029, 0.3166, 0.2798, 0.2255, 0.7635, 0.8762,
#         0.9911, 0.5739, 0.2127, 0.3089, 0.9892, 0.6840, 0.3167, 0.2129, 0.9950,
#         0.6813, 0.2407, 0.7105, 0.7861, 0.9880, 0.3748, 0.6182, 0.2223, 0.6930,
#         0.4401, 0.9833, 0.2762, 0.2220, 0.9997, 0.3810, 0.8486, 0.7632, 0.3436,
#         0.9880, 0.4970, 0.2106, 0.9978, 0.3015, 0.2465, 0.3255, 0.5427, 0.9879,
#         0.2297, 0.9983, 0.2442, 0.3393, 0.3165, 0.6668, 0.6661, 0.2237, 0.2370,
#         0.7672, 0.5636, 0.6458, 0.2237, 0.2605, 0.6842, 0.3041, 0.7468, 0.2223,
#         0.6198, 0.2411, 0.6179, 0.2223, 0.2052, 0.3156, 1.0644, 0.9946, 0.9833,
#         0.2219, 0.9876, 0.6242, 0.7686, 0.9978, 0.5477, 0.2588, 0.3185, 0.6840,
#         0.3198, 0.2234, 0.6536, 0.2324, 0.2131, 0.9950, 0.9878, 0.6944, 0.5936,
#         0.9903, 1.0309, 0.2251, 0.7983, 0.7187, 0.6037, 0.6561, 0.6449, 0.9774,
#         0.2728, 0.4353, 0.2299, 0.2181, 0.3903, 0.3569, 0.7355, 0.6180, 0.2229,
#         0.6597, 0.3130, 0.2339, 0.3137, 0.2332, 0.3140, 0.3130, 0.3065, 0.9861,
#         0.3132, 0.2812, 0.6640, 0.5818, 0.3462, 0.3435, 0.6179, 0.2222, 0.9881,
#         0.6097, 0.9979, 0.3103, 0.7530, 0.3372, 0.2236, 0.5748, 1.0286, 0.2811,
#         0.2295, 0.7957, 0.2393, 0.5904, 0.3308, 0.2910, 0.9667, 0.3332, 0.2954,
#         0.9925, 0.6578, 0.8449, 0.9918, 1.0514, 0.7177, 1.0541, 0.7032, 0.2873,
#         0.3134, 0.6555, 0.3057, 0.2312, 0.3713, 0.6140, 0.2070, 0.3442, 0.2746,
#         0.2921, 0.2811, 0.6906, 0.3728, 0.4918, 0.3256, 0.8338, 0.2179, 0.2296,
#         0.6835, 0.6785, 1.0155, 0.8651, 0.6976, 0.2087, 0.4918, 0.5674, 0.9964,
#         0.2210, 0.8425, 0.2724, 0.2202, 0.3029, 0.5512, 0.5763, 0.5332, 0.9869,
#         0.9894, 1.0273, 0.2427, 0.9478, 0.2436, 0.2831, 0.2792, 0.7270, 0.2301,
#         0.3510, 0.3531, 0.7803, 0.9891, 0.3748, 0.2237, 0.6258, 0.6223, 0.5531,
#         0.6965, 0.6313, 0.2420, 0.7915, 0.9888, 0.3748, 0.3183, 0.2383, 0.2354,
#         0.2431, 0.3049, 0.2155, 0.9995, 0.9894, 0.6529, 0.4633, 0.6392, 0.9924,
#         0.7003, 0.2088, 0.3142, 0.9241, 0.6871, 0.2356, 0.2977, 0.5224, 1.0028,
#         0.2360, 0.2966, 0.2235, 0.3130, 0.3122, 0.3070, 0.3152, 0.2302, 0.3492,
#         0.4365, 0.3075, 0.2836, 0.3197, 0.2416, 0.3143, 0.7048, 0.7012, 0.9791,
#         0.9969, 0.2210, 0.2226, 0.2321, 0.9891, 1.0369, 0.2373, 0.7644, 0.3134,
#         0.3040, 0.2745, 0.7098], device='cuda:0')
# [INFO] Number of well-explained examples: 0/822
# [INFO] All SymRef(Translate) examples filtered out at iteration 2
# [SUCCESS] Model training finished for SymRef(Translate). Total well-explained examples: 0/822
# [INFO] Skipping SymTrans(Translate) (only 42 examples)
# [INFO] Skipping Union(SymTrans) (only 42 examples)
# [INFO] Skipping Union(SymRot) (only 23 examples)
# [INFO] Skipping SymRot(Union) (only 14 examples)
# [INFO] Skipping SymRot(Translate) (only 9 examples)
# [SUCCESS] Finished training 7 PAIRS
# [SUCCESS] Training complete. 4 singleton models and 7 pair models trained.

# %%
# Test on a random DSL shape
if all_dsl_shapes and singleton_models and pair_models:
    random_chair = random.choice(all_dsl_shapes)
    debug_info("--- ORIGINAL CHAIR ---")
    debug_info(f"Type: {type(random_chair).__name__}")
    debug_info(f"Serialized children count: {len(random_chair.serialize()[1][1])}")
    debug_info(f"Preview: {random_chair}")

    # Integrate abstractions
    debug_info("Integrating abstractions...")
    abstracted_chair = integrate_abstractions(
        random_chair, singleton_models, pair_models, error_threshold=0.01
    )

    debug_info("\n--- ABSTRACTED CHAIR ---")
    debug_info(f"Type: {type(abstracted_chair).__name__}")
    if isinstance(abstracted_chair, Abstraction):
        debug_info(f"Abstraction pattern: {abstracted_chair.pattern_name}, compressed dim: {len(abstracted_chair.compressed_params)}")
    debug_info(f"Preview: {abstracted_chair}")

    # Visualization
    try:
        debug_info("Plotting original and abstracted DSL shapes...")
        plot_dsl_with_k3d(random_chair)
        plot_dsl_with_k3d(abstracted_chair)
        debug_success("Visualization complete.")
    except Exception as e:
        debug_error("Plotting failed:", e)
else:
    debug_error("Cannot run test: DSL shapes or trained models are missing.")
# Out:
# [INFO] --- ORIGINAL CHAIR ---
# [INFO] Type: Union
# [INFO] Serialized children count: 2
# [INFO] Preview: Union(
#     Union(
#         Union(
#             Translate(center=[-0.019, 0.017, 0.149])
#                 Rotate(quat=[0.0000, 0.0000, 0.0000, 1.0000])
#                     Scale(lengths=[0.916, 0.191, 0.761])
#                         Box(label=1),
#             SymRef(
#                 plane=[1.000, -0.000, -0.000],
#                 point_on_plane=[-0.018, 0.215, 0.035]
#             )(
#                 Translate(center=[-0.587, 0.215, 0.035])
#                     Rotate(quat=[0.0000, 0.0000, 0.0000, 1.0000])
#                         Scale(lengths=[0.174, 0.588, 0.933])
#                             Box(label=3)
#             )
#         ),
#         Union(
#             Translate(center=[-0.006, -0.479, 0.117])
#                 Rotate(quat=[0.0000, 0.0000, 0.0000, 1.0000])
#                     Scale(lengths=[0.767, 0.552, 0.767])
#                         Box(label=2),
#             Translate(center=[-0.012, -0.719, 0.124])
#                 Rotate(quat=[-0.0000, -0.0523, 0.0002, 0.9986])
#                     Scale(lengths=[1.116, 0.076, 1.115])
#                         Box(label=2)
#         )
#     ),
#     Translate(center=[-0.008, 0.328, -0.385])
#         Rotate(quat=[-0.0819, 0.0000, -0.0000, 0.9966])
#             Scale(lengths=[0.939, 0.824, 0.151])
#                 Box(label=0)
# )
# [INFO] Integrating abstractions...
# [INFO]             [Rebuilt] Box with 1 children
# [INFO]             [RETURN NODE] Box
# [INFO]           [Rebuilt] Scale with 1 children
# [INFO]           [PAIR CHECK] Scale(Box), error=0.0677
# [INFO]           [SINGLETON CHECK] Scale, error=0.0562
# [INFO]           [RETURN NODE] Scale
# [INFO]         [Rebuilt] Rotate with 1 children
# [INFO]         [PAIR CHECK] Rotate(Scale), error=0.0121
# [INFO]         [SINGLETON CHECK] Rotate, error=0.0025
# [SUCCESS]         [SINGLETON ABSTRACTION CREATED] Rotate
# [INFO]       [Rebuilt] Translate with 1 children
# [INFO]       [SINGLETON CHECK] Translate, error=0.0867
# [INFO]       [RETURN NODE] Translate
# [INFO]               [Rebuilt] Box with 1 children
# [INFO]               [RETURN NODE] Box
# [INFO]             [Rebuilt] Scale with 1 children
# [INFO]             [PAIR CHECK] Scale(Box), error=0.4956
# [INFO]             [SINGLETON CHECK] Scale, error=0.7604
# [INFO]             [RETURN NODE] Scale
# [INFO]           [Rebuilt] Rotate with 1 children
# [INFO]           [PAIR CHECK] Rotate(Scale), error=0.0102
# [INFO]           [SINGLETON CHECK] Rotate, error=0.0025
# [SUCCESS]           [SINGLETON ABSTRACTION CREATED] Rotate
# [INFO]         [Rebuilt] Translate with 1 children
# [INFO]         [SINGLETON CHECK] Translate, error=0.1167
# [INFO]         [RETURN NODE] Translate
# [INFO]       [Rebuilt] SymRef with 1 children
# [INFO]       [PAIR CHECK] SymRef(Translate), error=0.2812
# [INFO]       [SINGLETON CHECK] SymRef, error=0.0182
# [INFO]       [RETURN NODE] SymRef
# [INFO]     [Rebuilt] Union with 2 children
# [INFO]     [RETURN NODE] Union
# [INFO]             [Rebuilt] Box with 1 children
# [INFO]             [RETURN NODE] Box
# [INFO]           [Rebuilt] Scale with 1 children
# [INFO]           [PAIR CHECK] Scale(Box), error=0.3011
# [INFO]           [SINGLETON CHECK] Scale, error=0.4516
# [INFO]           [RETURN NODE] Scale
# [INFO]         [Rebuilt] Rotate with 1 children
# [INFO]         [PAIR CHECK] Rotate(Scale), error=0.0128
# [INFO]         [SINGLETON CHECK] Rotate, error=0.0025
# [SUCCESS]         [SINGLETON ABSTRACTION CREATED] Rotate
# [INFO]       [Rebuilt] Translate with 1 children
# [INFO]       [SINGLETON CHECK] Translate, error=0.1237
# [INFO]       [RETURN NODE] Translate
# [INFO]             [Rebuilt] Box with 1 children
# [INFO]             [RETURN NODE] Box
# [INFO]           [Rebuilt] Scale with 1 children
# [INFO]           [PAIR CHECK] Scale(Box), error=0.3260
# [INFO]           [SINGLETON CHECK] Scale, error=0.3827
# [INFO]           [RETURN NODE] Scale
# [INFO]         [Rebuilt] Rotate with 1 children
# [INFO]         [PAIR CHECK] Rotate(Scale), error=0.0526
# [INFO]         [SINGLETON CHECK] Rotate, error=0.0025
# [SUCCESS]         [SINGLETON ABSTRACTION CREATED] Rotate
# [INFO]       [Rebuilt] Translate with 1 children
# [INFO]       [SINGLETON CHECK] Translate, error=0.1475
# [INFO]       [RETURN NODE] Translate
# [INFO]     [Rebuilt] Union with 2 children
# [INFO]     [RETURN NODE] Union
# [INFO]   [Rebuilt] Union with 2 children
# [INFO]   [RETURN NODE] Union
# [INFO]         [Rebuilt] Box with 1 children
# [INFO]         [RETURN NODE] Box
# [INFO]       [Rebuilt] Scale with 1 children
# [INFO]       [PAIR CHECK] Scale(Box), error=0.0803
# [INFO]       [SINGLETON CHECK] Scale, error=0.0395
# [INFO]       [RETURN NODE] Scale
# [INFO]     [Rebuilt] Rotate with 1 children
# [INFO]     [PAIR CHECK] Rotate(Scale), error=0.0442
# [INFO]     [SINGLETON CHECK] Rotate, error=0.0028
# [SUCCESS]     [SINGLETON ABSTRACTION CREATED] Rotate
# [INFO]   [Rebuilt] Translate with 1 children
# [INFO]   [SINGLETON CHECK] Translate, error=0.0509
# [INFO]   [RETURN NODE] Translate
# [INFO] [Rebuilt] Union with 2 children
# [INFO] [RETURN NODE] Union
# [INFO]
# --- ABSTRACTED CHAIR ---
# [INFO] Type: Union
# [INFO] Preview: Union(
#     Union(
#         Union(
#             Translate(center=[-0.019, 0.017, 0.149])
#                 Abs(Rotate, dim=3)(
#                     Scale(lengths=[0.916, 0.191, 0.761])
#                         Box(label=1)
#                 ),
#             SymRef(
#                 plane=[1.000, -0.000, -0.000],
#                 point_on_plane=[-0.018, 0.215, 0.035]
#             )(
#                 Translate(center=[-0.587, 0.215, 0.035])
#                     Abs(Rotate, dim=3)(
#                         Scale(lengths=[0.174, 0.588, 0.933])
#                             Box(label=3)
#                     )
#             )
#         ),
#         Union(
#             Translate(center=[-0.006, -0.479, 0.117])
#                 Abs(Rotate, dim=3)(
#                     Scale(lengths=[0.767, 0.552, 0.767])
#                         Box(label=2)
#                 ),
#             Translate(center=[-0.012, -0.719, 0.124])
#                 Abs(Rotate, dim=3)(
#                     Scale(lengths=[1.116, 0.076, 1.115])
#                         Box(label=2)
#                 )
#         )
#     ),
#     Translate(center=[-0.008, 0.328, -0.385])
#         Abs(Rotate, dim=3)(
#             Scale(lengths=[0.939, 0.824, 0.151])
#                 Box(label=0)
#         )
# )
# [INFO] Plotting original and abstracted DSL shapes...
# Expanding DSL tree for visualization...
# Found 6 total boxes after expansion.
# Output()
# Expanding DSL tree for visualization...
# [INFO] Expanding abstraction: Abs(Rotate, dim=3)(
#     Scale(lengths=[0.916, 0.191, 0.761])
#         Box(label=1)
# )
# [INFO] Compressed params tensor shape: (1, 3)
# [SUCCESS] Reconstructed params: [0.001000434160232544, -0.0012774765491485596, -0.0005693286657333374, 1.0025321245193481]
# [INFO] [INSTANTIATE] Pattern: 'Rotate' | params=[0.001000434160232544, -0.0012774765491485596, -0.0005693286657333374, 1.0025321245193481] | #children=1
# [SUCCESS] Successfully rebuilt node: Rotate(quat=[0.0010, -0.0013, -0.0006, 1.0025])
#     Scale(lengths=[0.916, 0.191, 0.761])
#         Box(label=1)
# [INFO] Expanding abstraction: Abs(Rotate, dim=3)(
#     Scale(lengths=[0.174, 0.588, 0.933])
#         Box(label=3)
# )
# [INFO] Compressed params tensor shape: (1, 3)
# [SUCCESS] Reconstructed params: [0.001000434160232544, -0.0012774765491485596, -0.0005693286657333374, 1.0025321245193481]
# [INFO] [INSTANTIATE] Pattern: 'Rotate' | params=[0.001000434160232544, -0.0012774765491485596, -0.0005693286657333374, 1.0025321245193481] | #children=1
# [SUCCESS] Successfully rebuilt node: Rotate(quat=[0.0010, -0.0013, -0.0006, 1.0025])
#     Scale(lengths=[0.174, 0.588, 0.933])
#         Box(label=3)
# [INFO] Expanding abstraction: Abs(Rotate, dim=3)(
#     Scale(lengths=[0.767, 0.552, 0.767])
#         Box(label=2)
# )
# [INFO] Compressed params tensor shape: (1, 3)
# [SUCCESS] Reconstructed params: [0.001000434160232544, -0.0012774765491485596, -0.0005693286657333374, 1.0025321245193481]
# [INFO] [INSTANTIATE] Pattern: 'Rotate' | params=[0.001000434160232544, -0.0012774765491485596, -0.0005693286657333374, 1.0025321245193481] | #children=1
# [SUCCESS] Successfully rebuilt node: Rotate(quat=[0.0010, -0.0013, -0.0006, 1.0025])
#     Scale(lengths=[0.767, 0.552, 0.767])
#         Box(label=2)
# [INFO] Expanding abstraction: Abs(Rotate, dim=3)(
#     Scale(lengths=[1.116, 0.076, 1.115])
#         Box(label=2)
# )
# [INFO] Compressed params tensor shape: (1, 3)
# [SUCCESS] Reconstructed params: [0.0007565021514892578, -0.05479636788368225, -0.0008804947137832642, 0.9996631741523743]
# [INFO] [INSTANTIATE] Pattern: 'Rotate' | params=[0.0007565021514892578, -0.05479636788368225, -0.0008804947137832642, 0.9996631741523743] | #children=1
# [SUCCESS] Successfully rebuilt node: Rotate(quat=[0.0008, -0.0548, -0.0009, 0.9997])
#     Scale(lengths=[1.116, 0.076, 1.115])
#         Box(label=2)
# [INFO] Expanding abstraction: Abs(Rotate, dim=3)(
#     Scale(lengths=[0.939, 0.824, 0.151])
#         Box(label=0)
# )
# [INFO] Compressed params tensor shape: (1, 3)
# [SUCCESS] Reconstructed params: [-0.08002892136573792, 0.0002854764461517334, 8.761882781982422e-05, 0.9994542598724365]
# [INFO] [INSTANTIATE] Pattern: 'Rotate' | params=[-0.08002892136573792, 0.0002854764461517334, 8.761882781982422e-05, 0.9994542598724365] | #children=1
# [SUCCESS] Successfully rebuilt node: Rotate(quat=[-0.0800, 0.0003, 0.0001, 0.9995])
#     Scale(lengths=[0.939, 0.824, 0.151])
#         Box(label=0)
# Found 6 total boxes after expansion.
# Output()
# [SUCCESS] Visualization complete.

# %%
print(abstracted_chair)
# Out:
# Union(
#     Union(
#         Union(
#             Translate(center=[-0.019, 0.017, 0.149])
#                 Abs(Rotate, dim=3)(
#                     Scale(lengths=[0.916, 0.191, 0.761])
#                         Box(label=1)
#                 ),
#             SymRef(
#                 plane=[1.000, -0.000, -0.000],
#                 point_on_plane=[-0.018, 0.215, 0.035]
#             )(
#                 Translate(center=[-0.587, 0.215, 0.035])
#                     Abs(Rotate, dim=3)(
#                         Scale(lengths=[0.174, 0.588, 0.933])
#                             Box(label=3)
#                     )
#             )
#         ),
#         Union(
#             Translate(center=[-0.006, -0.479, 0.117])
#                 Abs(Rotate, dim=3)(
#                     Scale(lengths=[0.767, 0.552, 0.767])
#                         Box(label=2)
#                 ),
#             Translate(center=[-0.012, -0.719, 0.124])
#                 Abs(Rotate, dim=3)(
#                     Scale(lengths=[1.116, 0.076, 1.115])
#                         Box(label=2)
#                 )
#         )
#     ),
#     Translate(center=[-0.008, 0.328, -0.385])
#         Abs(Rotate, dim=3)(
#             Scale(lengths=[0.939, 0.824, 0.151])
#                 Box(label=0)
#         )
# )

# %%
print(random_chair)
# Out:
# Union(
#     Union(
#         Union(
#             Translate(center=[-0.019, 0.017, 0.149])
#                 Rotate(quat=[0.0000, 0.0000, 0.0000, 1.0000])
#                     Scale(lengths=[0.916, 0.191, 0.761])
#                         Box(label=1),
#             SymRef(
#                 plane=[1.000, -0.000, -0.000],
#                 point_on_plane=[-0.018, 0.215, 0.035]
#             )(
#                 Translate(center=[-0.587, 0.215, 0.035])
#                     Rotate(quat=[0.0000, 0.0000, 0.0000, 1.0000])
#                         Scale(lengths=[0.174, 0.588, 0.933])
#                             Box(label=3)
#             )
#         ),
#         Union(
#             Translate(center=[-0.006, -0.479, 0.117])
#                 Rotate(quat=[0.0000, 0.0000, 0.0000, 1.0000])
#                     Scale(lengths=[0.767, 0.552, 0.767])
#                         Box(label=2),
#             Translate(center=[-0.012, -0.719, 0.124])
#                 Rotate(quat=[-0.0000, -0.0523, 0.0002, 0.9986])
#                     Scale(lengths=[1.116, 0.076, 1.115])
#                         Box(label=2)
#         )
#     ),
#     Translate(center=[-0.008, 0.328, -0.385])
#         Rotate(quat=[-0.0819, 0.0000, -0.0000, 0.9966])
#             Scale(lengths=[0.939, 0.824, 0.151])
#                 Box(label=0)
# )
