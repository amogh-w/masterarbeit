# %%
import sys
import os

# Add the src directory to sys.path
sys.path.append(os.path.abspath("../src"))

# %%
import torch

from abstractions3d.primitives.shapes import Box3D
from abstractions3d.primitives.visualization import visualize_boxes_3d

# %%
boxes = [
    Box3D(center=torch.tensor([0.0, 0.0, 0.0]), scale=torch.tensor([1.0, 0.5, 0.8])),
    Box3D(center=torch.tensor([1.0, 1.0, 0.5]), scale=torch.tensor([0.6, 0.6, 0.6])),
    Box3D(center=torch.tensor([-1.0, -0.5, 0.2]), scale=torch.tensor([0.8, 0.3, 0.5]))
]

visualize_boxes_3d(boxes)
# Out:
# Output()
