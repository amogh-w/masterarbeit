# %%
import scipy
from pathlib import Path
import numpy as np
import pandas as pd
import trimesh
from dataclasses import dataclass
import numpy as np
from enum import Enum
import torch
from scipy.spatial.transform import Rotation
import k3d

# %%
class Tree(object):
    class NodeType(Enum):
        BOX, ADJ, SYM = 0, 1, 2

    class Node(object):
        def __init__(self, box=None, left=None, right=None, node_type=None, sym=None, label=None):
            self.box, self.sym, self.left, self.right, self.node_type, self.label = box, sym, left, right, node_type, label
        def is_leaf(self): return self.node_type == Tree.NodeType.BOX
        def is_adj(self): return self.node_type == Tree.NodeType.ADJ
        def is_sym(self): return self.node_type == Tree.NodeType.SYM

    def __init__(self, boxes, ops, syms, labels):
        box_list = [b for b in torch.split(boxes, 1, 0)]
        sym_param = [s for s in torch.split(syms, 1, 0)]
        label_list = [l for l in labels[0]]
        box_list.reverse(); sym_param.reverse(); label_list.reverse()
        queue = []
        for op_id in range(ops.size()[1]):
            if ops[0, op_id] == self.NodeType.BOX.value:
                queue.append(self.Node(box=box_list.pop(), node_type=self.NodeType.BOX, label=label_list.pop()))
            elif ops[0, op_id] == self.NodeType.ADJ.value:
                right, left = queue.pop(), queue.pop()
                queue.append(self.Node(left=left, right=right, node_type=self.NodeType.ADJ))
            elif ops[0, op_id] == self.NodeType.SYM.value:
                node = queue.pop()
                queue.append(self.Node(left=node, sym=sym_param.pop(), node_type=self.NodeType.SYM))
        self.root = queue[0]

def normalize_vector(vec):
    norm = np.linalg.norm(vec)
    return vec if norm == 0 else vec / norm

def format_box(bv):
    center = bv[0:3]
    lengths = [bv[5], bv[3], bv[4]] # Reorder to x,y,z
    raw_dir2, raw_dir3 = bv[6:9], bv[9:12]
    
    dir2 = normalize_vector(raw_dir2)
    dir1 = normalize_vector(np.cross(dir2, raw_dir3))
    dir3 = normalize_vector(np.cross(dir1, dir2))

    rotation_matrix = np.array([dir1, dir2, dir3]).T
    quaternion = Rotation.from_matrix(rotation_matrix).as_quat()
    
    return {'center': center, 'lengths': lengths, 'quaternion': quaternion}

# %%
@dataclass
class ShapeData:
    """
    A self-contained class that loads all data for a single shape,
    constructs its hierarchical tree, and expands all symmetries.
    """
    def __init__(self, row):
        # Load all raw data from files
        self.boxes = scipy.io.loadmat(row.boxes)["box"]
        self.labels = scipy.io.loadmat(row.labels)["label"]
        self.ops = scipy.io.loadmat(row.ops)["op"]
        sym_mat = scipy.io.loadmat(row.syms)
        self.syms = sym_mat["sym"]
        self.shapename = str(sym_mat["shapename"].squeeze())
        
        self.tree = None
        self.expanded_tree = []

    def construct_tree(self):
        """Uses the loaded raw data to build the Tree object."""
        boxes_t = torch.tensor(self.boxes, dtype=torch.float).t()
        ops_t = torch.tensor(self.ops, dtype=torch.int)
        syms_t = torch.tensor(self.syms, dtype=torch.float).t()
        labels_t = torch.tensor(self.labels, dtype=torch.int)
        self.tree = Tree(boxes_t, ops_t, syms_t, labels_t)
        print(f"Successfully constructed tree for shape: {self.shapename}")

    def expand_tree(self):
        self.expanded_tree = _expand_tree_recursive(self.tree.root)
        print(f"Tree expanded (vectors). Found {len(self.expanded_tree)} final boxes.")


def _expand_tree_recursive(node):
    """
    A clean, recursive function to expand the tree nodes. This version
    uses quaternions for orientation storage.
    """
    if node.is_leaf():
        box_values = node.box.squeeze().tolist()
        box_dict = format_box(box_values)
        box_dict['label_id'] = node.label.item()
        box_dict['label_name'] = label_names.get(node.label.item(), "Unknown")
        return [box_dict]

    elif node.is_adj():
        left_boxes = _expand_tree_recursive(node.left) if node.left else []
        right_boxes = _expand_tree_recursive(node.right) if node.right else []
        return left_boxes + right_boxes

    elif node.is_sym():
        child_boxes = _expand_tree_recursive(node.left) if node.left else []
        sym_values = node.sym.squeeze().tolist()
        sym_type = sym_values[0]
        generated_boxes = []

        if sym_type == 0.0: # Reflection
            plane_normal = np.array(sym_values[1:4])
            point_on_plane = np.array(sym_values[4:7])
            for box in child_boxes:
                reflected_box = box.copy()
                vec_to_plane = box['center'] - point_on_plane
                reflected_box['center'] = box['center'] - 2 * np.dot(vec_to_plane, plane_normal) * plane_normal
                
                # Convert quaternion to matrix, reflect, convert back
                R_orig = Rotation.from_quat(box['quaternion']).as_matrix()
                M_reflect = np.identity(3) - 2 * np.outer(plane_normal, plane_normal)
                R_new = M_reflect @ R_orig
                R_new[:, 0] *= -1 # Fix handedness for valid quaternion
                reflected_box['quaternion'] = Rotation.from_matrix(R_new).as_quat()
                
                generated_boxes.append(reflected_box)

        elif sym_type == -1.0: # Rotation
            axis = normalize_vector(np.array(sym_values[1:4]))
            center = np.array(sym_values[4:7])
            n_fold = int(round(1.0 / sym_values[7])) if sym_values[7] != 0 else 1
            for i in range(1, n_fold):
                angle = 2 * np.pi * i / n_fold
                symmetry_rot = Rotation.from_rotvec(angle * axis)
                for box in child_boxes:
                    rotated_box = box.copy()
                    vec_from_center = box['center'] - center
                    rotated_box['center'] = center + symmetry_rot.apply(vec_from_center)

                    # Combine rotations using quaternion multiplication
                    original_rot = Rotation.from_quat(box['quaternion'])
                    rotated_box['quaternion'] = (symmetry_rot * original_rot).as_quat()
                    
                    generated_boxes.append(rotated_box)

        elif sym_type == 1.0: # Translation
            end_point = np.array(sym_values[4:7])
            n_fold = int(round(1.0 / sym_values[7])) if sym_values[7] != 0 else 1
            if n_fold > 1:
                for box in child_boxes:
                    start_point = box['center']
                    step_vector = (end_point - start_point) / (n_fold - 1)
                    for i in range(1, n_fold):
                        translated_box = box.copy()
                        translated_box['center'] = start_point + i * step_vector
                        # Orientation doesn't change in translation, so just copy quaternion
                        translated_box['quaternion'] = box['quaternion']
                        generated_boxes.append(translated_box)
        
        return child_boxes + generated_boxes
    
    return []

# %%
label_names = {0: "Backrest", 1: "Seat", 2: "Leg", 3: "Armrest"}

def print_full_tree(node, prefix="", is_last=True):
    branch = "└─ " if is_last else "├─ "
    if node.is_leaf():
        part_name = label_names.get(node.label.item(), f"Unknown({node.label.item()})")
        box_values = node.box.squeeze().tolist()
        box_dict = format_box(box_values)
        print(f"{prefix}{branch}Leaf: {part_name}, Label={node.label.item()}, Box={box_dict}")
    elif node.is_adj():
        print(f"{prefix}{branch}Adjacency Node")
        children = [node.left, node.right]
        for i, child in enumerate(children):
            print_full_tree(child, prefix + ("    " if is_last else "│   "), i == len(children)-1)
    elif node.is_sym():
        sym_values = node.sym.squeeze().tolist()
        print(f"{prefix}{branch}Symmetry Node: Sym Params={[round(x,6) for x in sym_values]}")
        print_full_tree(node.left, prefix + ("    " if is_last else "│   "), True)

# %%
df = pd.read_csv("dataset_overview.csv", index_col="shape")
shape_row = df.sample(n=1).iloc[0]

# 1. Instantiate ShapeData. Tree construction and symmetry
#    expansion happen automatically.
my_shape = ShapeData(shape_row)

# %%
my_shape.construct_tree()
print_full_tree(my_shape.tree.root)
# Out:
# Successfully constructed tree for shape: 35583
# └─ Adjacency Node
#     ├─ Adjacency Node
#     │   ├─ Leaf: Seat, Label=1, Box={'center': [0.00886400043964386, -0.35854798555374146, 0.21149499714374542], 'lengths': [0.9670400023460388, 0.29439300298690796, 0.9603679776191711], 'quaternion': array([0., 0., 0., 1.])}
#     │   └─ Adjacency Node
#     │       ├─ Adjacency Node
#     │       │   ├─ Leaf: Armrest, Label=3, Box={'center': [-0.5591269731521606, -0.2824159860610962, 0.4128679931163788], 'lengths': [0.2135089933872223, 0.09105680137872696, 0.06809809803962708], 'quaternion': array([ 0.00532569, -0.01219103, -0.03989125,  0.99911546])}
#     │       │   └─ Adjacency Node
#     │       │       ├─ Leaf: Armrest, Label=3, Box={'center': [0.5617309808731079, -0.1065950021147728, 0.42535400390625], 'lengths': [0.19912000000476837, 0.4413590133190155, 0.05372700095176697], 'quaternion': array([0., 0., 0., 1.])}
#     │       │       └─ Symmetry Node: Sym Params=[0.0, 0.999838, 0.013114, 0.012296, 0.003181, -0.06706, 0.417605, 0.0]
#     │       │           └─ Adjacency Node
#     │       │               ├─ Leaf: Armrest, Label=3, Box={'center': [-0.6269389986991882, -0.07532449811697006, 0.40985599160194397], 'lengths': [0.08314000070095062, 0.3300029933452606, 0.07908900082111359], 'quaternion': array([0., 0., 0., 1.])}
#     │       │               └─ Leaf: Armrest, Label=3, Box={'center': [0.6614260077476501, 0.1626890003681183, 0.19578100740909576], 'lengths': [0.2632400095462799, 0.0944959968328476, 0.6593899726867676], 'quaternion': array([0., 0., 0., 1.])}
#     │       └─ Symmetry Node: Sym Params=[0.0, 0.999974, -0.00265, -0.006705, 0.003435, -0.284837, 0.010467, 0.0]
#     │           └─ Adjacency Node
#     │               ├─ Leaf: Armrest, Label=3, Box={'center': [-0.5565419793128967, -0.2833530008792877, 0.01422099955379963], 'lengths': [0.1981620043516159, 0.09378500282764435, 0.05714000016450882], 'quaternion': array([0., 0., 0., 1.])}
#     │               └─ Leaf: Armrest, Label=3, Box={'center': [-0.6251360177993774, -0.08279299736022949, 0.014301500283181667], 'lengths': [0.07680299878120422, 0.32839199900627136, 0.057705000042915344], 'quaternion': array([0., 0., 0., 1.])}
#     └─ Adjacency Node
#         ├─ Leaf: Backrest, Label=0, Box={'center': [-0.004999999888241291, 0.43753400444984436, -0.36385399103164673], 'lengths': [1.065209984779358, 0.6441709995269775, 0.1556279957294464], 'quaternion': array([0., 0., 0., 1.])}
#         └─ Symmetry Node: Sym Params=[0.0, 0.999705, -0.024277, -0.000199, 0.014307, 0.103352, -0.453025, 0.0]
#             └─ Adjacency Node
#                 ├─ Leaf: Backrest, Label=0, Box={'center': [-0.13794200122356415, 0.10704900324344635, -0.4529950022697449], 'lengths': [0.13983500003814697, 0.7858260273933411, 0.0762460008263588], 'quaternion': array([0., 0., 0., 1.])}
#                 └─ Leaf: Backrest, Label=0, Box={'center': [-0.13465100526809692, 0.04617299884557724, -0.3793700039386749], 'lengths': [0.10393399745225906, 0.8800979852676392, 0.2234950065612793], 'quaternion': array([0., 0., 0., 1.])}

# %%
my_shape.expand_tree()
my_shape.expanded_tree
# Out:
# Tree expanded (vectors). Found 16 final boxes.
# [{'center': [0.00886400043964386, -0.35854798555374146, 0.21149499714374542],
#   'lengths': [0.9670400023460388, 0.29439300298690796, 0.9603679776191711],
#   'quaternion': array([0., 0., 0., 1.]),
#   'label_id': 1,
#   'label_name': 'Seat'},
#  {'center': [-0.5591269731521606, -0.2824159860610962, 0.4128679931163788],
#   'lengths': [0.2135089933872223, 0.09105680137872696, 0.06809809803962708],
#   'quaternion': array([ 0.00532569, -0.01219103, -0.03989125,  0.99911546]),
#   'label_id': 3,
#   'label_name': 'Armrest'},
#  {'center': [0.5617309808731079, -0.1065950021147728, 0.42535400390625],
#   'lengths': [0.19912000000476837, 0.4413590133190155, 0.05372700095176697],
#   'quaternion': array([0., 0., 0., 1.]),
#   'label_id': 3,
#   'label_name': 'Armrest'},
#  {'center': [-0.6269389986991882, -0.07532449811697006, 0.40985599160194397],
#   'lengths': [0.08314000070095062, 0.3300029933452606, 0.07908900082111359],
#   'quaternion': array([0., 0., 0., 1.]),
#   'label_id': 3,
#   'label_name': 'Armrest'},
#  {'center': [0.6614260077476501, 0.1626890003681183, 0.19578100740909576],
#   'lengths': [0.2632400095462799, 0.0944959968328476, 0.6593899726867676],
#   'quaternion': array([0., 0., 0., 1.]),
#   'label_id': 3,
#   'label_name': 'Armrest'},
#  {'center': array([ 0.63330097, -0.05879503,  0.42535504]),
#   'lengths': [0.08314000070095062, 0.3300029933452606, 0.07908900082111359],
#   'quaternion': array([ 6.46153390e-17, -1.22965046e-02,  1.31140050e-02,  9.99838396e-01]),
#   'label_id': 3,
#   'label_name': 'Armrest'},
#  {'center': array([-0.65520693,  0.14541988,  0.17958841]),
#   'lengths': [0.2632400095462799, 0.0944959968328476, 0.6593899726867676],
#   'quaternion': array([ 6.46153390e-17, -1.22965046e-02,  1.31140050e-02,  9.99838396e-01]),
#   'label_id': 3,
#   'label_name': 'Armrest'},
#  {'center': [-0.5565419793128967, -0.2833530008792877, 0.01422099955379963],
#   'lengths': [0.1981620043516159, 0.09378500282764435, 0.05714000016450882],
#   'quaternion': array([0., 0., 0., 1.]),
#   'label_id': 3,
#   'label_name': 'Armrest'},
#  {'center': [-0.6251360177993774, -0.08279299736022949, 0.014301500283181667],
#   'lengths': [0.07680299878120422, 0.32839199900627136, 0.057705000042915344],
#   'quaternion': array([0., 0., 0., 1.]),
#   'label_id': 3,
#   'label_name': 'Armrest'},
#  {'center': array([ 0.56341198, -0.286321  ,  0.00671199]),
#   'lengths': [0.1981620043516159, 0.09378500282764435, 0.05714000016450882],
#   'quaternion': array([-1.62824293e-16,  6.70456980e-03, -2.65003997e-03,  9.99974013e-01]),
#   'label_id': 3,
#   'label_name': 'Armrest'},
#  {'center': array([ 0.63306292, -0.08612736,  0.0058656 ]),
#   'lengths': [0.07680299878120422, 0.32839199900627136, 0.057705000042915344],
#   'quaternion': array([-1.62824293e-16,  6.70456980e-03, -2.65003997e-03,  9.99974013e-01]),
#   'label_id': 3,
#   'label_name': 'Armrest'},
#  {'center': [-0.004999999888241291, 0.43753400444984436, -0.36385399103164673],
#   'lengths': [1.065209984779358, 0.6441709995269775, 0.1556279957294464],
#   'quaternion': array([0., 0., 0., 1.]),
#   'label_id': 0,
#   'label_name': 'Backrest'},
#  {'center': [-0.13794200122356415, 0.10704900324344635, -0.4529950022697449],
#   'lengths': [0.13983500003814697, 0.7858260273933411, 0.0762460008263588],
#   'quaternion': array([0., 0., 0., 1.]),
#   'label_id': 0,
#   'label_name': 'Backrest'},
#  {'center': [-0.13465100526809692, 0.04617299884557724, -0.3793700039386749],
#   'lengths': [0.10393399745225906, 0.8800979852676392, 0.2234950065612793],
#   'quaternion': array([0., 0., 0., 1.]),
#   'label_id': 0,
#   'label_name': 'Backrest'},
#  {'center': array([ 0.16655525,  0.09965454, -0.4530555 ]),
#   'lengths': [0.13983500003814697, 0.7858260273933411, 0.0762460008263588],
#   'quaternion': array([-4.12203026e-19,  1.98629047e-04, -2.42770054e-02,  9.99705250e-01]),
#   'label_id': 0,
#   'label_name': 'Backrest'},
#  {'center': array([ 0.16034247,  0.03900933, -0.37942862]),
#   'lengths': [0.10393399745225906, 0.8800979852676392, 0.2234950065612793],
#   'quaternion': array([-4.12203026e-19,  1.98629047e-04, -2.42770054e-02,  9.99705250e-01]),
#   'label_id': 0,
#   'label_name': 'Backrest'}]

# %%
import numpy as np
import k3d

# fixed color map for label ids
LABEL_COLORS = {
    0: 0xFF0000,  # red   (Backrest)
    1: 0x00FF00,  # green (Seat)
    2: 0x0000FF,  # blue  (Leg)
    3: 0xFFFF00,  # yellow (Armrest)
}

def plot_boxes(box_list):
    """
    Plots a list of box dictionaries that use QUATERNIONS for orientation.
    """
    plot = k3d.plot(name="Expanded Shape Visualization")

    for box in box_list:
        center = np.array(box["center"])
        lengths = np.array(box["lengths"])
        quaternion = np.array(box["quaternion"])
        label_id = box.get("label_id", -1)

        # 1. Convert quaternion back to rotation matrix (dir vectors)
        rotation_matrix = Rotation.from_quat(quaternion).as_matrix()
        dir1 = rotation_matrix[:, 0]
        dir2 = rotation_matrix[:, 1]
        dir3 = rotation_matrix[:, 2]

        # 2. Calculate the 8 corner points using the dir vectors
        d1 = 0.5 * lengths[0] * dir1
        d2 = 0.5 * lengths[1] * dir2
        d3 = 0.5 * lengths[2] * dir3

        corners = np.array([
            center - d1 - d2 - d3, center - d1 + d2 - d3,
            center + d1 - d2 - d3, center + d1 + d2 - d3,
            center - d1 - d2 + d3, center - d1 + d2 + d3,
            center + d1 - d2 + d3, center + d1 + d2 + d3
        ], dtype=np.float32)

        # 3. Define the 12 triangular faces of the box
        faces = np.array([
            [0,1,3], [0,3,2], [4,6,7], [4,7,5],
            [0,2,6], [0,6,4], [1,5,7], [1,7,3],
            [0,4,5], [0,5,1], [2,3,7], [2,7,6]
        ], dtype=np.uint32)

        color = LABEL_COLORS.get(label_id, 0x808080) # Fallback to gray
        plot += k3d.mesh(corners, faces, color=color, opacity=1.0)

    plot.display()

plot_boxes(my_shape.expanded_tree)
# Out:
# Output()

# %%
import torch
import textwrap
import numpy as np
from scipy.spatial.transform import Rotation as R

# Helper to format vectors for printing
def _format_vec(vec, precision=3):
    """Formats a list of numbers into a clean string like '[1.234, 5.678]'."""
    return f"[{', '.join(f'{x:.{precision}f}' for x in vec)}]"

# Label mapping for better readability
LABEL_NAMES = {0: "Backrest", 1: "Seat", 2: "Leg", 3: "Armrest"}

# --- LEAF NODE ---
class Box:
    def __init__(self, label: int, center, dims, quaternion):
        self.label = label
        self.center = center
        self.lengths = dims
        self.quaternion = quaternion # Store the quaternion directly

    def __str__(self):
        # The __str__ method now simply reads the stored quaternion
        # label_name = LABEL_NAMES.get(self.label, "Unknown")
        info = (
            # f"Box(label={self.label} '{label_name}',\n"
            f"Box(label={self.label},\n"
            f"    center={_format_vec(self.center)},\n"
            f"    lengths={_format_vec(self.lengths)},\n"
            f"    quat={_format_vec(self.quaternion, precision=4)}\n)"
        )
        return textwrap.indent(info, "    ").lstrip()

# --- INTERNAL NODES ---
class Union:
    def __init__(self, left, right):
        self.left = left
        self.right = right

    def __str__(self):
        left_str = textwrap.indent(str(self.left), "    ")
        right_str = textwrap.indent(str(self.right), "    ")
        return f"Union(\n{left_str},\n{right_str}\n)"

class Symmetry:
    def __init__(self, child):
        self.child = child

class SymRef(Symmetry):
    def __init__(self, child, plane_normal, point_on_plane):
        super().__init__(child)
        self.plane = plane_normal
        self.point_on_plane = point_on_plane

    def __str__(self):
        info = (
            f"SymRef(\n"
            f"    plane={_format_vec(self.plane)},\n"
            f"    point_on_plane={_format_vec(self.point_on_plane)}\n)"
        )
        child_str = textwrap.indent(str(self.child), "    ")
        return f"{info}(\n{child_str}\n)"

class SymRot(Symmetry):
    def __init__(self, child, axis, center, n_fold: int):
        super().__init__(child)
        self.axis = axis
        self.center = center
        self.n = n_fold

    def __str__(self):
        info = (
            f"SymRot(\n"
            f"    axis={_format_vec(self.axis)},\n"
            f"    center={_format_vec(self.center)},\n"
            f"    n={self.n}\n)"
        )
        child_str = textwrap.indent(str(self.child), "    ")
        return f"{info}(\n{child_str}\n)"

class SymTrans(Symmetry):
    def __init__(self, child, end_point, n_fold: int):
        super().__init__(child)
        self.end_point = end_point
        self.n = n_fold
        # Note: The translation_vector is a step vector calculated during expansion,
        # not a fixed property. The end_point is the defining parameter.

    def __str__(self):
        info = (
            f"SymTrans(\n"
            # The 'end_point' defines the goal of the symmetric translation.
            f"    end_point={_format_vec(self.end_point)},\n"
            f"    n={self.n}\n)"
        )
        child_str = textwrap.indent(str(self.child), "    ")
        return f"{info}(\n{child_str}\n)"

# %%
from scipy.spatial.transform import Rotation as R

def tree_to_dsl(node):
    """
    Converts a node from the original Tree structure into its equivalent
    DSL object representation, now using quaternions directly.
    """
    # Base Case: The node is a leaf (a primitive box)
    if node.is_leaf():
        box_vec = node.box.squeeze()

        center = box_vec[0:3].tolist()
        dims = [box_vec[5].item(), box_vec[3].item(), box_vec[4].item()]
        label = node.label.item()

        # --- THIS IS THE MODIFIED PART ---
        # Calculate the quaternion from the raw direction vectors
        raw_dir2, raw_dir3 = box_vec[6:9].numpy(), box_vec[9:12].numpy()
        
        dir2_norm = raw_dir2 / (np.linalg.norm(raw_dir2) + 1e-8)
        dir1_norm = np.cross(dir2_norm, raw_dir3)
        dir1_norm /= (np.linalg.norm(dir1_norm) + 1e-8)
        dir3_norm = np.cross(dir1_norm, dir2_norm)
        
        rotation_matrix = np.array([dir1_norm, dir2_norm, dir3_norm]).T
        quaternion = R.from_matrix(rotation_matrix).as_quat().tolist()
        # --- END OF MODIFICATION ---

        # Pass the calculated quaternion to the Box constructor
        return Box(label=label, center=center, dims=dims, quaternion=quaternion)

    # Recursive cases for Adjacency and Symmetry remain the same
    elif node.is_adj():
        left_child_dsl = tree_to_dsl(node.left)
        right_child_dsl = tree_to_dsl(node.right)
        return Union(left=left_child_dsl, right=right_child_dsl)

    elif node.is_sym():
        child_dsl = tree_to_dsl(node.left)
        sym_vec = node.sym.squeeze()
        sym_type = sym_vec[0].item()

        if sym_type == 0.0: # Reflection
            plane_normal = sym_vec[1:4].tolist()
            point_on_plane = sym_vec[4:7].tolist()
            return SymRef(child=child_dsl, plane_normal=plane_normal, point_on_plane=point_on_plane)
        elif sym_type == -1.0: # Rotation
            axis = sym_vec[1:4].tolist()
            center = sym_vec[4:7].tolist()
            n_fold_param = sym_vec[7].item()
            n_fold = int(round(1.0 / n_fold_param)) if n_fold_param != 0 else 1
            return SymRot(child=child_dsl, axis=axis, center=center, n_fold=n_fold)
        elif sym_type == 1.0: # Translation
            end_point = sym_vec[4:7].tolist()
            n_fold_param = sym_vec[7].item()
            n_fold = int(round(1.0 / n_fold_param)) if n_fold_param != 0 else 1
            return SymTrans(child=child_dsl, end_point=end_point, n_fold=n_fold)
    
    return None

# %%
# Assuming 'my_shape' is an object from your first script
# and you have already run:
# my_shape.construct_tree()

# Convert the tree to our new DSL representation
dsl_representation = tree_to_dsl(my_shape.tree.root)

# Print the readable DSL version of the tree
print(dsl_representation)
# Out:
# Union(
#     Union(
#         Box(label=1,
#                 center=[0.009, -0.359, 0.211],
#                 lengths=[0.967, 0.294, 0.960],
#                 quat=[0.0000, 0.0000, 0.0000, 1.0000]
#             ),
#         Union(
#             Union(
#                 Box(label=3,
#                         center=[-0.559, -0.282, 0.413],
#                         lengths=[0.214, 0.091, 0.068],
#                         quat=[0.0053, -0.0122, -0.0399, 0.9991]
#                     ),
#                 Union(
#                     Box(label=3,
#                             center=[0.562, -0.107, 0.425],
#                             lengths=[0.199, 0.441, 0.054],
#                             quat=[0.0000, 0.0000, 0.0000, 1.0000]
#                         ),
#                     SymRef(
#                         plane=[1.000, 0.013, 0.012],
#                         point_on_plane=[0.003, -0.067, 0.418]
#                     )(
#                         Union(
#                             Box(label=3,
#                                     center=[-0.627, -0.075, 0.410],
#                                     lengths=[0.083, 0.330, 0.079],
#                                     quat=[0.0000, 0.0000, 0.0000, 1.0000]
#                                 ),
#                             Box(label=3,
#                                     center=[0.661, 0.163, 0.196],
#                                     lengths=[0.263, 0.094, 0.659],
#                                     quat=[0.0000, 0.0000, 0.0000, 1.0000]
#                                 )
#                         )
#                     )
#                 )
#             ),
#             SymRef(
#                 plane=[1.000, -0.003, -0.007],
#                 point_on_plane=[0.003, -0.285, 0.010]
#             )(
#                 Union(
#                     Box(label=3,
#                             center=[-0.557, -0.283, 0.014],
#                             lengths=[0.198, 0.094, 0.057],
#                             quat=[0.0000, 0.0000, 0.0000, 1.0000]
#                         ),
#                     Box(label=3,
#                             center=[-0.625, -0.083, 0.014],
#                             lengths=[0.077, 0.328, 0.058],
#                             quat=[0.0000, 0.0000, 0.0000, 1.0000]
#                         )
#                 )
#             )
#         )
#     ),
#     Union(
#         Box(label=0,
#                 center=[-0.005, 0.438, -0.364],
#                 lengths=[1.065, 0.644, 0.156],
#                 quat=[0.0000, 0.0000, 0.0000, 1.0000]
#             ),
#         SymRef(
#             plane=[1.000, -0.024, -0.000],
#             point_on_plane=[0.014, 0.103, -0.453]
#         )(
#             Union(
#                 Box(label=0,
#                         center=[-0.138, 0.107, -0.453],
#                         lengths=[0.140, 0.786, 0.076],
#                         quat=[0.0000, 0.0000, 0.0000, 1.0000]
#                     ),
#                 Box(label=0,
#                         center=[-0.135, 0.046, -0.379],
#                         lengths=[0.104, 0.880, 0.223],
#                         quat=[0.0000, 0.0000, 0.0000, 1.0000]
#                     )
#             )
#         )
#     )
# )

# %%
def dsl_to_dict(node):
    """
    Recursively converts a DSL object tree into a JSON-serializable dictionary.
    This version expects Box objects to have a .quaternion attribute.
    """
    if isinstance(node, Box):
        return {
            "type": "Box",
            "label": node.label,
            "center": node.center,
            "lengths": node.lengths,
            "quaternion": node.quaternion  # Changed from dir_vectors
        }
    # ... the rest of the function for Union, SymRef, etc. is unchanged ...
    elif isinstance(node, Union):
        return {"type": "Union", "left": dsl_to_dict(node.left), "right": dsl_to_dict(node.right)}
    elif isinstance(node, SymRef):
        return {"type": "SymRef", "plane_normal": node.plane, "point_on_plane": node.point_on_plane, "child": dsl_to_dict(node.child)}
    elif isinstance(node, SymRot):
        return {"type": "SymRot", "axis": node.axis, "center": node.center, "n_fold": node.n, "child": dsl_to_dict(node.child)}
    elif isinstance(node, SymTrans):
        return {"type": "SymTrans", "end_point": node.end_point, "n_fold": node.n, "child": dsl_to_dict(node.child)}
    raise TypeError(f"Object of type {type(node).__name__} is not JSON serializable")

# %%
import json


# 1. Re-create the DSL representation using the updated function
# This ensures Box objects are created with .quaternion
dsl_representation = tree_to_dsl(my_shape.tree.root)

# 2. Convert the new DSL object tree into a dictionary
dsl_dictionary = dsl_to_dict(dsl_representation)

# 3. Serialize the dictionary into a JSON string
json_output = json.dumps(dsl_dictionary, indent=2)

# 4. Print the final result, which will now have quaternions
print(json_output)
# Out:
# {
#   "type": "Union",
#   "left": {
#     "type": "Union",
#     "left": {
#       "type": "Box",
#       "label": 1,
#       "center": [
#         0.00886400043964386,
#         -0.35854798555374146,
#         0.21149499714374542
#       ],
#       "lengths": [
#         0.9670400023460388,
#         0.29439300298690796,
#         0.9603679776191711
#       ],
#       "quaternion": [
#         0.0,
#         0.0,
#         0.0,
#         1.0
#       ]
#     },
#     "right": {
#       "type": "Union",
#       "left": {
#         "type": "Union",
#         "left": {
#           "type": "Box",
#           "label": 3,
#           "center": [
#             -0.5591269731521606,
#             -0.2824159860610962,
#             0.4128679931163788
#           ],
#           "lengths": [
#             0.2135089933872223,
#             0.09105680137872696,
#             0.06809809803962708
#           ],
#           "quaternion": [
#             0.005325693452493309,
#             -0.012191035994820522,
#             -0.03989124898150948,
#             0.999115460737806
#           ]
#         },
#         "right": {
#           "type": "Union",
#           "left": {
#             "type": "Box",
#             "label": 3,
#             "center": [
#               0.5617309808731079,
#               -0.1065950021147728,
#               0.42535400390625
#             ],
#             "lengths": [
#               0.19912000000476837,
#               0.4413590133190155,
#               0.05372700095176697
#             ],
#             "quaternion": [
#               0.0,
#               0.0,
#               0.0,
#               1.0
#             ]
#           },
#           "right": {
#             "type": "SymRef",
#             "plane_normal": [
#               0.9998379945755005,
#               0.013113999739289284,
#               0.01229649968445301
#             ],
#             "point_on_plane": [
#               0.003181499894708395,
#               -0.06705980002880096,
#               0.4176050126552582
#             ],
#             "child": {
#               "type": "Union",
#               "left": {
#                 "type": "Box",
#                 "label": 3,
#                 "center": [
#                   -0.6269389986991882,
#                   -0.07532449811697006,
#                   0.40985599160194397
#                 ],
#                 "lengths": [
#                   0.08314000070095062,
#                   0.3300029933452606,
#                   0.07908900082111359
#                 ],
#                 "quaternion": [
#                   0.0,
#                   0.0,
#                   0.0,
#                   1.0
#                 ]
#               },
#               "right": {
#                 "type": "Box",
#                 "label": 3,
#                 "center": [
#                   0.6614260077476501,
#                   0.1626890003681183,
#                   0.19578100740909576
#                 ],
#                 "lengths": [
#                   0.2632400095462799,
#                   0.0944959968328476,
#                   0.6593899726867676
#                 ],
#                 "quaternion": [
#                   0.0,
#                   0.0,
#                   0.0,
#                   1.0
#                 ]
#               }
#             }
#           }
#         }
#       },
#       "right": {
#         "type": "SymRef",
#         "plane_normal": [
#           0.9999740123748779,
#           -0.0026500399690121412,
#           -0.006704569794237614
#         ],
#         "point_on_plane": [
#           0.003435000078752637,
#           -0.284837007522583,
#           0.01046650018543005
#         ],
#         "child": {
#           "type": "Union",
#           "left": {
#             "type": "Box",
#             "label": 3,
#             "center": [
#               -0.5565419793128967,
#               -0.2833530008792877,
#               0.01422099955379963
#             ],
#             "lengths": [
#               0.1981620043516159,
#               0.09378500282764435,
#               0.05714000016450882
#             ],
#             "quaternion": [
#               0.0,
#               0.0,
#               0.0,
#               1.0
#             ]
#           },
#           "right": {
#             "type": "Box",
#             "label": 3,
#             "center": [
#               -0.6251360177993774,
#               -0.08279299736022949,
#               0.014301500283181667
#             ],
#             "lengths": [
#               0.07680299878120422,
#               0.32839199900627136,
#               0.057705000042915344
#             ],
#             "quaternion": [
#               0.0,
#               0.0,
#               0.0,
#               1.0
#             ]
#           }
#         }
#       }
#     }
#   },
#   "right": {
#     "type": "Union",
#     "left": {
#       "type": "Box",
#       "label": 0,
#       "center": [
#         -0.004999999888241291,
#         0.43753400444984436,
#         -0.36385399103164673
#       ],
#       "lengths": [
#         1.065209984779358,
#         0.6441709995269775,
#         0.1556279957294464
#       ],
#       "quaternion": [
#         0.0,
#         0.0,
#         0.0,
#         1.0
#       ]
#     },
#     "right": {
#       "type": "SymRef",
#       "plane_normal": [
#         0.9997050166130066,
#         -0.02427699975669384,
#         -0.00019862900080624968
#       ],
#       "point_on_plane": [
#         0.014306699857115746,
#         0.10335200279951096,
#         -0.4530250132083893
#       ],
#       "child": {
#         "type": "Union",
#         "left": {
#           "type": "Box",
#           "label": 0,
#           "center": [
#             -0.13794200122356415,
#             0.10704900324344635,
#             -0.4529950022697449
#           ],
#           "lengths": [
#             0.13983500003814697,
#             0.7858260273933411,
#             0.0762460008263588
#           ],
#           "quaternion": [
#             0.0,
#             0.0,
#             0.0,
#             1.0
#           ]
#         },
#         "right": {
#           "type": "Box",
#           "label": 0,
#           "center": [
#             -0.13465100526809692,
#             0.04617299884557724,
#             -0.3793700039386749
#           ],
#           "lengths": [
#             0.10393399745225906,
#             0.8800979852676392,
#             0.2234950065612793
#           ],
#           "quaternion": [
#             0.0,
#             0.0,
#             0.0,
#             1.0
#           ]
#         }
#       }
#     }
#   }
# }

# %%
import json

# Note: This parser assumes that your DSL classes (Box, Union, SymRef, etc.)
# are already defined in your notebook's memory.

def dict_to_dsl(node_dict):
    """
    Recursively traverses a dictionary and converts it into the corresponding
    DSL object tree (Box, Union, SymRef, etc.).
    """
    if not isinstance(node_dict, dict):
        raise TypeError("Input must be a dictionary.")

    node_type = node_dict.get("type")

    # --- Base Case: Reconstruct a Box object ---
    if node_type == "Box":
        return Box(
            label=node_dict["label"],
            center=node_dict["center"],
            dims=node_dict["lengths"],
            quaternion=node_dict["quaternion"]
        )

    # --- Recursive Cases for Internal Nodes ---
    elif node_type == "Union":
        # Recursively build the left and right children first
        left_child = dict_to_dsl(node_dict["left"])
        right_child = dict_to_dsl(node_dict["right"])
        return Union(left=left_child, right=right_child)

    elif node_type == "SymRef":
        child_obj = dict_to_dsl(node_dict["child"])
        return SymRef(
            child=child_obj,
            plane_normal=node_dict["plane_normal"],
            point_on_plane=node_dict["point_on_plane"]
        )

    elif node_type == "SymRot":
        child_obj = dict_to_dsl(node_dict["child"])
        return SymRot(
            child=child_obj,
            axis=node_dict["axis"],
            center=node_dict["center"],
            n_fold=node_dict["n_fold"]
        )

    elif node_type == "SymTrans":
        child_obj = dict_to_dsl(node_dict["child"])
        return SymTrans(
            child=child_obj,
            end_point=node_dict["end_point"],
            n_fold=node_dict["n_fold"]
        )

    # --- Error Case for unknown types ---
    else:
        raise ValueError(f"Unknown node type found in JSON: '{node_type}'")


def parse_json_to_dsl(json_string):
    """
    A convenient wrapper function that parses a JSON string into a DSL object tree.
    """
    # 1. Convert the JSON string into a Python dictionary
    data_dictionary = json.loads(json_string)
    
    # 2. Convert the dictionary into DSL objects
    return dict_to_dsl(data_dictionary)

# %%
# 'json_output' is the JSON string created in the previous step.

print("--- Parsing JSON back into Python objects... ---")

# Use the parser to reconstruct the entire object tree
reconstructed_dsl_root = parse_json_to_dsl(json_output)

print("--- Parse Complete. Verifying the result. ---")
print(f"The reconstructed object is of type: {type(reconstructed_dsl_root)}\n")

# To visually confirm it worked, print the reconstructed object.
# This should produce the nicely formatted text output.
print("--- Formatted String Output of the Reconstructed Object: ---")
print(reconstructed_dsl_root)
# Out:
# --- Parsing JSON back into Python objects... ---
# --- Parse Complete. Verifying the result. ---
# The reconstructed object is of type: <class '__main__.Union'>
#
# --- Formatted String Output of the Reconstructed Object: ---
# Union(
#     Union(
#         Box(label=1,
#                 center=[0.009, -0.359, 0.211],
#                 lengths=[0.967, 0.294, 0.960],
#                 quat=[0.0000, 0.0000, 0.0000, 1.0000]
#             ),
#         Union(
#             Union(
#                 Box(label=3,
#                         center=[-0.559, -0.282, 0.413],
#                         lengths=[0.214, 0.091, 0.068],
#                         quat=[0.0053, -0.0122, -0.0399, 0.9991]
#                     ),
#                 Union(
#                     Box(label=3,
#                             center=[0.562, -0.107, 0.425],
#                             lengths=[0.199, 0.441, 0.054],
#                             quat=[0.0000, 0.0000, 0.0000, 1.0000]
#                         ),
#                     SymRef(
#                         plane=[1.000, 0.013, 0.012],
#                         point_on_plane=[0.003, -0.067, 0.418]
#                     )(
#                         Union(
#                             Box(label=3,
#                                     center=[-0.627, -0.075, 0.410],
#                                     lengths=[0.083, 0.330, 0.079],
#                                     quat=[0.0000, 0.0000, 0.0000, 1.0000]
#                                 ),
#                             Box(label=3,
#                                     center=[0.661, 0.163, 0.196],
#                                     lengths=[0.263, 0.094, 0.659],
#                                     quat=[0.0000, 0.0000, 0.0000, 1.0000]
#                                 )
#                         )
#                     )
#                 )
#             ),
#             SymRef(
#                 plane=[1.000, -0.003, -0.007],
#                 point_on_plane=[0.003, -0.285, 0.010]
#             )(
#                 Union(
#                     Box(label=3,
#                             center=[-0.557, -0.283, 0.014],
#                             lengths=[0.198, 0.094, 0.057],
#                             quat=[0.0000, 0.0000, 0.0000, 1.0000]
#                         ),
#                     Box(label=3,
#                             center=[-0.625, -0.083, 0.014],
#                             lengths=[0.077, 0.328, 0.058],
#                             quat=[0.0000, 0.0000, 0.0000, 1.0000]
#                         )
#                 )
#             )
#         )
#     ),
#     Union(
#         Box(label=0,
#                 center=[-0.005, 0.438, -0.364],
#                 lengths=[1.065, 0.644, 0.156],
#                 quat=[0.0000, 0.0000, 0.0000, 1.0000]
#             ),
#         SymRef(
#             plane=[1.000, -0.024, -0.000],
#             point_on_plane=[0.014, 0.103, -0.453]
#         )(
#             Union(
#                 Box(label=0,
#                         center=[-0.138, 0.107, -0.453],
#                         lengths=[0.140, 0.786, 0.076],
#                         quat=[0.0000, 0.0000, 0.0000, 1.0000]
#                     ),
#                 Box(label=0,
#                         center=[-0.135, 0.046, -0.379],
#                         lengths=[0.104, 0.880, 0.223],
#                         quat=[0.0000, 0.0000, 0.0000, 1.0000]
#                     )
#             )
#         )
#     )
# )

# %%
import k3d
import numpy as np
from scipy.spatial.transform import Rotation

# Color map for part labels
LABEL_COLORS = {
    0: 0xFF0000,  # red   (Backrest)
    1: 0x00FF00,  # green (Seat)
    2: 0x0000FF,  # blue  (Leg)
    3: 0xFFFF00,  # yellow (Armrest)
    -1: 0x808080 # gray (Unknown)
}

def expand_dsl_tree(node):
    """
    Recursively traverses the DSL object tree and expands all symmetries to generate
    a final, flat list of box dictionaries.
    """
    # Base Case: A primitive Box
    if isinstance(node, Box):
        return [{
            'center': np.array(node.center),
            'lengths': np.array(node.lengths),
            'quaternion': np.array(node.quaternion),
            'label_id': node.label
        }]

    # Recursive Case: A Union of two parts
    elif isinstance(node, Union):
        left_boxes = expand_dsl_tree(node.left)
        right_boxes = expand_dsl_tree(node.right)
        return left_boxes + right_boxes

    # Recursive Case: A Symmetry operation
    elif isinstance(node, (SymRef, SymRot, SymTrans)):
        child_boxes = expand_dsl_tree(node.child)
        generated_boxes = []

        if isinstance(node, SymRef):
            plane_normal = np.array(node.plane) / (np.linalg.norm(node.plane) + 1e-8)
            point_on_plane = np.array(node.point_on_plane)
            for box in child_boxes:
                reflected_box = box.copy()
                vec_to_plane = box['center'] - point_on_plane
                dist = np.dot(vec_to_plane, plane_normal)
                reflected_box['center'] = box['center'] - 2 * dist * plane_normal
                R_orig = Rotation.from_quat(box['quaternion']).as_matrix()
                M_reflect = np.identity(3) - 2 * np.outer(plane_normal, plane_normal)
                R_new = M_reflect @ R_orig
                if np.linalg.det(R_new) < 0: R_new[:, 0] *= -1
                reflected_box['quaternion'] = Rotation.from_matrix(R_new).as_quat()
                generated_boxes.append(reflected_box)

        elif isinstance(node, SymRot):
            axis = np.array(node.axis) / (np.linalg.norm(node.axis) + 1e-8)
            center = np.array(node.center)
            for i in range(1, node.n):
                angle = 2 * np.pi * i / node.n
                symmetry_rot = Rotation.from_rotvec(angle * axis)
                for box in child_boxes:
                    rotated_box = box.copy()
                    vec_from_center = box['center'] - center
                    rotated_box['center'] = center + symmetry_rot.apply(vec_from_center)
                    original_rot = Rotation.from_quat(box['quaternion'])
                    rotated_box['quaternion'] = (symmetry_rot * original_rot).as_quat()
                    generated_boxes.append(rotated_box)

        elif isinstance(node, SymTrans):
            if child_boxes:
                start_point = child_boxes[0]['center']
                step_vector = (np.array(node.end_point) - start_point) / (node.n - 1)
                for i in range(1, node.n):
                    translation = i * step_vector
                    for box in child_boxes:
                        translated_box = box.copy()
                        translated_box['center'] = box['center'] + translation
                        generated_boxes.append(translated_box)
        
        return child_boxes + generated_boxes
    return []

def plot_dsl_with_k3d(dsl_root_node):
    """
    Top-level function to expand a DSL tree and plot it using k3d.
    """
    print("Expanding DSL tree for visualization...")
    final_boxes = expand_dsl_tree(dsl_root_node)
    print(f"Found {len(final_boxes)} total boxes after expansion.")

    plot = k3d.plot(name="Reconstructed DSL Shape")
    for box in final_boxes:
        center, lengths, quaternion, label_id = box["center"], box["lengths"], box["quaternion"], box.get("label_id", -1)
        
        rotation_matrix = Rotation.from_quat(quaternion).as_matrix()
        d1, d2, d3 = [col * length / 2 for col, length in zip(rotation_matrix.T, lengths)]

        corners = np.array([
            center-d1-d2-d3, center-d1+d2-d3, center+d1-d2-d3, center+d1+d2-d3,
            center-d1-d2+d3, center-d1+d2+d3, center+d1-d2+d3, center+d1+d2+d3
        ], dtype=np.float32)

        faces = np.array([
            [0,1,3], [0,3,2], [4,6,7], [4,7,5], [0,2,6], [0,6,4],
            [1,5,7], [1,7,3], [0,4,5], [0,5,1], [2,3,7], [2,7,6]
        ], dtype=np.uint32)

        color = LABEL_COLORS.get(label_id, LABEL_COLORS[-1])
        plot += k3d.mesh(corners, faces, color=color)

    plot.display()

# %%
plot_dsl_with_k3d(reconstructed_dsl_root)
# Out:
# Expanding DSL tree for visualization...
# Found 16 total boxes after expansion.
# Output()

# %%
import os
import pandas as pd
import json

# --- Configuration ---
CSV_FILE_PATH = "dataset_overview.csv"
OUTPUT_DIRECTORY = "dataset"

# --- Create the output directory if it doesn't already exist ---
os.makedirs(OUTPUT_DIRECTORY, exist_ok=True)
print(f"Output directory '{OUTPUT_DIRECTORY}' is ready.")

# --- Load the dataset overview, using the 'shape' column as the index ---
print(f"Loading shape data from '{CSV_FILE_PATH}'...")
df = pd.read_csv(CSV_FILE_PATH, index_col="shape")
total_shapes = len(df)
print(f"Found {total_shapes} shapes to process.")

# --- Main Processing Loop ---
# The .iterrows() method gives us the index (which we call 'shapename') and the row data
for i, (shapename, row) in enumerate(df.iterrows()):
    print(f"\n[{i+1}/{total_shapes}] Processing shape: {shapename}")
    
    try:
        # 1. Load the raw shape data
        shape_obj = ShapeData(row)
        
        # 2. Construct the initial binary tree
        shape_obj.construct_tree()
        
        # 3. Convert the tree to our custom DSL object representation
        dsl_representation = tree_to_dsl(shape_obj.tree.root)
        
        # 4. Convert the DSL object tree to a JSON-serializable dictionary
        dsl_dictionary = dsl_to_dict(dsl_representation)
        
        # 5. Define the output path using the 'shapename' from the first column
        #    This line creates filenames like "Bag_1.json", "Bag_10.json", etc.
        json_filepath = os.path.join(OUTPUT_DIRECTORY, f"{shapename}.json")
        
        # 6. Write the dictionary to the JSON file
        with open(json_filepath, 'w') as f:
            json.dump(dsl_dictionary, f, indent=2)
            
        print(f"✅ Successfully saved to {json_filepath}")

    except Exception as e:
        # If anything goes wrong, print an error and continue to the next shape
        print(f"❌ ERROR: Failed to process shape {shapename}. Reason: {e}")

print("\n--- All shapes processed. ---")
# Out:
# Output directory 'dataset' is ready.
# Loading shape data from 'dataset_overview.csv'...
# Found 6866 shapes to process.
#
# [1/6866] Processing shape: Bag_1
# Successfully constructed tree for shape: 13205
# ✅ Successfully saved to dataset/Bag_1.json
#
# [2/6866] Processing shape: Bag_10
# Successfully constructed tree for shape: 13226
# ✅ Successfully saved to dataset/Bag_10.json
#
# [3/6866] Processing shape: Bag_100
# Successfully constructed tree for shape: 9183
# ✅ Successfully saved to dataset/Bag_100.json
#
# [4/6866] Processing shape: Bag_101
# Successfully constructed tree for shape: 9186
# ✅ Successfully saved to dataset/Bag_101.json
#
# [5/6866] Processing shape: Bag_102
# Successfully constructed tree for shape: 9190
# ✅ Successfully saved to dataset/Bag_102.json
#
# [6/6866] Processing shape: Bag_103
# Successfully constructed tree for shape: 9201
# ✅ Successfully saved to dataset/Bag_103.json
#
# [7/6866] Processing shape: Bag_104
# Successfully constructed tree for shape: 9203
# ✅ Successfully saved to dataset/Bag_104.json
#
# [8/6866] Processing shape: Bag_105
# Successfully constructed tree for shape: 9206
# ✅ Successfully saved to dataset/Bag_105.json
#
# [9/6866] Processing shape: Bag_106
# Successfully constructed tree for shape: 9208
# ✅ Successfully saved to dataset/Bag_106.json
#
# [10/6866] Processing shape: Bag_107
# Successfully constructed tree for shape: 9210
# ✅ Successfully saved to dataset/Bag_107.json
#
# [11/6866] Processing shape: Bag_108
# Successfully constructed tree for shape: 9213
# ✅ Successfully saved to dataset/Bag_108.json
#
# [12/6866] Processing shape: Bag_109
# Successfully constructed tree for shape: 9220
# ✅ Successfully saved to dataset/Bag_109.json
#
# [13/6866] Processing shape: Bag_11
# Successfully constructed tree for shape: 8340
# ✅ Successfully saved to dataset/Bag_11.json
#
# [14/6866] Processing shape: Bag_110
# Successfully constructed tree for shape: 9224
# ✅ Successfully saved to dataset/Bag_110.json
#
# [15/6866] Processing shape: Bag_111
# Successfully constructed tree for shape: 9229
# ✅ Successfully saved to dataset/Bag_111.json
#
# [16/6866] Processing shape: Bag_112
# Successfully constructed tree for shape: 9231
# ✅ Successfully saved to dataset/Bag_112.json
#
# [17/6866] Processing shape: Bag_113
# Successfully constructed tree for shape: 9232
# ✅ Successfully saved to dataset/Bag_113.json
#
# [18/6866] Processing shape: Bag_114
# Successfully constructed tree for shape: 9233
# ✅ Successfully saved to dataset/Bag_114.json
#
# [19/6866] Processing shape: Bag_115
# Successfully constructed tree for shape: 9238
# ✅ Successfully saved to dataset/Bag_115.json
#
# [20/6866] Processing shape: Bag_116
# Successfully constructed tree for shape: 9244
# ✅ Successfully saved to dataset/Bag_116.json
#
# [21/6866] Processing shape: Bag_117
# Successfully constructed tree for shape: 9256
# ✅ Successfully saved to dataset/Bag_117.json
#
# [22/6866] Processing shape: Bag_118
# Successfully constructed tree for shape: 9257
# ✅ Successfully saved to dataset/Bag_118.json
#
# [23/6866] Processing shape: Bag_119
# Successfully constructed tree for shape: 9300
# ✅ Successfully saved to dataset/Bag_119.json
#
# [24/6866] Processing shape: Bag_12
# Successfully constructed tree for shape: 8383
# ✅ Successfully saved to dataset/Bag_12.json
#
# [25/6866] Processing shape: Bag_120
# Successfully constructed tree for shape: 9304
# ✅ Successfully saved to dataset/Bag_120.json
#
# [26/6866] Processing shape: Bag_121
# Successfully constructed tree for shape: 9307
# ✅ Successfully saved to dataset/Bag_121.json
#
# [27/6866] Processing shape: Bag_122
# Successfully constructed tree for shape: 9314
# ✅ Successfully saved to dataset/Bag_122.json
#
# [28/6866] Processing shape: Bag_123
# Successfully constructed tree for shape: 9315
# ✅ Successfully saved to dataset/Bag_123.json
#
# [29/6866] Processing shape: Bag_124
# Successfully constructed tree for shape: 9317
# ✅ Successfully saved to dataset/Bag_124.json
#
# [30/6866] Processing shape: Bag_125
# Successfully constructed tree for shape: 9337
# ✅ Successfully saved to dataset/Bag_125.json
#
# [31/6866] Processing shape: Bag_126
# Successfully constructed tree for shape: 9347
# ✅ Successfully saved to dataset/Bag_126.json
#
# [32/6866] Processing shape: Bag_127
# Successfully constructed tree for shape: 9376
# ✅ Successfully saved to dataset/Bag_127.json
#
# [33/6866] Processing shape: Bag_128
# Successfully constructed tree for shape: 9401
# ✅ Successfully saved to dataset/Bag_128.json
#
# [34/6866] Processing shape: Bag_129
# Successfully constructed tree for shape: 9407
# ✅ Successfully saved to dataset/Bag_129.json
#
# [35/6866] Processing shape: Bag_13
# Successfully constructed tree for shape: 8408
# ✅ Successfully saved to dataset/Bag_13.json
#
# [36/6866] Processing shape: Bag_130
# Successfully constructed tree for shape: 9413
# ✅ Successfully saved to dataset/Bag_130.json
#
# [37/6866] Processing shape: Bag_131
# Successfully constructed tree for shape: 9414
# ✅ Successfully saved to dataset/Bag_131.json
#
# [38/6866] Processing shape: Bag_132
# Successfully constructed tree for shape: 9427
# ✅ Successfully saved to dataset/Bag_132.json
#
# [39/6866] Processing shape: Bag_133
# Successfully constructed tree for shape: 9428
# ✅ Successfully saved to dataset/Bag_133.json
#
# [40/6866] Processing shape: Bag_134
# Successfully constructed tree for shape: 9429
# ✅ Successfully saved to dataset/Bag_134.json
#
# [41/6866] Processing shape: Bag_135
# Successfully constructed tree for shape: 9430
# ✅ Successfully saved to dataset/Bag_135.json
#
# [42/6866] Processing shape: Bag_136
# Successfully constructed tree for shape: 9432
# ✅ Successfully saved to dataset/Bag_136.json
#
# [43/6866] Processing shape: Bag_137
# Successfully constructed tree for shape: 9434
# ✅ Successfully saved to dataset/Bag_137.json
#
# [44/6866] Processing shape: Bag_138
# Successfully constructed tree for shape: 9435
# ✅ Successfully saved to dataset/Bag_138.json
#
# [45/6866] Processing shape: Bag_139
# Successfully constructed tree for shape: 9438
# ✅ Successfully saved to dataset/Bag_139.json
#
# [46/6866] Processing shape: Bag_14
# Successfully constructed tree for shape: 8409
# ✅ Successfully saved to dataset/Bag_14.json
#
# [47/6866] Processing shape: Bag_140
# Successfully constructed tree for shape: 9446
# ✅ Successfully saved to dataset/Bag_140.json
#
# [48/6866] Processing shape: Bag_141
# Successfully constructed tree for shape: 9515
# ✅ Successfully saved to dataset/Bag_141.json
#
# [49/6866] Processing shape: Bag_142
# Successfully constructed tree for shape: 9537
# ✅ Successfully saved to dataset/Bag_142.json
#
# [50/6866] Processing shape: Bag_143
# Successfully constructed tree for shape: 9544
# ✅ Successfully saved to dataset/Bag_143.json
#
# [51/6866] Processing shape: Bag_144
# Successfully constructed tree for shape: 9545
# ✅ Successfully saved to dataset/Bag_144.json
#
# [52/6866] Processing shape: Bag_145
# Successfully constructed tree for shape: 9546
# ✅ Successfully saved to dataset/Bag_145.json
#
# [53/6866] Processing shape: Bag_146
# Successfully constructed tree for shape: 9552
# ✅ Successfully saved to dataset/Bag_146.json
#
# [54/6866] Processing shape: Bag_147
# Successfully constructed tree for shape: 9554
# ✅ Successfully saved to dataset/Bag_147.json
#
# [55/6866] Processing shape: Bag_148
# Successfully constructed tree for shape: 9560
# ✅ Successfully saved to dataset/Bag_148.json
#
# [56/6866] Processing shape: Bag_149
# Successfully constructed tree for shape: 9562
# ✅ Successfully saved to dataset/Bag_149.json
#
# [57/6866] Processing shape: Bag_15
# Successfully constructed tree for shape: 8411
# ✅ Successfully saved to dataset/Bag_15.json
#
# [58/6866] Processing shape: Bag_150
# Successfully constructed tree for shape: 9563
# ✅ Successfully saved to dataset/Bag_150.json
#
# [59/6866] Processing shape: Bag_151
# Successfully constructed tree for shape: 9573
# ✅ Successfully saved to dataset/Bag_151.json
#
# [60/6866] Processing shape: Bag_152
# Successfully constructed tree for shape: 9574
# ✅ Successfully saved to dataset/Bag_152.json
#
# [61/6866] Processing shape: Bag_153
# Successfully constructed tree for shape: 9576
# ✅ Successfully saved to dataset/Bag_153.json
#
# [62/6866] Processing shape: Bag_154
# Successfully constructed tree for shape: 9583
# ✅ Successfully saved to dataset/Bag_154.json
#
# [63/6866] Processing shape: Bag_16
# Successfully constructed tree for shape: 8412
# ✅ Successfully saved to dataset/Bag_16.json
#
# [64/6866] Processing shape: Bag_17
# Successfully constructed tree for shape: 8430
# ✅ Successfully saved to dataset/Bag_17.json
#
# [65/6866] Processing shape: Bag_18
# Successfully constructed tree for shape: 8517
# ✅ Successfully saved to dataset/Bag_18.json
#
# [66/6866] Processing shape: Bag_19
# Successfully constructed tree for shape: 8532
# ✅ Successfully saved to dataset/Bag_19.json
#
# [67/6866] Processing shape: Bag_2
# Successfully constructed tree for shape: 13207
# ✅ Successfully saved to dataset/Bag_2.json
#
# [68/6866] Processing shape: Bag_20
# Successfully constructed tree for shape: 8541
# ✅ Successfully saved to dataset/Bag_20.json
#
# [69/6866] Processing shape: Bag_21
# Successfully constructed tree for shape: 8570
# ✅ Successfully saved to dataset/Bag_21.json
#
# [70/6866] Processing shape: Bag_22
# Successfully constructed tree for shape: 8571
# ✅ Successfully saved to dataset/Bag_22.json
#
# [71/6866] Processing shape: Bag_23
# Successfully constructed tree for shape: 8653
# ✅ Successfully saved to dataset/Bag_23.json
#
# [72/6866] Processing shape: Bag_24
# Successfully constructed tree for shape: 8668
# ✅ Successfully saved to dataset/Bag_24.json
#
# [73/6866] Processing shape: Bag_25
# Successfully constructed tree for shape: 8673
# ✅ Successfully saved to dataset/Bag_25.json
#
# [74/6866] Processing shape: Bag_26
# Successfully constructed tree for shape: 8693
# ✅ Successfully saved to dataset/Bag_26.json
#
# [75/6866] Processing shape: Bag_27
# Successfully constructed tree for shape: 8694
# ✅ Successfully saved to dataset/Bag_27.json
#
# [76/6866] Processing shape: Bag_28
# Successfully constructed tree for shape: 8713
# ✅ Successfully saved to dataset/Bag_28.json
#
# [77/6866] Processing shape: Bag_29
# Successfully constructed tree for shape: 8714
# ✅ Successfully saved to dataset/Bag_29.json
#
# [78/6866] Processing shape: Bag_3
# Successfully constructed tree for shape: 13208
# ✅ Successfully saved to dataset/Bag_3.json
#
# [79/6866] Processing shape: Bag_30
# Successfully constructed tree for shape: 8801
# ✅ Successfully saved to dataset/Bag_30.json
#
# [80/6866] Processing shape: Bag_31
# Successfully constructed tree for shape: 8821
# ✅ Successfully saved to dataset/Bag_31.json
#
# [81/6866] Processing shape: Bag_32
# Successfully constructed tree for shape: 8869
# ✅ Successfully saved to dataset/Bag_32.json
#
# [82/6866] Processing shape: Bag_33
# Successfully constructed tree for shape: 8871
# ✅ Successfully saved to dataset/Bag_33.json
#
# [83/6866] Processing shape: Bag_34
# Successfully constructed tree for shape: 8878
# ✅ Successfully saved to dataset/Bag_34.json
#
# [84/6866] Processing shape: Bag_35
# Successfully constructed tree for shape: 8879
# ✅ Successfully saved to dataset/Bag_35.json
#
# [85/6866] Processing shape: Bag_36
# Successfully constructed tree for shape: 8880
# ✅ Successfully saved to dataset/Bag_36.json
#
# [86/6866] Processing shape: Bag_37
# Successfully constructed tree for shape: 8886
# ✅ Successfully saved to dataset/Bag_37.json
#
# [87/6866] Processing shape: Bag_38
# Successfully constructed tree for shape: 8889
# ✅ Successfully saved to dataset/Bag_38.json
#
# [88/6866] Processing shape: Bag_39
# Successfully constructed tree for shape: 8894
# ✅ Successfully saved to dataset/Bag_39.json
#
# [89/6866] Processing shape: Bag_4
# Successfully constructed tree for shape: 13209
# ✅ Successfully saved to dataset/Bag_4.json
#
# [90/6866] Processing shape: Bag_40
# Successfully constructed tree for shape: 8899
# ✅ Successfully saved to dataset/Bag_40.json
#
# [91/6866] Processing shape: Bag_41
# Successfully constructed tree for shape: 8907
# ✅ Successfully saved to dataset/Bag_41.json
#
# [92/6866] Processing shape: Bag_42
# Successfully constructed tree for shape: 8908
# ✅ Successfully saved to dataset/Bag_42.json
#
# [93/6866] Processing shape: Bag_43
# Successfully constructed tree for shape: 8913
# ✅ Successfully saved to dataset/Bag_43.json
#
# [94/6866] Processing shape: Bag_44
# Successfully constructed tree for shape: 8917
# ✅ Successfully saved to dataset/Bag_44.json
#
# [95/6866] Processing shape: Bag_45
# Successfully constructed tree for shape: 8920
# ✅ Successfully saved to dataset/Bag_45.json
#
# [96/6866] Processing shape: Bag_46
# Successfully constructed tree for shape: 8922
# ✅ Successfully saved to dataset/Bag_46.json
#
# [97/6866] Processing shape: Bag_47
# Successfully constructed tree for shape: 8929
# ✅ Successfully saved to dataset/Bag_47.json
#
# [98/6866] Processing shape: Bag_48
# Successfully constructed tree for shape: 8932
# ✅ Successfully saved to dataset/Bag_48.json
#
# [99/6866] Processing shape: Bag_49
# Successfully constructed tree for shape: 8952
# ✅ Successfully saved to dataset/Bag_49.json
#
# [100/6866] Processing shape: Bag_5
# Successfully constructed tree for shape: 13213
# ✅ Successfully saved to dataset/Bag_5.json
#
# [101/6866] Processing shape: Bag_50
# Successfully constructed tree for shape: 8953
# ✅ Successfully saved to dataset/Bag_50.json
#
# [102/6866] Processing shape: Bag_51
# Successfully constructed tree for shape: 8960
# ✅ Successfully saved to dataset/Bag_51.json
#
# [103/6866] Processing shape: Bag_52
# Successfully constructed tree for shape: 8964
# ✅ Successfully saved to dataset/Bag_52.json
#
# [104/6866] Processing shape: Bag_53
# Successfully constructed tree for shape: 8968
# ✅ Successfully saved to dataset/Bag_53.json
#
# [105/6866] Processing shape: Bag_54
# Successfully constructed tree for shape: 8970
# ✅ Successfully saved to dataset/Bag_54.json
#
# [106/6866] Processing shape: Bag_55
# Successfully constructed tree for shape: 8986
# ✅ Successfully saved to dataset/Bag_55.json
#
# [107/6866] Processing shape: Bag_56
# Successfully constructed tree for shape: 8996
# ✅ Successfully saved to dataset/Bag_56.json
#
# [108/6866] Processing shape: Bag_57
# Successfully constructed tree for shape: 9001
# ✅ Successfully saved to dataset/Bag_57.json
#
# [109/6866] Processing shape: Bag_58
# Successfully constructed tree for shape: 9009
# ✅ Successfully saved to dataset/Bag_58.json
#
# [110/6866] Processing shape: Bag_59
# Successfully constructed tree for shape: 9012
# ✅ Successfully saved to dataset/Bag_59.json
#
# [111/6866] Processing shape: Bag_6
# Successfully constructed tree for shape: 13216
# ✅ Successfully saved to dataset/Bag_6.json
#
# [112/6866] Processing shape: Bag_60
# Successfully constructed tree for shape: 9021
# ✅ Successfully saved to dataset/Bag_60.json
#
# [113/6866] Processing shape: Bag_61
# Successfully constructed tree for shape: 9029
# ✅ Successfully saved to dataset/Bag_61.json
#
# [114/6866] Processing shape: Bag_62
# Successfully constructed tree for shape: 9034
# ✅ Successfully saved to dataset/Bag_62.json
#
# [115/6866] Processing shape: Bag_63
# Successfully constructed tree for shape: 9039
# ✅ Successfully saved to dataset/Bag_63.json
#
# [116/6866] Processing shape: Bag_64
# Successfully constructed tree for shape: 9047
# ✅ Successfully saved to dataset/Bag_64.json
#
# [117/6866] Processing shape: Bag_65
# Successfully constructed tree for shape: 9052
# ✅ Successfully saved to dataset/Bag_65.json
#
# [118/6866] Processing shape: Bag_66
# Successfully constructed tree for shape: 9058
# ✅ Successfully saved to dataset/Bag_66.json
#
# [119/6866] Processing shape: Bag_67
# Successfully constructed tree for shape: 9060
# ✅ Successfully saved to dataset/Bag_67.json
#
# [120/6866] Processing shape: Bag_68
# Successfully constructed tree for shape: 9063
# ✅ Successfully saved to dataset/Bag_68.json
#
# [121/6866] Processing shape: Bag_69
# Successfully constructed tree for shape: 9066
# ✅ Successfully saved to dataset/Bag_69.json
#
# [122/6866] Processing shape: Bag_7
# Successfully constructed tree for shape: 13218
# ✅ Successfully saved to dataset/Bag_7.json
#
# [123/6866] Processing shape: Bag_70
# Successfully constructed tree for shape: 9067
# ✅ Successfully saved to dataset/Bag_70.json
#
# [124/6866] Processing shape: Bag_71
# Successfully constructed tree for shape: 9069
# ✅ Successfully saved to dataset/Bag_71.json
#
# [125/6866] Processing shape: Bag_72
# Successfully constructed tree for shape: 9074
# ✅ Successfully saved to dataset/Bag_72.json
#
# [126/6866] Processing shape: Bag_73
# Successfully constructed tree for shape: 9077
# ✅ Successfully saved to dataset/Bag_73.json
#
# [127/6866] Processing shape: Bag_74
# Successfully constructed tree for shape: 9078
# ✅ Successfully saved to dataset/Bag_74.json
#
# [128/6866] Processing shape: Bag_75
# Successfully constructed tree for shape: 9079
# ✅ Successfully saved to dataset/Bag_75.json
#
# [129/6866] Processing shape: Bag_76
# Successfully constructed tree for shape: 9080
# ✅ Successfully saved to dataset/Bag_76.json
#
# [130/6866] Processing shape: Bag_77
# Successfully constructed tree for shape: 9081
# ✅ Successfully saved to dataset/Bag_77.json
#
# [131/6866] Processing shape: Bag_78
# Successfully constructed tree for shape: 9086
# ✅ Successfully saved to dataset/Bag_78.json
#
# [132/6866] Processing shape: Bag_79
# Successfully constructed tree for shape: 9087
# ✅ Successfully saved to dataset/Bag_79.json
#
# [133/6866] Processing shape: Bag_8
# Successfully constructed tree for shape: 13220
# ✅ Successfully saved to dataset/Bag_8.json
#
# [134/6866] Processing shape: Bag_80
# Successfully constructed tree for shape: 9090
# ✅ Successfully saved to dataset/Bag_80.json
#
# [135/6866] Processing shape: Bag_81
# Successfully constructed tree for shape: 9091
# ✅ Successfully saved to dataset/Bag_81.json
#
# [136/6866] Processing shape: Bag_82
# Successfully constructed tree for shape: 9096
# ✅ Successfully saved to dataset/Bag_82.json
#
# [137/6866] Processing shape: Bag_83
# Successfully constructed tree for shape: 9105
# ✅ Successfully saved to dataset/Bag_83.json
#
# [138/6866] Processing shape: Bag_84
# Successfully constructed tree for shape: 9123
# ✅ Successfully saved to dataset/Bag_84.json
#
# [139/6866] Processing shape: Bag_85
# Successfully constructed tree for shape: 9125
# ✅ Successfully saved to dataset/Bag_85.json
#
# [140/6866] Processing shape: Bag_86
# Successfully constructed tree for shape: 9126
# ✅ Successfully saved to dataset/Bag_86.json
#
# [141/6866] Processing shape: Bag_87
# Successfully constructed tree for shape: 9129
# ✅ Successfully saved to dataset/Bag_87.json
#
# [142/6866] Processing shape: Bag_88
# Successfully constructed tree for shape: 9133
# ✅ Successfully saved to dataset/Bag_88.json
#
# [143/6866] Processing shape: Bag_89
# Successfully constructed tree for shape: 9136
# ✅ Successfully saved to dataset/Bag_89.json
#
# [144/6866] Processing shape: Bag_9
# Successfully constructed tree for shape: 13221
# ✅ Successfully saved to dataset/Bag_9.json
#
# [145/6866] Processing shape: Bag_90
# Successfully constructed tree for shape: 9138
# ✅ Successfully saved to dataset/Bag_90.json
#
# [146/6866] Processing shape: Bag_91
# Successfully constructed tree for shape: 9139
# ✅ Successfully saved to dataset/Bag_91.json
#
# [147/6866] Processing shape: Bag_92
# Successfully constructed tree for shape: 9143
# ✅ Successfully saved to dataset/Bag_92.json
#
# [148/6866] Processing shape: Bag_93
# Successfully constructed tree for shape: 9144
# ✅ Successfully saved to dataset/Bag_93.json
#
# [149/6866] Processing shape: Bag_94
# Successfully constructed tree for shape: 9158
# ✅ Successfully saved to dataset/Bag_94.json
#
# [150/6866] Processing shape: Bag_95
# Successfully constructed tree for shape: 9160
# ✅ Successfully saved to dataset/Bag_95.json
#
# [151/6866] Processing shape: Bag_96
# Successfully constructed tree for shape: 9173
# ✅ Successfully saved to dataset/Bag_96.json
#
# [152/6866] Processing shape: Bag_97
# Successfully constructed tree for shape: 9174
# ✅ Successfully saved to dataset/Bag_97.json
#
# [153/6866] Processing shape: Bag_98
# Successfully constructed tree for shape: 9176
# ✅ Successfully saved to dataset/Bag_98.json
#
# [154/6866] Processing shape: Bag_99
# Successfully constructed tree for shape: 9178
# ✅ Successfully saved to dataset/Bag_99.json
#
# [155/6866] Processing shape: Bottle_1
# Successfully constructed tree for shape: 3380
# ✅ Successfully saved to dataset/Bottle_1.json
#
# [156/6866] Processing shape: Bottle_10
# Successfully constructed tree for shape: 3416
# ✅ Successfully saved to dataset/Bottle_10.json
#
# [157/6866] Processing shape: Bottle_100
# Successfully constructed tree for shape: 3593
# ✅ Successfully saved to dataset/Bottle_100.json
#
# [158/6866] Processing shape: Bottle_101
# Successfully constructed tree for shape: 3594
# ✅ Successfully saved to dataset/Bottle_101.json
#
# [159/6866] Processing shape: Bottle_102
# Successfully constructed tree for shape: 3595
# ✅ Successfully saved to dataset/Bottle_102.json
#
# [160/6866] Processing shape: Bottle_103
# Successfully constructed tree for shape: 3596
# ✅ Successfully saved to dataset/Bottle_103.json
#
# [161/6866] Processing shape: Bottle_104
# Successfully constructed tree for shape: 3597
# ✅ Successfully saved to dataset/Bottle_104.json
#
# [162/6866] Processing shape: Bottle_105
# Successfully constructed tree for shape: 3598
# ✅ Successfully saved to dataset/Bottle_105.json
#
# [163/6866] Processing shape: Bottle_106
# Successfully constructed tree for shape: 3599
# ✅ Successfully saved to dataset/Bottle_106.json
#
# [164/6866] Processing shape: Bottle_107
# Successfully constructed tree for shape: 3600
# ✅ Successfully saved to dataset/Bottle_107.json
#
# [165/6866] Processing shape: Bottle_108
# Successfully constructed tree for shape: 3601
# ✅ Successfully saved to dataset/Bottle_108.json
#
# [166/6866] Processing shape: Bottle_109
# Successfully constructed tree for shape: 3602
# ✅ Successfully saved to dataset/Bottle_109.json
#
# [167/6866] Processing shape: Bottle_11
# Successfully constructed tree for shape: 3418
# ✅ Successfully saved to dataset/Bottle_11.json
#
# [168/6866] Processing shape: Bottle_110
# Successfully constructed tree for shape: 3603
# ✅ Successfully saved to dataset/Bottle_110.json
#
# [169/6866] Processing shape: Bottle_111
# Successfully constructed tree for shape: 3604
# ✅ Successfully saved to dataset/Bottle_111.json
#
# [170/6866] Processing shape: Bottle_112
# Successfully constructed tree for shape: 3605
# ✅ Successfully saved to dataset/Bottle_112.json
#
# [171/6866] Processing shape: Bottle_113
# Successfully constructed tree for shape: 3606
# ✅ Successfully saved to dataset/Bottle_113.json
#
# [172/6866] Processing shape: Bottle_114
# Successfully constructed tree for shape: 3607
# ✅ Successfully saved to dataset/Bottle_114.json
#
# [173/6866] Processing shape: Bottle_115
# Successfully constructed tree for shape: 3608
# ✅ Successfully saved to dataset/Bottle_115.json
#
# [174/6866] Processing shape: Bottle_116
# Successfully constructed tree for shape: 3609
# ✅ Successfully saved to dataset/Bottle_116.json
#
# [175/6866] Processing shape: Bottle_117
# Successfully constructed tree for shape: 3610
# ✅ Successfully saved to dataset/Bottle_117.json
#
# [176/6866] Processing shape: Bottle_118
# Successfully constructed tree for shape: 3611
# ✅ Successfully saved to dataset/Bottle_118.json
#
# [177/6866] Processing shape: Bottle_119
# Successfully constructed tree for shape: 3612
# ✅ Successfully saved to dataset/Bottle_119.json
#
# [178/6866] Processing shape: Bottle_12
# Successfully constructed tree for shape: 3422
# ✅ Successfully saved to dataset/Bottle_12.json
#
# [179/6866] Processing shape: Bottle_120
# Successfully constructed tree for shape: 3613
# ✅ Successfully saved to dataset/Bottle_120.json
#
# [180/6866] Processing shape: Bottle_121
# Successfully constructed tree for shape: 3614
# ✅ Successfully saved to dataset/Bottle_121.json
#
# [181/6866] Processing shape: Bottle_122
# Successfully constructed tree for shape: 3615
# ✅ Successfully saved to dataset/Bottle_122.json
#
# [182/6866] Processing shape: Bottle_123
# Successfully constructed tree for shape: 3616
# ✅ Successfully saved to dataset/Bottle_123.json
#
# [183/6866] Processing shape: Bottle_124
# Successfully constructed tree for shape: 3617
# ✅ Successfully saved to dataset/Bottle_124.json
#
# [184/6866] Processing shape: Bottle_125
# Successfully constructed tree for shape: 3618
# ✅ Successfully saved to dataset/Bottle_125.json
#
# [185/6866] Processing shape: Bottle_126
# Successfully constructed tree for shape: 3619
# ✅ Successfully saved to dataset/Bottle_126.json
#
# [186/6866] Processing shape: Bottle_127
# Successfully constructed tree for shape: 3620
# ✅ Successfully saved to dataset/Bottle_127.json
#
# [187/6866] Processing shape: Bottle_128
# Successfully constructed tree for shape: 3621
# ✅ Successfully saved to dataset/Bottle_128.json
#
# [188/6866] Processing shape: Bottle_129
# Successfully constructed tree for shape: 3622
# ✅ Successfully saved to dataset/Bottle_129.json
#
# [189/6866] Processing shape: Bottle_13
# Successfully constructed tree for shape: 3424
# ✅ Successfully saved to dataset/Bottle_13.json
#
# [190/6866] Processing shape: Bottle_130
# Successfully constructed tree for shape: 3623
# ✅ Successfully saved to dataset/Bottle_130.json
#
# [191/6866] Processing shape: Bottle_131
# Successfully constructed tree for shape: 3624
# ✅ Successfully saved to dataset/Bottle_131.json
#
# [192/6866] Processing shape: Bottle_132
# Successfully constructed tree for shape: 3625
# ✅ Successfully saved to dataset/Bottle_132.json
#
# [193/6866] Processing shape: Bottle_133
# Successfully constructed tree for shape: 3628
# ✅ Successfully saved to dataset/Bottle_133.json
#
# [194/6866] Processing shape: Bottle_134
# Successfully constructed tree for shape: 3629
# ✅ Successfully saved to dataset/Bottle_134.json
#
# [195/6866] Processing shape: Bottle_135
# Successfully constructed tree for shape: 3630
# ✅ Successfully saved to dataset/Bottle_135.json
#
# [196/6866] Processing shape: Bottle_136
# Successfully constructed tree for shape: 3631
# ✅ Successfully saved to dataset/Bottle_136.json
#
# [197/6866] Processing shape: Bottle_137
# Successfully constructed tree for shape: 3632
# ✅ Successfully saved to dataset/Bottle_137.json
#
# [198/6866] Processing shape: Bottle_138
# Successfully constructed tree for shape: 3633
# ✅ Successfully saved to dataset/Bottle_138.json
#
# [199/6866] Processing shape: Bottle_139
# Successfully constructed tree for shape: 3635
# ✅ Successfully saved to dataset/Bottle_139.json
#
# [200/6866] Processing shape: Bottle_14
# Successfully constructed tree for shape: 3425
# ✅ Successfully saved to dataset/Bottle_14.json
#
# [201/6866] Processing shape: Bottle_140
# Successfully constructed tree for shape: 3636
# ✅ Successfully saved to dataset/Bottle_140.json
#
# [202/6866] Processing shape: Bottle_141
# Successfully constructed tree for shape: 3637
# ✅ Successfully saved to dataset/Bottle_141.json
#
# [203/6866] Processing shape: Bottle_142
# Successfully constructed tree for shape: 3638
# ✅ Successfully saved to dataset/Bottle_142.json
#
# [204/6866] Processing shape: Bottle_143
# Successfully constructed tree for shape: 3639
# ✅ Successfully saved to dataset/Bottle_143.json
#
# [205/6866] Processing shape: Bottle_144
# Successfully constructed tree for shape: 3640
# ✅ Successfully saved to dataset/Bottle_144.json
#
# [206/6866] Processing shape: Bottle_145
# Successfully constructed tree for shape: 3641
# ✅ Successfully saved to dataset/Bottle_145.json
#
# [207/6866] Processing shape: Bottle_146
# Successfully constructed tree for shape: 3642
# ✅ Successfully saved to dataset/Bottle_146.json
#
# [208/6866] Processing shape: Bottle_147
# Successfully constructed tree for shape: 3643
# ✅ Successfully saved to dataset/Bottle_147.json
#
# [209/6866] Processing shape: Bottle_148
# Successfully constructed tree for shape: 3644
# ✅ Successfully saved to dataset/Bottle_148.json
#
# [210/6866] Processing shape: Bottle_149
# Successfully constructed tree for shape: 3645
# ✅ Successfully saved to dataset/Bottle_149.json
#
# [211/6866] Processing shape: Bottle_15
# Successfully constructed tree for shape: 3428
# ✅ Successfully saved to dataset/Bottle_15.json
#
# [212/6866] Processing shape: Bottle_150
# Successfully constructed tree for shape: 3646
# ✅ Successfully saved to dataset/Bottle_150.json
#
# [213/6866] Processing shape: Bottle_151
# Successfully constructed tree for shape: 3647
# ✅ Successfully saved to dataset/Bottle_151.json
#
# [214/6866] Processing shape: Bottle_152
# Successfully constructed tree for shape: 3648
# ✅ Successfully saved to dataset/Bottle_152.json
#
# [215/6866] Processing shape: Bottle_153
# Successfully constructed tree for shape: 3649
# ✅ Successfully saved to dataset/Bottle_153.json
#
# [216/6866] Processing shape: Bottle_154
# Successfully constructed tree for shape: 3650
# ✅ Successfully saved to dataset/Bottle_154.json
#
# [217/6866] Processing shape: Bottle_155
# Successfully constructed tree for shape: 3651
# ✅ Successfully saved to dataset/Bottle_155.json
#
# [218/6866] Processing shape: Bottle_156
# Successfully constructed tree for shape: 3654
# ✅ Successfully saved to dataset/Bottle_156.json
#
# [219/6866] Processing shape: Bottle_157
# Successfully constructed tree for shape: 3655
# ✅ Successfully saved to dataset/Bottle_157.json
#
# [220/6866] Processing shape: Bottle_158
# Successfully constructed tree for shape: 3656
# ✅ Successfully saved to dataset/Bottle_158.json
#
# [221/6866] Processing shape: Bottle_159
# Successfully constructed tree for shape: 3657
# ✅ Successfully saved to dataset/Bottle_159.json
#
# [222/6866] Processing shape: Bottle_16
# Successfully constructed tree for shape: 3432
# ✅ Successfully saved to dataset/Bottle_16.json
#
# [223/6866] Processing shape: Bottle_160
# Successfully constructed tree for shape: 3658
# ✅ Successfully saved to dataset/Bottle_160.json
#
# [224/6866] Processing shape: Bottle_161
# Successfully constructed tree for shape: 3660
# ✅ Successfully saved to dataset/Bottle_161.json
#
# [225/6866] Processing shape: Bottle_162
# Successfully constructed tree for shape: 3661
# ✅ Successfully saved to dataset/Bottle_162.json
#
# [226/6866] Processing shape: Bottle_163
# Successfully constructed tree for shape: 3662
# ✅ Successfully saved to dataset/Bottle_163.json
#
# [227/6866] Processing shape: Bottle_164
# Successfully constructed tree for shape: 3663
# ✅ Successfully saved to dataset/Bottle_164.json
#
# [228/6866] Processing shape: Bottle_165
# Successfully constructed tree for shape: 3664
# ✅ Successfully saved to dataset/Bottle_165.json
#
# [229/6866] Processing shape: Bottle_166
# Successfully constructed tree for shape: 3665
# ✅ Successfully saved to dataset/Bottle_166.json
#
# [230/6866] Processing shape: Bottle_167
# Successfully constructed tree for shape: 3666
# ✅ Successfully saved to dataset/Bottle_167.json
#
# [231/6866] Processing shape: Bottle_168
# Successfully constructed tree for shape: 3667
# ✅ Successfully saved to dataset/Bottle_168.json
#
# [232/6866] Processing shape: Bottle_169
# Successfully constructed tree for shape: 3668
# ✅ Successfully saved to dataset/Bottle_169.json
#
# [233/6866] Processing shape: Bottle_17
# Successfully constructed tree for shape: 3443
# ✅ Successfully saved to dataset/Bottle_17.json
#
# [234/6866] Processing shape: Bottle_170
# Successfully constructed tree for shape: 3669
# ✅ Successfully saved to dataset/Bottle_170.json
#
# [235/6866] Processing shape: Bottle_171
# Successfully constructed tree for shape: 3672
# ✅ Successfully saved to dataset/Bottle_171.json
#
# [236/6866] Processing shape: Bottle_172
# Successfully constructed tree for shape: 3673
# ✅ Successfully saved to dataset/Bottle_172.json
#
# [237/6866] Processing shape: Bottle_173
# Successfully constructed tree for shape: 3674
# ✅ Successfully saved to dataset/Bottle_173.json
#
# [238/6866] Processing shape: Bottle_174
# Successfully constructed tree for shape: 3675
# ✅ Successfully saved to dataset/Bottle_174.json
#
# [239/6866] Processing shape: Bottle_175
# Successfully constructed tree for shape: 3676
# ✅ Successfully saved to dataset/Bottle_175.json
#
# [240/6866] Processing shape: Bottle_176
# Successfully constructed tree for shape: 3677
# ✅ Successfully saved to dataset/Bottle_176.json
#
# [241/6866] Processing shape: Bottle_177
# Successfully constructed tree for shape: 3678
# ✅ Successfully saved to dataset/Bottle_177.json
#
# [242/6866] Processing shape: Bottle_178
# Successfully constructed tree for shape: 3679
# ✅ Successfully saved to dataset/Bottle_178.json
#
# [243/6866] Processing shape: Bottle_179
# Successfully constructed tree for shape: 3680
# ✅ Successfully saved to dataset/Bottle_179.json
#
# [244/6866] Processing shape: Bottle_18
# Successfully constructed tree for shape: 3449
# ✅ Successfully saved to dataset/Bottle_18.json
#
# [245/6866] Processing shape: Bottle_180
# Successfully constructed tree for shape: 3681
# ✅ Successfully saved to dataset/Bottle_180.json
#
# [246/6866] Processing shape: Bottle_181
# Successfully constructed tree for shape: 3682
# ✅ Successfully saved to dataset/Bottle_181.json
#
# [247/6866] Processing shape: Bottle_182
# Successfully constructed tree for shape: 3683
# ✅ Successfully saved to dataset/Bottle_182.json
#
# [248/6866] Processing shape: Bottle_183
# Successfully constructed tree for shape: 3684
# ✅ Successfully saved to dataset/Bottle_183.json
#
# [249/6866] Processing shape: Bottle_184
# Successfully constructed tree for shape: 3685
# ✅ Successfully saved to dataset/Bottle_184.json
#
# [250/6866] Processing shape: Bottle_185
# Successfully constructed tree for shape: 3686
# ✅ Successfully saved to dataset/Bottle_185.json
#
# [251/6866] Processing shape: Bottle_186
# Successfully constructed tree for shape: 3687
# ✅ Successfully saved to dataset/Bottle_186.json
#
# [252/6866] Processing shape: Bottle_187
# Successfully constructed tree for shape: 3689
# ✅ Successfully saved to dataset/Bottle_187.json
#
# [253/6866] Processing shape: Bottle_188
# Successfully constructed tree for shape: 3690
# ✅ Successfully saved to dataset/Bottle_188.json
#
# [254/6866] Processing shape: Bottle_189
# Successfully constructed tree for shape: 3691
# ✅ Successfully saved to dataset/Bottle_189.json
#
# [255/6866] Processing shape: Bottle_19
# Successfully constructed tree for shape: 3451
# ✅ Successfully saved to dataset/Bottle_19.json
#
# [256/6866] Processing shape: Bottle_190
# Successfully constructed tree for shape: 3692
# ✅ Successfully saved to dataset/Bottle_190.json
#
# [257/6866] Processing shape: Bottle_191
# Successfully constructed tree for shape: 3693
# ✅ Successfully saved to dataset/Bottle_191.json
#
# [258/6866] Processing shape: Bottle_192
# Successfully constructed tree for shape: 3695
# ✅ Successfully saved to dataset/Bottle_192.json
#
# [259/6866] Processing shape: Bottle_193
# Successfully constructed tree for shape: 3696
# ✅ Successfully saved to dataset/Bottle_193.json
#
# [260/6866] Processing shape: Bottle_194
# Successfully constructed tree for shape: 3697
# ✅ Successfully saved to dataset/Bottle_194.json
#
# [261/6866] Processing shape: Bottle_195
# Successfully constructed tree for shape: 3699
# ✅ Successfully saved to dataset/Bottle_195.json
#
# [262/6866] Processing shape: Bottle_196
# Successfully constructed tree for shape: 3700
# ✅ Successfully saved to dataset/Bottle_196.json
#
# [263/6866] Processing shape: Bottle_197
# Successfully constructed tree for shape: 3701
# ✅ Successfully saved to dataset/Bottle_197.json
#
# [264/6866] Processing shape: Bottle_198
# Successfully constructed tree for shape: 3702
# ✅ Successfully saved to dataset/Bottle_198.json
#
# [265/6866] Processing shape: Bottle_199
# Successfully constructed tree for shape: 3703
# ✅ Successfully saved to dataset/Bottle_199.json
#
# [266/6866] Processing shape: Bottle_2
# Successfully constructed tree for shape: 3381
# ✅ Successfully saved to dataset/Bottle_2.json
#
# [267/6866] Processing shape: Bottle_20
# Successfully constructed tree for shape: 3452
# ✅ Successfully saved to dataset/Bottle_20.json
#
# [268/6866] Processing shape: Bottle_200
# Successfully constructed tree for shape: 3704
# ✅ Successfully saved to dataset/Bottle_200.json
#
# [269/6866] Processing shape: Bottle_201
# Successfully constructed tree for shape: 3705
# ✅ Successfully saved to dataset/Bottle_201.json
#
# [270/6866] Processing shape: Bottle_202
# Successfully constructed tree for shape: 3706
# ✅ Successfully saved to dataset/Bottle_202.json
#
# [271/6866] Processing shape: Bottle_203
# Successfully constructed tree for shape: 3707
# ✅ Successfully saved to dataset/Bottle_203.json
#
# [272/6866] Processing shape: Bottle_204
# Successfully constructed tree for shape: 3708
# ✅ Successfully saved to dataset/Bottle_204.json
#
# [273/6866] Processing shape: Bottle_205
# Successfully constructed tree for shape: 3710
# ✅ Successfully saved to dataset/Bottle_205.json
#
# [274/6866] Processing shape: Bottle_206
# Successfully constructed tree for shape: 3711
# ✅ Successfully saved to dataset/Bottle_206.json
#
# [275/6866] Processing shape: Bottle_207
# Successfully constructed tree for shape: 3713
# ✅ Successfully saved to dataset/Bottle_207.json
#
# [276/6866] Processing shape: Bottle_208
# Successfully constructed tree for shape: 3714
# ✅ Successfully saved to dataset/Bottle_208.json
#
# [277/6866] Processing shape: Bottle_209
# Successfully constructed tree for shape: 3715
# ✅ Successfully saved to dataset/Bottle_209.json
#
# [278/6866] Processing shape: Bottle_21
# Successfully constructed tree for shape: 3454
# ✅ Successfully saved to dataset/Bottle_21.json
#
# [279/6866] Processing shape: Bottle_210
# Successfully constructed tree for shape: 3716
# ✅ Successfully saved to dataset/Bottle_210.json
#
# [280/6866] Processing shape: Bottle_211
# Successfully constructed tree for shape: 3717
# ✅ Successfully saved to dataset/Bottle_211.json
#
# [281/6866] Processing shape: Bottle_212
# Successfully constructed tree for shape: 3718
# ✅ Successfully saved to dataset/Bottle_212.json
#
# [282/6866] Processing shape: Bottle_213
# Successfully constructed tree for shape: 3719
# ✅ Successfully saved to dataset/Bottle_213.json
#
# [283/6866] Processing shape: Bottle_214
# Successfully constructed tree for shape: 3720
# ✅ Successfully saved to dataset/Bottle_214.json
#
# [284/6866] Processing shape: Bottle_215
# Successfully constructed tree for shape: 3721
# ✅ Successfully saved to dataset/Bottle_215.json
#
# [285/6866] Processing shape: Bottle_216
# Successfully constructed tree for shape: 3722
# ✅ Successfully saved to dataset/Bottle_216.json
#
# [286/6866] Processing shape: Bottle_217
# Successfully constructed tree for shape: 3723
# ✅ Successfully saved to dataset/Bottle_217.json
#
# [287/6866] Processing shape: Bottle_218
# Successfully constructed tree for shape: 3724
# ✅ Successfully saved to dataset/Bottle_218.json
#
# [288/6866] Processing shape: Bottle_219
# Successfully constructed tree for shape: 3725
# ✅ Successfully saved to dataset/Bottle_219.json
#
# [289/6866] Processing shape: Bottle_22
# Successfully constructed tree for shape: 3457
# ✅ Successfully saved to dataset/Bottle_22.json
#
# [290/6866] Processing shape: Bottle_220
# Successfully constructed tree for shape: 3726
# ✅ Successfully saved to dataset/Bottle_220.json
#
# [291/6866] Processing shape: Bottle_221
# Successfully constructed tree for shape: 3727
# ✅ Successfully saved to dataset/Bottle_221.json
#
# [292/6866] Processing shape: Bottle_222
# Successfully constructed tree for shape: 3728
# ✅ Successfully saved to dataset/Bottle_222.json
#
# [293/6866] Processing shape: Bottle_223
# Successfully constructed tree for shape: 3729
# ✅ Successfully saved to dataset/Bottle_223.json
#
# [294/6866] Processing shape: Bottle_224
# Successfully constructed tree for shape: 3730
# ✅ Successfully saved to dataset/Bottle_224.json
#
# [295/6866] Processing shape: Bottle_225
# Successfully constructed tree for shape: 3732
# ✅ Successfully saved to dataset/Bottle_225.json
#
# [296/6866] Processing shape: Bottle_226
# Successfully constructed tree for shape: 3734
# ✅ Successfully saved to dataset/Bottle_226.json
#
# [297/6866] Processing shape: Bottle_227
# Successfully constructed tree for shape: 3735
# ✅ Successfully saved to dataset/Bottle_227.json
#
# [298/6866] Processing shape: Bottle_228
# Successfully constructed tree for shape: 3736
# ✅ Successfully saved to dataset/Bottle_228.json
#
# [299/6866] Processing shape: Bottle_229
# Successfully constructed tree for shape: 3737
# ✅ Successfully saved to dataset/Bottle_229.json
#
# [300/6866] Processing shape: Bottle_23
# Successfully constructed tree for shape: 3459
# ✅ Successfully saved to dataset/Bottle_23.json
#
# [301/6866] Processing shape: Bottle_230
# Successfully constructed tree for shape: 3738
# ✅ Successfully saved to dataset/Bottle_230.json
#
# [302/6866] Processing shape: Bottle_231
# Successfully constructed tree for shape: 3740
# ✅ Successfully saved to dataset/Bottle_231.json
#
# [303/6866] Processing shape: Bottle_232
# Successfully constructed tree for shape: 3741
# ✅ Successfully saved to dataset/Bottle_232.json
#
# [304/6866] Processing shape: Bottle_233
# Successfully constructed tree for shape: 3742
# ✅ Successfully saved to dataset/Bottle_233.json
#
# [305/6866] Processing shape: Bottle_234
# Successfully constructed tree for shape: 3743
# ✅ Successfully saved to dataset/Bottle_234.json
#
# [306/6866] Processing shape: Bottle_235
# Successfully constructed tree for shape: 3744
# ✅ Successfully saved to dataset/Bottle_235.json
#
# [307/6866] Processing shape: Bottle_236
# Successfully constructed tree for shape: 3745
# ✅ Successfully saved to dataset/Bottle_236.json
#
# [308/6866] Processing shape: Bottle_237
# Successfully constructed tree for shape: 3747
# ✅ Successfully saved to dataset/Bottle_237.json
#
# [309/6866] Processing shape: Bottle_238
# Successfully constructed tree for shape: 3748
# ✅ Successfully saved to dataset/Bottle_238.json
#
# [310/6866] Processing shape: Bottle_239
# Successfully constructed tree for shape: 3749
# ✅ Successfully saved to dataset/Bottle_239.json
#
# [311/6866] Processing shape: Bottle_24
# Successfully constructed tree for shape: 3460
# ✅ Successfully saved to dataset/Bottle_24.json
#
# [312/6866] Processing shape: Bottle_240
# Successfully constructed tree for shape: 3752
# ✅ Successfully saved to dataset/Bottle_240.json
#
# [313/6866] Processing shape: Bottle_241
# Successfully constructed tree for shape: 3753
# ✅ Successfully saved to dataset/Bottle_241.json
#
# [314/6866] Processing shape: Bottle_242
# Successfully constructed tree for shape: 3756
# ✅ Successfully saved to dataset/Bottle_242.json
#
# [315/6866] Processing shape: Bottle_243
# Successfully constructed tree for shape: 3757
# ✅ Successfully saved to dataset/Bottle_243.json
#
# [316/6866] Processing shape: Bottle_244
# Successfully constructed tree for shape: 3758
# ✅ Successfully saved to dataset/Bottle_244.json
#
# [317/6866] Processing shape: Bottle_245
# Successfully constructed tree for shape: 3760
# ✅ Successfully saved to dataset/Bottle_245.json
#
# [318/6866] Processing shape: Bottle_246
# Successfully constructed tree for shape: 3761
# ✅ Successfully saved to dataset/Bottle_246.json
#
# [319/6866] Processing shape: Bottle_247
# Successfully constructed tree for shape: 3763
# ✅ Successfully saved to dataset/Bottle_247.json
#
# [320/6866] Processing shape: Bottle_248
# Successfully constructed tree for shape: 3765
# ✅ Successfully saved to dataset/Bottle_248.json
#
# [321/6866] Processing shape: Bottle_249
# Successfully constructed tree for shape: 3767
# ✅ Successfully saved to dataset/Bottle_249.json
#
# [322/6866] Processing shape: Bottle_25
# Successfully constructed tree for shape: 3486
# ✅ Successfully saved to dataset/Bottle_25.json
#
# [323/6866] Processing shape: Bottle_250
# Successfully constructed tree for shape: 3768
# ✅ Successfully saved to dataset/Bottle_250.json
#
# [324/6866] Processing shape: Bottle_251
# Successfully constructed tree for shape: 3769
# ✅ Successfully saved to dataset/Bottle_251.json
#
# [325/6866] Processing shape: Bottle_252
# Successfully constructed tree for shape: 3770
# ✅ Successfully saved to dataset/Bottle_252.json
#
# [326/6866] Processing shape: Bottle_253
# Successfully constructed tree for shape: 3771
# ✅ Successfully saved to dataset/Bottle_253.json
#
# [327/6866] Processing shape: Bottle_254
# Successfully constructed tree for shape: 3772
# ✅ Successfully saved to dataset/Bottle_254.json
#
# [328/6866] Processing shape: Bottle_255
# Successfully constructed tree for shape: 3773
# ✅ Successfully saved to dataset/Bottle_255.json
#
# [329/6866] Processing shape: Bottle_256
# Successfully constructed tree for shape: 3774
# ✅ Successfully saved to dataset/Bottle_256.json
#
# [330/6866] Processing shape: Bottle_257
# Successfully constructed tree for shape: 3776
# ✅ Successfully saved to dataset/Bottle_257.json
#
# [331/6866] Processing shape: Bottle_258
# Successfully constructed tree for shape: 3777
# ✅ Successfully saved to dataset/Bottle_258.json
#
# [332/6866] Processing shape: Bottle_259
# Successfully constructed tree for shape: 3778
# ✅ Successfully saved to dataset/Bottle_259.json
#
# [333/6866] Processing shape: Bottle_26
# Successfully constructed tree for shape: 3495
# ✅ Successfully saved to dataset/Bottle_26.json
#
# [334/6866] Processing shape: Bottle_260
# Successfully constructed tree for shape: 3779
# ✅ Successfully saved to dataset/Bottle_260.json
#
# [335/6866] Processing shape: Bottle_261
# Successfully constructed tree for shape: 3780
# ✅ Successfully saved to dataset/Bottle_261.json
#
# [336/6866] Processing shape: Bottle_262
# Successfully constructed tree for shape: 3781
# ✅ Successfully saved to dataset/Bottle_262.json
#
# [337/6866] Processing shape: Bottle_263
# Successfully constructed tree for shape: 3782
# ✅ Successfully saved to dataset/Bottle_263.json
#
# [338/6866] Processing shape: Bottle_264
# Successfully constructed tree for shape: 3783
# ✅ Successfully saved to dataset/Bottle_264.json
#
# [339/6866] Processing shape: Bottle_265
# Successfully constructed tree for shape: 3784
# ✅ Successfully saved to dataset/Bottle_265.json
#
# [340/6866] Processing shape: Bottle_266
# Successfully constructed tree for shape: 3785
# ✅ Successfully saved to dataset/Bottle_266.json
#
# [341/6866] Processing shape: Bottle_267
# Successfully constructed tree for shape: 3786
# ✅ Successfully saved to dataset/Bottle_267.json
#
# [342/6866] Processing shape: Bottle_268
# Successfully constructed tree for shape: 3787
# ✅ Successfully saved to dataset/Bottle_268.json
#
# [343/6866] Processing shape: Bottle_269
# Successfully constructed tree for shape: 3788
# ✅ Successfully saved to dataset/Bottle_269.json
#
# [344/6866] Processing shape: Bottle_27
# Successfully constructed tree for shape: 3497
# ✅ Successfully saved to dataset/Bottle_27.json
#
# [345/6866] Processing shape: Bottle_270
# Successfully constructed tree for shape: 3789
# ✅ Successfully saved to dataset/Bottle_270.json
#
# [346/6866] Processing shape: Bottle_271
# Successfully constructed tree for shape: 3790
# ✅ Successfully saved to dataset/Bottle_271.json
#
# [347/6866] Processing shape: Bottle_272
# Successfully constructed tree for shape: 3791
# ✅ Successfully saved to dataset/Bottle_272.json
#
# [348/6866] Processing shape: Bottle_273
# Successfully constructed tree for shape: 3792
# ✅ Successfully saved to dataset/Bottle_273.json
#
# [349/6866] Processing shape: Bottle_274
# Successfully constructed tree for shape: 3793
# ✅ Successfully saved to dataset/Bottle_274.json
#
# [350/6866] Processing shape: Bottle_275
# Successfully constructed tree for shape: 3794
# ✅ Successfully saved to dataset/Bottle_275.json
#
# [351/6866] Processing shape: Bottle_276
# Successfully constructed tree for shape: 3795
# ✅ Successfully saved to dataset/Bottle_276.json
#
# [352/6866] Processing shape: Bottle_277
# Successfully constructed tree for shape: 3796
# ✅ Successfully saved to dataset/Bottle_277.json
#
# [353/6866] Processing shape: Bottle_278
# Successfully constructed tree for shape: 3797
# ✅ Successfully saved to dataset/Bottle_278.json
#
# [354/6866] Processing shape: Bottle_279
# Successfully constructed tree for shape: 3798
# ✅ Successfully saved to dataset/Bottle_279.json
#
# [355/6866] Processing shape: Bottle_28
# Successfully constructed tree for shape: 3499
# ✅ Successfully saved to dataset/Bottle_28.json
#
# [356/6866] Processing shape: Bottle_280
# Successfully constructed tree for shape: 3799
# ✅ Successfully saved to dataset/Bottle_280.json
#
# [357/6866] Processing shape: Bottle_281
# Successfully constructed tree for shape: 3800
# ✅ Successfully saved to dataset/Bottle_281.json
#
# [358/6866] Processing shape: Bottle_282
# Successfully constructed tree for shape: 3801
# ✅ Successfully saved to dataset/Bottle_282.json
#
# [359/6866] Processing shape: Bottle_283
# Successfully constructed tree for shape: 3802
# ✅ Successfully saved to dataset/Bottle_283.json
#
# [360/6866] Processing shape: Bottle_284
# Successfully constructed tree for shape: 3804
# ✅ Successfully saved to dataset/Bottle_284.json
#
# [361/6866] Processing shape: Bottle_285
# Successfully constructed tree for shape: 3805
# ✅ Successfully saved to dataset/Bottle_285.json
#
# [362/6866] Processing shape: Bottle_286
# Successfully constructed tree for shape: 3806
# ✅ Successfully saved to dataset/Bottle_286.json
#
# [363/6866] Processing shape: Bottle_287
# Successfully constructed tree for shape: 3807
# ✅ Successfully saved to dataset/Bottle_287.json
#
# [364/6866] Processing shape: Bottle_288
# Successfully constructed tree for shape: 3808
# ✅ Successfully saved to dataset/Bottle_288.json
#
# ...
# ✅ Successfully saved to dataset/Chair_892.json
#
# [6749/6866] Processing shape: Chair_893
# Successfully constructed tree for shape: 35153
# ✅ Successfully saved to dataset/Chair_893.json
#
# [6750/6866] Processing shape: Chair_894
# Successfully constructed tree for shape: 35174
# ✅ Successfully saved to dataset/Chair_894.json
#
# [6751/6866] Processing shape: Chair_895
# Successfully constructed tree for shape: 35176
# ✅ Successfully saved to dataset/Chair_895.json
#
# [6752/6866] Processing shape: Chair_896
# Successfully constructed tree for shape: 35178
# ✅ Successfully saved to dataset/Chair_896.json
#
# [6753/6866] Processing shape: Chair_897
# Successfully constructed tree for shape: 35182
# ✅ Successfully saved to dataset/Chair_897.json
#
# [6754/6866] Processing shape: Chair_898
# Successfully constructed tree for shape: 35183
# ✅ Successfully saved to dataset/Chair_898.json
#
# [6755/6866] Processing shape: Chair_899
# Successfully constructed tree for shape: 35185
# ✅ Successfully saved to dataset/Chair_899.json
#
# [6756/6866] Processing shape: Chair_9
# Successfully constructed tree for shape: 1297
# ✅ Successfully saved to dataset/Chair_9.json
#
# [6757/6866] Processing shape: Chair_90
# Successfully constructed tree for shape: 2215
# ✅ Successfully saved to dataset/Chair_90.json
#
# [6758/6866] Processing shape: Chair_900
# Successfully constructed tree for shape: 35186
# ✅ Successfully saved to dataset/Chair_900.json
#
# [6759/6866] Processing shape: Chair_901
# Successfully constructed tree for shape: 35187
# ✅ Successfully saved to dataset/Chair_901.json
#
# [6760/6866] Processing shape: Chair_902
# Successfully constructed tree for shape: 35189
# ✅ Successfully saved to dataset/Chair_902.json
#
# [6761/6866] Processing shape: Chair_903
# Successfully constructed tree for shape: 35190
# ✅ Successfully saved to dataset/Chair_903.json
#
# [6762/6866] Processing shape: Chair_904
# Successfully constructed tree for shape: 35192
# ✅ Successfully saved to dataset/Chair_904.json
#
# [6763/6866] Processing shape: Chair_905
# Successfully constructed tree for shape: 35194
# ✅ Successfully saved to dataset/Chair_905.json
#
# [6764/6866] Processing shape: Chair_906
# Successfully constructed tree for shape: 35196
# ✅ Successfully saved to dataset/Chair_906.json
#
# [6765/6866] Processing shape: Chair_907
# Successfully constructed tree for shape: 35197
# ✅ Successfully saved to dataset/Chair_907.json
#
# [6766/6866] Processing shape: Chair_908
# Successfully constructed tree for shape: 35198
# ✅ Successfully saved to dataset/Chair_908.json
#
# [6767/6866] Processing shape: Chair_909
# Successfully constructed tree for shape: 35200
# ✅ Successfully saved to dataset/Chair_909.json
#
# [6768/6866] Processing shape: Chair_91
# Successfully constructed tree for shape: 2216
# ✅ Successfully saved to dataset/Chair_91.json
#
# [6769/6866] Processing shape: Chair_910
# Successfully constructed tree for shape: 35201
# ✅ Successfully saved to dataset/Chair_910.json
#
# [6770/6866] Processing shape: Chair_911
# Successfully constructed tree for shape: 35203
# ✅ Successfully saved to dataset/Chair_911.json
#
# [6771/6866] Processing shape: Chair_912
# Successfully constructed tree for shape: 35204
# ✅ Successfully saved to dataset/Chair_912.json
#
# [6772/6866] Processing shape: Chair_913
# Successfully constructed tree for shape: 35205
# ✅ Successfully saved to dataset/Chair_913.json
#
# [6773/6866] Processing shape: Chair_914
# Successfully constructed tree for shape: 35208
# ✅ Successfully saved to dataset/Chair_914.json
#
# [6774/6866] Processing shape: Chair_915
# Successfully constructed tree for shape: 35210
# ✅ Successfully saved to dataset/Chair_915.json
#
# [6775/6866] Processing shape: Chair_916
# Successfully constructed tree for shape: 35211
# ✅ Successfully saved to dataset/Chair_916.json
#
# [6776/6866] Processing shape: Chair_917
# Successfully constructed tree for shape: 35212
# ✅ Successfully saved to dataset/Chair_917.json
#
# [6777/6866] Processing shape: Chair_918
# Successfully constructed tree for shape: 35213
# ✅ Successfully saved to dataset/Chair_918.json
#
# [6778/6866] Processing shape: Chair_919
# Successfully constructed tree for shape: 35214
# ✅ Successfully saved to dataset/Chair_919.json
#
# [6779/6866] Processing shape: Chair_92
# Successfully constructed tree for shape: 2217
# ✅ Successfully saved to dataset/Chair_92.json
#
# [6780/6866] Processing shape: Chair_920
# Successfully constructed tree for shape: 35215
# ✅ Successfully saved to dataset/Chair_920.json
#
# [6781/6866] Processing shape: Chair_921
# Successfully constructed tree for shape: 35217
# ✅ Successfully saved to dataset/Chair_921.json
#
# [6782/6866] Processing shape: Chair_922
# Successfully constructed tree for shape: 35222
# ✅ Successfully saved to dataset/Chair_922.json
#
# [6783/6866] Processing shape: Chair_923
# Successfully constructed tree for shape: 35223
# ✅ Successfully saved to dataset/Chair_923.json
#
# [6784/6866] Processing shape: Chair_924
# Successfully constructed tree for shape: 35229
# ✅ Successfully saved to dataset/Chair_924.json
#
# [6785/6866] Processing shape: Chair_925
# Successfully constructed tree for shape: 35231
# ✅ Successfully saved to dataset/Chair_925.json
#
# [6786/6866] Processing shape: Chair_926
# Successfully constructed tree for shape: 35233
# ✅ Successfully saved to dataset/Chair_926.json
#
# [6787/6866] Processing shape: Chair_927
# Successfully constructed tree for shape: 35234
# ✅ Successfully saved to dataset/Chair_927.json
#
# [6788/6866] Processing shape: Chair_928
# Successfully constructed tree for shape: 35235
# ✅ Successfully saved to dataset/Chair_928.json
#
# [6789/6866] Processing shape: Chair_929
# Successfully constructed tree for shape: 35236
# ✅ Successfully saved to dataset/Chair_929.json
#
# [6790/6866] Processing shape: Chair_93
# Successfully constructed tree for shape: 2218
# ✅ Successfully saved to dataset/Chair_93.json
#
# [6791/6866] Processing shape: Chair_930
# Successfully constructed tree for shape: 35238
# ✅ Successfully saved to dataset/Chair_930.json
#
# [6792/6866] Processing shape: Chair_931
# Successfully constructed tree for shape: 35239
# ✅ Successfully saved to dataset/Chair_931.json
#
# [6793/6866] Processing shape: Chair_932
# Successfully constructed tree for shape: 35242
# ✅ Successfully saved to dataset/Chair_932.json
#
# [6794/6866] Processing shape: Chair_933
# Successfully constructed tree for shape: 35245
# ✅ Successfully saved to dataset/Chair_933.json
#
# [6795/6866] Processing shape: Chair_934
# Successfully constructed tree for shape: 35254
# ✅ Successfully saved to dataset/Chair_934.json
#
# [6796/6866] Processing shape: Chair_935
# Successfully constructed tree for shape: 35255
# ✅ Successfully saved to dataset/Chair_935.json
#
# [6797/6866] Processing shape: Chair_936
# Successfully constructed tree for shape: 35258
# ✅ Successfully saved to dataset/Chair_936.json
#
# [6798/6866] Processing shape: Chair_937
# Successfully constructed tree for shape: 35270
# ✅ Successfully saved to dataset/Chair_937.json
#
# [6799/6866] Processing shape: Chair_938
# Successfully constructed tree for shape: 35273
# ✅ Successfully saved to dataset/Chair_938.json
#
# [6800/6866] Processing shape: Chair_939
# Successfully constructed tree for shape: 35274
# ✅ Successfully saved to dataset/Chair_939.json
#
# [6801/6866] Processing shape: Chair_94
# Successfully constructed tree for shape: 2219
# ✅ Successfully saved to dataset/Chair_94.json
#
# [6802/6866] Processing shape: Chair_940
# Successfully constructed tree for shape: 35275
# ✅ Successfully saved to dataset/Chair_940.json
#
# [6803/6866] Processing shape: Chair_941
# Successfully constructed tree for shape: 35285
# ✅ Successfully saved to dataset/Chair_941.json
#
# [6804/6866] Processing shape: Chair_942
# Successfully constructed tree for shape: 35291
# ✅ Successfully saved to dataset/Chair_942.json
#
# [6805/6866] Processing shape: Chair_943
# Successfully constructed tree for shape: 35307
# ✅ Successfully saved to dataset/Chair_943.json
#
# [6806/6866] Processing shape: Chair_944
# Successfully constructed tree for shape: 35316
# ✅ Successfully saved to dataset/Chair_944.json
#
# [6807/6866] Processing shape: Chair_945
# Successfully constructed tree for shape: 35319
# ✅ Successfully saved to dataset/Chair_945.json
#
# [6808/6866] Processing shape: Chair_946
# Successfully constructed tree for shape: 35320
# ✅ Successfully saved to dataset/Chair_946.json
#
# [6809/6866] Processing shape: Chair_947
# Successfully constructed tree for shape: 35321
# ✅ Successfully saved to dataset/Chair_947.json
#
# [6810/6866] Processing shape: Chair_948
# Successfully constructed tree for shape: 35326
# ✅ Successfully saved to dataset/Chair_948.json
#
# [6811/6866] Processing shape: Chair_949
# Successfully constructed tree for shape: 35330
# ✅ Successfully saved to dataset/Chair_949.json
#
# [6812/6866] Processing shape: Chair_95
# Successfully constructed tree for shape: 2221
# ✅ Successfully saved to dataset/Chair_95.json
#
# [6813/6866] Processing shape: Chair_950
# Successfully constructed tree for shape: 35331
# ✅ Successfully saved to dataset/Chair_950.json
#
# [6814/6866] Processing shape: Chair_951
# Successfully constructed tree for shape: 35333
# ✅ Successfully saved to dataset/Chair_951.json
#
# [6815/6866] Processing shape: Chair_952
# Successfully constructed tree for shape: 35350
# ✅ Successfully saved to dataset/Chair_952.json
#
# [6816/6866] Processing shape: Chair_953
# Successfully constructed tree for shape: 35355
# ✅ Successfully saved to dataset/Chair_953.json
#
# [6817/6866] Processing shape: Chair_954
# Successfully constructed tree for shape: 35356
# ✅ Successfully saved to dataset/Chair_954.json
#
# [6818/6866] Processing shape: Chair_955
# Successfully constructed tree for shape: 35367
# ✅ Successfully saved to dataset/Chair_955.json
#
# [6819/6866] Processing shape: Chair_956
# Successfully constructed tree for shape: 35368
# ✅ Successfully saved to dataset/Chair_956.json
#
# [6820/6866] Processing shape: Chair_957
# Successfully constructed tree for shape: 35370
# ✅ Successfully saved to dataset/Chair_957.json
#
# [6821/6866] Processing shape: Chair_958
# Successfully constructed tree for shape: 35372
# ✅ Successfully saved to dataset/Chair_958.json
#
# [6822/6866] Processing shape: Chair_959
# Successfully constructed tree for shape: 35376
# ✅ Successfully saved to dataset/Chair_959.json
#
# [6823/6866] Processing shape: Chair_96
# Successfully constructed tree for shape: 2222
# ✅ Successfully saved to dataset/Chair_96.json
#
# [6824/6866] Processing shape: Chair_960
# Successfully constructed tree for shape: 35377
# ✅ Successfully saved to dataset/Chair_960.json
#
# [6825/6866] Processing shape: Chair_961
# Successfully constructed tree for shape: 35379
# ✅ Successfully saved to dataset/Chair_961.json
#
# [6826/6866] Processing shape: Chair_962
# Successfully constructed tree for shape: 35381
# ✅ Successfully saved to dataset/Chair_962.json
#
# [6827/6866] Processing shape: Chair_963
# Successfully constructed tree for shape: 35384
# ✅ Successfully saved to dataset/Chair_963.json
#
# [6828/6866] Processing shape: Chair_964
# Successfully constructed tree for shape: 35385
# ✅ Successfully saved to dataset/Chair_964.json
#
# [6829/6866] Processing shape: Chair_965
# Successfully constructed tree for shape: 35387
# ✅ Successfully saved to dataset/Chair_965.json
#
# [6830/6866] Processing shape: Chair_966
# Successfully constructed tree for shape: 35389
# ✅ Successfully saved to dataset/Chair_966.json
#
# [6831/6866] Processing shape: Chair_967
# Successfully constructed tree for shape: 35392
# ✅ Successfully saved to dataset/Chair_967.json
#
# [6832/6866] Processing shape: Chair_968
# Successfully constructed tree for shape: 35394
# ✅ Successfully saved to dataset/Chair_968.json
#
# [6833/6866] Processing shape: Chair_969
# Successfully constructed tree for shape: 35396
# ✅ Successfully saved to dataset/Chair_969.json
#
# [6834/6866] Processing shape: Chair_97
# Successfully constructed tree for shape: 2223
# ✅ Successfully saved to dataset/Chair_97.json
#
# [6835/6866] Processing shape: Chair_970
# Successfully constructed tree for shape: 35399
# ✅ Successfully saved to dataset/Chair_970.json
#
# [6836/6866] Processing shape: Chair_971
# Successfully constructed tree for shape: 35401
# ✅ Successfully saved to dataset/Chair_971.json
#
# [6837/6866] Processing shape: Chair_972
# Successfully constructed tree for shape: 35402
# ✅ Successfully saved to dataset/Chair_972.json
#
# [6838/6866] Processing shape: Chair_973
# Successfully constructed tree for shape: 35406
# ✅ Successfully saved to dataset/Chair_973.json
#
# [6839/6866] Processing shape: Chair_974
# Successfully constructed tree for shape: 35407
# ✅ Successfully saved to dataset/Chair_974.json
#
# [6840/6866] Processing shape: Chair_975
# Successfully constructed tree for shape: 35409
# ✅ Successfully saved to dataset/Chair_975.json
#
# [6841/6866] Processing shape: Chair_976
# Successfully constructed tree for shape: 35422
# ✅ Successfully saved to dataset/Chair_976.json
#
# [6842/6866] Processing shape: Chair_977
# Successfully constructed tree for shape: 35423
# ✅ Successfully saved to dataset/Chair_977.json
#
# [6843/6866] Processing shape: Chair_978
# Successfully constructed tree for shape: 35424
# ✅ Successfully saved to dataset/Chair_978.json
#
# [6844/6866] Processing shape: Chair_979
# Successfully constructed tree for shape: 35436
# ✅ Successfully saved to dataset/Chair_979.json
#
# [6845/6866] Processing shape: Chair_98
# Successfully constructed tree for shape: 2225
# ✅ Successfully saved to dataset/Chair_98.json
#
# [6846/6866] Processing shape: Chair_980
# Successfully constructed tree for shape: 35438
# ✅ Successfully saved to dataset/Chair_980.json
#
# [6847/6866] Processing shape: Chair_981
# Successfully constructed tree for shape: 35439
# ✅ Successfully saved to dataset/Chair_981.json
#
# [6848/6866] Processing shape: Chair_982
# Successfully constructed tree for shape: 35440
# ✅ Successfully saved to dataset/Chair_982.json
#
# [6849/6866] Processing shape: Chair_983
# Successfully constructed tree for shape: 35441
# ✅ Successfully saved to dataset/Chair_983.json
#
# [6850/6866] Processing shape: Chair_984
# Successfully constructed tree for shape: 35442
# ✅ Successfully saved to dataset/Chair_984.json
#
# [6851/6866] Processing shape: Chair_985
# Successfully constructed tree for shape: 35443
# ✅ Successfully saved to dataset/Chair_985.json
#
# [6852/6866] Processing shape: Chair_986
# Successfully constructed tree for shape: 35445
# ✅ Successfully saved to dataset/Chair_986.json
#
# [6853/6866] Processing shape: Chair_987
# Successfully constructed tree for shape: 35447
# ✅ Successfully saved to dataset/Chair_987.json
#
# [6854/6866] Processing shape: Chair_988
# Successfully constructed tree for shape: 35448
# ✅ Successfully saved to dataset/Chair_988.json
#
# [6855/6866] Processing shape: Chair_989
# Successfully constructed tree for shape: 35449
# ✅ Successfully saved to dataset/Chair_989.json
#
# [6856/6866] Processing shape: Chair_99
# Successfully constructed tree for shape: 2226
# ✅ Successfully saved to dataset/Chair_99.json
#
# [6857/6866] Processing shape: Chair_990
# Successfully constructed tree for shape: 35453
# ✅ Successfully saved to dataset/Chair_990.json
#
# [6858/6866] Processing shape: Chair_991
# Successfully constructed tree for shape: 35455
# ✅ Successfully saved to dataset/Chair_991.json
#
# [6859/6866] Processing shape: Chair_992
# Successfully constructed tree for shape: 35464
# ✅ Successfully saved to dataset/Chair_992.json
#
# [6860/6866] Processing shape: Chair_993
# Successfully constructed tree for shape: 35465
# ✅ Successfully saved to dataset/Chair_993.json
#
# [6861/6866] Processing shape: Chair_994
# Successfully constructed tree for shape: 35470
# ✅ Successfully saved to dataset/Chair_994.json
#
# [6862/6866] Processing shape: Chair_995
# Successfully constructed tree for shape: 35471
# ✅ Successfully saved to dataset/Chair_995.json
#
# [6863/6866] Processing shape: Chair_996
# Successfully constructed tree for shape: 35473
# ✅ Successfully saved to dataset/Chair_996.json
#
# [6864/6866] Processing shape: Chair_997
# Successfully constructed tree for shape: 35475
# ✅ Successfully saved to dataset/Chair_997.json
#
# [6865/6866] Processing shape: Chair_998
# Successfully constructed tree for shape: 35476
# ✅ Successfully saved to dataset/Chair_998.json
#
# [6866/6866] Processing shape: Chair_999
# Successfully constructed tree for shape: 35477
# ✅ Successfully saved to dataset/Chair_999.json
#
# --- All shapes processed. ---
